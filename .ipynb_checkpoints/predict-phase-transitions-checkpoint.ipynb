# %%
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd
import seaborn           as sns
import libraries.model   as clm
import libraries.dataset as cld
import os
import torch
import json

# Checking if pytorch can run in GPU, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sns.set_theme()

# %% [markdown]
# In this notebook you are able to load an use a pre-trained model for predicting the lattice contribution to the free-energy over an input database. The model, $GCNN$, predicts the lattice contribution to the free-energy, $F_v(m, T) = GCNN(m, T)$, for material $m$ at temperature $T$. Then, knowing the ground-state energy of material $m$, $E_0 (m)$ (typically estimated from DFT), the Helmholtz free-energy reads from:
#
# \begin{equation}
#     F(m, T) = E_0 (m) + F_v(m, T)
# \end{equation}
#
# Importantly, this approach disregards any other contribution to the free-energy that just vibrational (e.g., metallic materials should be avoided).
#
# The baseline pretrained model has been trained in the 100 to 700 K temperature range, thus it is recommended to make predictions within the 200 to 600 K range, in order to avoid the misbehaviour of $C_p$ at high temperature.
#
# We implemented a tool which allows estimating the quality of the predicted free energy regarding 1) the chemistry of the target material and 2) the temperature at which the prediction is made. This approach is valid for any other input model, as it directly checks the proximity of the hyper-representation that the GCNN creates for the target material and this from any known prediction.
#
# Ferromagnetic transitions are estimated based on pure geometrical reasons, predicted as any transition involving a non-centrosymmmetric space group.
#
# The input database should contain on each folder a POSCAR file with the structure, a file name EPA with the energy per atom in eV/atom (typically from DFT) and, optionally, a file name LTC with the lattice thermal conductivity in W/mK. It should be strucuture like:
#
# **database**
# &nbsp;**material-1**
# &nbsp;&nbsp;&nbsp;**polymorph-1**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- POSCAR
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- EPA
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- LTC (opt)
# &nbsp;&nbsp;&nbsp;**polymorph-2**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- POSCAR
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- EPA
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- LTC (opt)
# &nbsp;&nbsp;&nbsp;**polymorph-...**
# &nbsp;**material-2**
# &nbsp;&nbsp;&nbsp;**polymorph-...**
# &nbsp;**material-...**

# %% [markdown]
# # Define parameters

# %%
model_folder    = 'model'  # Pre-trained model and dataset parameters
data_folder     = 'example-data'  # Example coefficients and labels of the target database
output_folder   = 'output'  # Output files and figures
input_folder    = 'input'  # General files (e.g., atomic masses information)
target_database = '/home/claudio/cibran/Work/UCL/PhaseTransitions/Loaded_PhaseTransition'  # Target database

# Whether to plot the harmonic extrapolations of Fv (very time-consuming) or not
plot_extrapolations = False

# Defining the range of temperatures
Ti = 300
Tf = 600
dT = 50
temperatures = np.arange(Ti, Tf+dT, dT)  # Temperatures for prediction of free-energies

# Loading dictionary of atomic masses
atomic_masses = cld.load_atomic_masses(f'{input_folder}/atomic_masses.dat')

# %% [markdown]
# # Perform predictions

# %% [markdown]
# For the sake of optimization, we first predict all free-energies in the target database. In order to do that, we read the parameters needed for standardizing the target dataset, load the pre-trained model, perform the predictions and smooth those with a fitting to a fourth-order polynomial (with respect to temperature).

# %%
if os.path.exists(f'{data_folder}/coefficients.txt'):
    coefficients  = np.loadtxt(f'{data_folder}/coefficients.txt')
    uncertainties = np.loadtxt(f'{data_folder}/uncertainties.txt')
    labels = [f'{label[0]} {label[1]}' for label in np.loadtxt(f'{data_folder}/labels.txt', dtype=str)]
else:
    # Load the data from the JSON file
    with open(f'{model_folder}/standardized_parameters.json', 'r') as json_file:
        numpy_dict = json.load(json_file)

    # Convert NumPy arrays back to PyTorch tensors
    standardized_parameters = {}
    for key, value in numpy_dict.items():
        try:
            standardized_parameters[key] = torch.tensor(value)
        except:
            standardized_parameters[key] = value

    # Load reference dataset for uncertainty estimation
    reference_dataset = torch.load(f'{model_folder}/ref_dataset_std.pt', weights_only=False)

    # Load Graph Neural Network model (making room for temperature as node attribute) to device
    # Dropout for initializing the model, not used at all while predicting
    model = clm.GCNN(features_channels=5,
                     pdropout=0).to(device)

    # Load and evaluate Graph Neural Network model
    model.load_state_dict(torch.load(f'{model_folder}/model.pt', map_location=torch.device(device)))
    model.eval()

    uncertainty_data = cld.load_json(f'{model_folder}/uncertainty_data.json')

    interpolator = clm.fit_interpolator(uncertainty_data['uncertainty_values'], reference_dataset, model)
    del reference_dataset

    # Create dataset for predictions
    dataset = cld.create_predictions_dataset(target_database)
    labels  = [graph.label for graph in dataset]

    # Standardize properties
    std_dataset = cld.standardize_dataset_from_keys(dataset, standardized_parameters)

    # Free-up CUDA
    del dataset

    # Include temperatures
    std_dataset_w_temp = cld.include_temperatures(std_dataset, temperatures, standardized_parameters)

    # Free-up CUDA
    del std_dataset

    # Compute predictions and corresponding uncertainties
    predictions, uncertainties = clm.make_predictions(std_dataset_w_temp,  model, standardized_parameters,
                                                      uncertainty_data, interpolator)

    # Free-up CUDA
    del std_dataset_w_temp, reference_dataset

    # Computing the coefficients and uncertainties from fitting
    coefficients = clm.compute_coefficients(temperatures, predictions)

    np.savetxt(f'{data_folder}/coefficients.txt',  coefficients)
    np.savetxt(f'{data_folder}/uncertainties.txt', uncertainties)
    np.savetxt(f'{data_folder}/labels.txt',        labels, fmt='%s')

# %%
n_graphs = int(len(uncertainties) / len(temperatures))

uncertainties_list = []
for i in range(n_graphs):
    idx0 = i     * len(temperatures)
    idxf = (i+1) * len(temperatures)

    # Concatenate array
    uncert = uncertainties[idx0:idxf]
    uncert = np.ones_like(uncert) * np.max(np.abs(uncert))
    uncertainties_list.append(uncert)

# Convert into array and transpose
uncertainties = np.array(uncertainties_list).T

# %% [markdown]
# # Compute phase transitions

# %% [markdown]
# Then, we have already computed the free-energies for each material in the intended temperature range and also the parameters of the fourth-order polynomial which smooths the predictions. With that information, we can look for phase transitions for each materials presenting at least two polymorphs in the target dataset and, for those, extract transition temperature, entropy change or whether this is or not a ferroelectric transition.

# %%
# Ordering by families
indexes       = np.argsort(labels)  # This way we put all the polymorphs from a same material together
labels        = np.array(labels)[indexes]
coefficients  = coefficients[:, indexes]
uncertainties = uncertainties[:, indexes]

# Separating compounds and polymorphes
compounds, polymorphs = zip(*(line.split() for line in labels))

# Reading ground state energies (energy per atom)
# From eV/atom to meV/atom
gs_energies = [float(np.loadtxt(f'{target_database}/{comp}/{poly}/EPA')) * 1e3 for comp, poly in zip(compounds, polymorphs)]

# Reading conductivities (lattice thermal conductivities)
# In W/mK
conductivities = [float(np.loadtxt(f'{target_database}/{comp}/{poly}/LTC'))
                  if os.path.isfile(f'{target_database}/{comp}/{poly}/LTC') else np.nan for comp, poly in zip(compounds, polymorphs)]

# Reading centrosymmetris (1 is centrosymmetric, 0 is not)
centrosymmetries = np.array([np.loadtxt(f'{target_database}/{comp}/{poly}/is_centrosymmetric', dtype=int) for comp, poly in zip(compounds, polymorphs)])
space_groups     = np.array([np.loadtxt(f'{target_database}/{comp}/{poly}/space_group', dtype=str) for comp, poly in zip(compounds, polymorphs)])

# Unique compounds (not considering polymorphes)
unique_compounds, unique_counts = np.unique(compounds, return_counts=True)
unique_indexes = np.append([0], np.cumsum(unique_counts))  # So it starts with 0

# %%
# Initializing files with data
stable_transition_phases   = []
metastable_transition_phases = []
for i, compound in enumerate(unique_compounds):
    # Getting corresponding predictions
    index1 = unique_indexes[i]
    index2 = unique_indexes[i+1]

    index_gs_energies      = gs_energies[index1:index2]
    index_conductivities   = conductivities[index1:index2]
    index_centrosymmetries = centrosymmetries[index1:index2]
    index_space_groups     = space_groups[index1:index2]
    index_coefficients     = coefficients[:, index1:index2]
    index_uncertainties    = uncertainties[:, index1:index2]

    n_polymorphs = index2 - index1
    if n_polymorphs > 1:
        print(compound)

        for k in range(n_polymorphs):
            gs_energy_k      = index_gs_energies[k]
            conductivity_k   = index_conductivities[k]
            centrosymmetry_k = index_centrosymmetries[k]
            space_group_k    = index_space_groups[k]
            coefficient_k    = index_coefficients[:, k]
            uncertainty_k    = index_uncertainties[:, k]

            # Plotting
            if plot_extrapolations:
                # Temperature range for plotting
                temperatures_plot = np.arange(Ti, Tf+dT, 0.1)

                # Smooth Gibbs energy for plotting
                gibbs_energy_plot = gs_energy_k + clm.Helmholtz_free_energy_function(temperatures_plot, *coefficient_k)
                plt.plot(temperatures_plot, gibbs_energy_plot, label=space_group_k)

            # Looking for phase transitions
            for m in np.arange(k+1, n_polymorphs):
                gs_energy_m      = index_gs_energies[m]
                conductivity_m   = index_conductivities[m]
                centrosymmetry_m = index_centrosymmetries[m]
                space_group_m    = index_space_groups[m]
                coefficient_m    = index_coefficients[:, m]
                uncertainty_m    = index_uncertainties[:, m]

                # Computing the entropy change provoked by the transition
                d_E0 = gs_energy_m - gs_energy_k
                d_alpha, d_beta, d_gamma = coefficient_m - coefficient_k
                
                # We scaled parameters for fitting, so now we re-scale them
                d_beta  *= 1e-5
                d_gamma *= 1e-10
                
                # Two possible transition temperatures
                temp_root_1 = (-d_beta + np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha) * d_gamma)) / (2 * d_gamma)
                temp_root_2 = (-d_beta - np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha) * d_gamma)) / (2 * d_gamma)

                # Filter valid transition within the temperature range of interest
                c_valid_temperatures = [x for x in [np.sqrt(temp_root_1), np.sqrt(temp_root_2)] if Ti < x < Tf]

                # Determine if there is any transition within the temperature interval
                if not len(c_valid_temperatures):  # There is not a transition between these polymorphs
                    continue
                elif len(c_valid_temperatures) > 1:
                    print(f'Warning: {len(c_valid_temperatures)} transitions within this interval')

                # Get the expected critical temperature and free energy
                c_temperature = np.min(c_valid_temperatures)

                # Compute free energy and slope changes 
                c_free_energy = gs_energy_k + clm.Helmholtz_free_energy_function(c_temperature, *coefficient_k)
                d_slope       = c_temperature * np.abs(2 * d_beta + 4 * d_gamma * c_temperature**2)
                
                # Read atomic information for entropy change estimation
                with open(f'{target_database}/{compound}/{polymorphs[index1+k]}/POSCAR', 'r') as POSCAR_file:
                    POSCAR_lines = POSCAR_file.readlines()
                composition   = POSCAR_lines[5].split()
                concentration = np.array(POSCAR_lines[6].split(), dtype=float)

                # Get atomic mass involved in the transition
                total_mass = sum(float(atomic_masses[el]) * conc for el, conc in zip(composition, concentration))

                # Compute entropy change, from meV/atomK to J/kgK (1e3 as g goes to kg)
                c_entropy = d_slope * 6.022 * 1.6 * 1e4 * concentration.sum() / total_mass

                # Get uncertainties ML
                c_temp_idx = np.argmin(np.abs(temperatures-c_temperature))
                uncert_1 = uncertainty_k[c_temp_idx]
                uncert_2 = uncertainty_m[c_temp_idx]
                uncert_Fv = np.sqrt(uncert_1**2 + uncert_2**2)

                # Two possible transition temperatures for uncertainty
                root_1_n = (-d_beta + np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha - uncert_Fv) * d_gamma)) / (2 * d_gamma)
                root_2_n = (-d_beta - np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha - uncert_Fv) * d_gamma)) / (2 * d_gamma)
                root_1_p = (-d_beta + np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha + uncert_Fv) * d_gamma)) / (2 * d_gamma)
                root_2_p = (-d_beta - np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha + uncert_Fv) * d_gamma)) / (2 * d_gamma)
                uncert_temperature = np.array(
                    [x for x in [np.sqrt(root_1_n), np.sqrt(root_2_n), np.sqrt(root_1_p), np.sqrt(root_2_p)] if x >= 0]
                )

                # The uncertainty temperature is the minimum one
                uncert_ML = np.min(np.abs(uncert_temperature - c_temperature))

                # Get uncertainties DFT
                c_temp_idx = np.argmin(np.abs(temperatures-c_temperature))
                uncert_Fv = np.sqrt(2) * 4  # sqrt(4² + 4²) meV/atom

                # Two possible transition temperatures for uncertainty
                root_1_n = (-d_beta + np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha - uncert_Fv) * d_gamma)) / (2 * d_gamma)
                root_2_n = (-d_beta - np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha - uncert_Fv) * d_gamma)) / (2 * d_gamma)
                root_1_p = (-d_beta + np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha + uncert_Fv) * d_gamma)) / (2 * d_gamma)
                root_2_p = (-d_beta - np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha + uncert_Fv) * d_gamma)) / (2 * d_gamma)
                uncert_temperature = np.array(
                    [x for x in [np.sqrt(root_1_n), np.sqrt(root_2_n), np.sqrt(root_1_p), np.sqrt(root_2_p)] if x >= 0]
                )

                # The uncertainty temperature is the minimum one
                uncert_DFT = np.min(np.abs(uncert_temperature - c_temperature))
                
                # Check which has lower energy at lower temperature
                c_free_energy_1 = gs_energy_k + clm.Helmholtz_free_energy_function(c_temperature-5, *coefficient_k)
                c_free_energy_2 = gs_energy_m + clm.Helmholtz_free_energy_function(c_temperature-5, *coefficient_m)

                first_polymorph, last_polymorph = (space_group_k,  space_group_m) if c_free_energy_1 < c_free_energy_2 else (space_group_m, space_group_k)
                first_LTC,       last_LTC       = (conductivity_k, conductivity_m) if c_free_energy_1 < c_free_energy_2 else (conductivity_m, conductivity_k)
                label = f'{first_polymorph} -> {last_polymorph} ({c_temperature:.2f}K, {c_entropy:.2f} J/kgK)'
                print(label)
                
                if plot_extrapolations:
                    plt.plot(c_temperature, c_free_energy, 'o', label=label)

                # 0, 1, 2 if none, one or both are centrosymmetric, respectively
                centrosymmetric = centrosymmetry_k + centrosymmetry_m
                
                # Get lattice thermal conductivity change
                # Divide by the centrysymmetric (nonpolar) polymorph LTC
                LTC_change = None
                if centrosymmetric == 1:
                    LTC_change = (last_LTC - first_LTC) / first_LTC

                # Append information
                transition_data = {'compound': compound, 'polymorph-1': first_polymorph, 'polymorph-2': last_polymorph,
                                   'transition-temperature': c_temperature, 'entropy-change': c_entropy,
                                   'centrosymmetry': centrosymmetric, 'conductivity-change': LTC_change,
                                   'LTC-1': first_LTC, 'LTC-2': last_LTC,
                                   'uncert-ML': uncert_ML, 'uncert-DFT': uncert_DFT}

                min_vib_energy = min(
                    index_gs_energies[j] + clm.Helmholtz_free_energy_function(c_temperature, *index_coefficients[:, j])
                    for j in range(n_polymorphs)
                )

                if np.isclose(c_free_energy, min_vib_energy):
                    stable_transition_phases.append(transition_data)
                else:
                    metastable_transition_phases.append(transition_data)

        if plot_extrapolations:
            plt.title(compound)
            plt.xlabel('$T$ (K)')
            plt.ylabel(r'$F_{v}$ (meV/atom)')
            plt.legend(loc=(1.05, 0.5))
            plt.savefig(f'{output_folder}/{compound}.pdf', dpi=50, bbox_inches='tight')
            plt.show()
# Out:
# Ag(CO)2
# Ag10Te4Br3
# Ag2B8O13
# Ag2HgI4
# Ag2Mo2O7
# P-1 -> P2_1/c (407.64K, 55.85 J/kgK)
# Ag2PS3
# Ag2S
# Cm -> Cmc2_1 (585.14K, 9.21 J/kgK)
# P1 -> Cmc2_1 (399.86K, 15.97 J/kgK)
# P2_1 -> P2_1/m (537.60K, 6.85 J/kgK)
# Ag2SO4
# Ag2Se
# Ag2WO4
# Ag3AsS3
# C2/c -> R3c (396.70K, 21.31 J/kgK)
# Ag3AsSe3
# Ag3SI
# Ag3SbS3
# AgAsS2
# AgBiO2
# C2/m -> P6_3/mmc (595.71K, 9.13 J/kgK)
# C2/m -> R-3m (593.29K, 9.22 J/kgK)
# AgBr
# AgBrO4
# AgC2N3
# AgC3N3O2
# AgCNO
# AgCSN
# AgCl
# AgClO2
# AgClO3
# P2_13 -> I4/m (341.09K, 191.42 J/kgK)
# AgClO4
# AgGe2N3
# AgH8C3S2ClO4
# AgHgSI
# AgI
# P6_3mc -> F-43m (363.20K, 20.58 J/kgK)
# Fm-3m -> P2_1/m (393.96K, 38.71 J/kgK)
# AgI3O8
# AgIO3
# Pbca -> Pnma (533.82K, 99.81 J/kgK)
# AgN3
# Ibam -> I4/mcm (434.58K, 260.75 J/kgK)
# AgNO2
# AgNO3
# AgSb3PbS6
# AgSbC2N2(ClF3)2
# AgSbS2
# AgTeO3
# Al(CN)3
# R3m -> P-42_1m (462.73K, 81.68 J/kgK)
# Al(HO)3
# P-1 -> Cm (461.23K, 312.94 J/kgK)
# P-1 -> P1 (425.51K, 388.87 J/kgK)
# Warning: 2 transitions within this interval
# P2_1 -> P2_12_12_1 (400.28K, 153.76 J/kgK)
# Al(PO3)3
# Al(SiO3)2
# Al10Si2O19
# Cmc2_1 -> Pm (457.23K, 137.54 J/kgK)
# Al11AgO17
# Ama2 -> Cmcm (368.72K, 58.70 J/kgK)
# Al15Fe9O32
# Al2(MoO4)3
# Al2(SO4)3
# Al2(SeO4)3
# Al2(WO4)3
# P2_1/c -> P2_1 (354.32K, 8.05 J/kgK)
# Al2CO
# Al2CdS4
# Al2CdSe4
# Al2CoO4
# Al2FeO4
# Al2H12(SeO5)3
# Al2HgS4
# Al2Mo2O7
# Al2NiO4
# Al2O3
# Warning: 2 transitions within this interval
# C2/c -> Cmc2_1 (402.32K, 45.57 J/kgK)
# Warning: 2 transitions within this interval
# C2/c -> R3m (364.78K, 118.14 J/kgK)
# R-3 -> P1 (421.97K, 171.48 J/kgK)
# Cmc2_1 -> R3m (336.93K, 70.38 J/kgK)
# P-31c -> Pm (418.31K, 108.03 J/kgK)
# P-31c -> Pnnm (367.60K, 187.45 J/kgK)
# P321 -> P1 (569.40K, 452.13 J/kgK)
# P2_1/m -> Pnnm (444.88K, 109.42 J/kgK)
# Pm -> Pnnm (308.15K, 87.80 J/kgK)
# R-3 -> Pnnm (516.69K, 224.58 J/kgK)
# Al2PbSe4
# Al2S3
# Cc -> P6_1 (396.71K, 79.28 J/kgK)
# Al2Se3
# Al2Si2H4O9
# Cc -> P1 (339.12K, 29.95 J/kgK)
# Al2Si2O7
# Al2Si2PbO8
# Al2Si3H8(NO5)2
# Al2SiO5
# C2/c -> Cmcm (301.53K, 242.34 J/kgK)
# Pnnm -> Pnma (401.89K, 106.74 J/kgK)
# Al2Te3
# Al2W2O7
# Al2Zn(SeS)2
# Al2Zn2S5
# Al2ZnO4
# Al2ZnS4
# I-4 -> Fd-3m (425.54K, 43.83 J/kgK)
# Al2ZnSe4
# Al3BC3
# Al3CrO6
# Al3GaN4
# Al3NO3
# Al3Pb5F19
# Al4B2O9
# Al4Si2H(O3F)3
# Al5(FeO4)3
# Al5C3N
# Al8SiO14
# AlAg(WO4)2
# AlAgO2
# AlAgS2
# AlAs
# AlAsO4
# AlBPbO4
# AlBiN2
# AlBiO3
# AlCoO3
# AlCr(WO4)2
# P1 -> P1 (483.87K, 1.00 J/kgK)
# AlCrO3
# AlCu(WO4)2
# AlCuCl4
# Pna2_1 -> P-42c (443.20K, 82.07 J/kgK)
# AlCuO2
# AlCuS2
# AlF3
# C2 -> P4/mbm (475.34K, 133.18 J/kgK)
# C2 -> P4/nmm (390.50K, 117.21 J/kgK)
# Pm-3m -> Cmcm (453.52K, 46.06 J/kgK)
# AlFe(WO4)2
# AlFeO3
# AlGa3N4
# AlGaN2
# AlGaO3
# AlH10C3N
# AlH12(NO5)3
# AlH12(OF)5
# AlH3
# Fd-3m -> Cmcm (523.64K, 175.96 J/kgK)
# AlH4NF4
# AlHO2
# Pmn2_1 -> P2_1/m (540.99K, 332.44 J/kgK)
# Pnnm -> Pnma (333.71K, 77.55 J/kgK)
# AlHg2SbCl4
# AlInN2
# AlInO3
# AlMo(WO4)2
# AlMoO3
# AlN
# AlNi(WO4)2
# AlP
# F-43m -> P6_3mc (498.31K, 185.96 J/kgK)
# AlP(H2O3)2
# P2_1/c -> Pbca (555.73K, 175.19 J/kgK)
# AlP2H4O8F
# AlPO4
# Aem2 -> Iba2 (362.50K, 26.92 J/kgK)
# Ima2 -> Aem2 (486.10K, 21.67 J/kgK)
# Aem2 -> P-1 (437.25K, 35.33 J/kgK)
# P6_3mc -> C2 (331.90K, 69.38 J/kgK)
# C2/m -> Pbca (596.89K, 28.41 J/kgK)
# P2/c -> C222_1 (534.21K, 80.26 J/kgK)
# R-3 -> Cmc2_1 (401.81K, 89.74 J/kgK)
# Ima2 -> Iba2 (413.23K, 49.11 J/kgK)
# P6cc -> Iba2 (308.11K, 24.95 J/kgK)
# Pnn2 -> Iba2 (528.41K, 50.69 J/kgK)
# Ima2 -> P-1 (455.22K, 57.08 J/kgK)
# Ima2 -> P6cc (577.00K, 21.85 J/kgK)
# Ima2 -> Pca2_1 (560.88K, 43.95 J/kgK)
# P6cc -> P-1 (390.96K, 34.22 J/kgK)
# Pnn2 -> P-1 (562.97K, 57.69 J/kgK)
# P-31c -> Pbca (338.29K, 58.00 J/kgK)
# P6_3mc -> P6_422 (528.32K, 83.90 J/kgK)
# Pnn2 -> P6_422 (308.86K, 60.83 J/kgK)
# P6cc -> Pca2_1 (545.38K, 22.08 J/kgK)
# AlPS4
# AlSb
# AlSb(WO4)2
# AlSbO3
# AlSn3Se2ClO8
# AlTeCl7
# AlVO3
# AlW3O8
# AlWO3
# As2O3
# As2O5
# P2_12_12_1 -> P4_12_12 (363.72K, 3.84 J/kgK)
# P2_12_12_1 -> P4_32_12 (367.48K, 3.85 J/kgK)
# As2S2O9
# P2_1/c -> Pc (334.15K, 36.92 J/kgK)
# As2S3
# As2Se3
# As3HO6
# As3Pb5ClO12
# P2_1/c -> P6_3/m (374.84K, 25.86 J/kgK)
# As3Pb5ClO9
# AsH6NO4
# AsHPbO4
# AsNO4
# AsS
# AsS3(NF3)2
# AsS4N4F5
# AsSClOF8
# AsSXeNF10
# AsXe2F9
# Au2O3
# Fdd2 -> P1 (514.45K, 105.24 J/kgK)
# AuBr
# AuC2N3
# AuCl
# AuClO2
# B
# B(HO)3
# B10H11C2
# B10H13
# Pbca -> P2_1/c (550.47K, 224.16 J/kgK)
# B10H18C2S
# B2(CN2)3
# B2O3
# B2S3
# B3H5
# B4C
# B5H9
# B8O
# B9H11
# BAs
# BAsO4
# BC2N
# BCl
# BF3
# BH2S3N3F4
# BH4N
# BH6N
# Cmc2_1 -> Pmn2_1 (578.23K, 1772.18 J/kgK)
# Pnma -> Pmn2_1 (536.62K, 2028.66 J/kgK)
# BHO2
# P-43n -> P2_1/c (370.65K, 985.60 J/kgK)
# P-43n -> Pnma (520.55K, 760.88 J/kgK)
# BN
# R3m -> Fmm2 (332.24K, 609.92 J/kgK)
# R3m -> P-6m2 (358.83K, 435.39 J/kgK)
# R3m -> P6_3/mmc (350.30K, 448.04 J/kgK)
# BNF8
# BP
# BPO4
# BSbO3
# Ba(AlTe2)2
# Ba(BO2)2
# Ba(BiS2)2
# Ba(BrO3)2
# Ba(C4N3)2
# Ba(CO2)2
# Ba(CuS)2
# Pnma -> I4/mmm (544.36K, 44.49 J/kgK)
# Ba(FeO2)2
# Ba(GaO2)2
# Ba(H2O3)2
# Ba(H8O5)2
# Cc -> C2/c (310.65K, 386.70 J/kgK)
# Pc -> C2/c (500.57K, 477.51 J/kgK)
# Ba(HO)2
# Ba(InTe2)2
# Ba(NdS2)2
# Ba(PO3)2
# Ba(ZnN)2
# Ba10IBr4N5
# Ba10MgAs6(ClO12)2
# Ba10MgMn6(O12F)2
# Ba2As6O11
# Ba2B2O5
# Ba2BiSbO6
# Ba2CaI6
# P-31m -> P-4b2 (325.36K, 25.64 J/kgK)
# P2_1/c -> P4_2/mnm (397.81K, 21.67 J/kgK)
# Ba2CaV2(Si2O7)2
# Ba2CaWO6
# Fm-3m -> Pn-3 (386.23K, 6.68 J/kgK)
# I4/m -> Pn-3 (510.66K, 8.71 J/kgK)
# Ba2CeHfO6
# Ba2CeSnO6
# Fm-3m -> Pn-3 (562.13K, 23.96 J/kgK)
# Ba2CeZrO6
# Ba2CoSi2O7
# P-42_1m -> C2/c (431.50K, 5.43 J/kgK)
# Ba2CrO4
# Ba2DyBiO6
# Ba2DyNbO6
# Ba2DySbO6
# Fm-3m -> Pn-3 (499.59K, 12.22 J/kgK)
# Ba2ErMgSbO6
# Ba2Fe2O5
# Ba2FeMoO6
# Ba2GdBiO6
# Ba2GdSbO6
# Ba2GdTaO6
# Ba2GeO4
# Ba2HoMgSbO6
# Ba2HoTaO6
# Ba2In2O5
# Ba2La2MgTi3O12
# Ba2LaBiO6
# Ba2LaCl7
# Ba2LaI7
# Ba2LaMgBiO6
# Ba2LaMgSbO6
# Ba2LaNbO6
# Ba2LaSbO6
# Ba2LaTaO6
# P2_1/c -> C2/m (324.26K, 11.97 J/kgK)
# Ba2LaVO6
# Ba2Li(NiO2)2
# Ba2LiMn2O6
# Ba2LiTbSnO6
# Ba2LiV2(Si2O7)2
# Ba2LiY2(Fe2O5)2
# Ba2LuBiO6
# Ba2LuMgSbO6
# Ba2Mg(BiO3)2
# Ba2Mg(CoO3)2
# Ba2Mg(NiO3)2
# Ba2MgCoMoO6
# Ba2MgCoWO6
# Ba2MgCrMoO6
# Ba2MgFeMoO6
# Ba2MgFeWO6
# Ba2MgMn2O6
# Ba2MgMnWO6
# Ba2MgMo4(P2O7)4
# Ba2MgMo4(Se2O11)2
# Ba2MgNiMoO6
# Ba2MgNiWO6
# Ba2MgSi2O7
# Ba2MgV2(Si2O7)2
# Ba2MgVMoO6
# Ba2MgZnWO6
# Ba2MnNbO6
# Ba2MnO3
# Ba2NF
# Ba2Na2O3
# Ba2NaNb5O15
# P4bm -> Ama2 (397.25K, 45.14 J/kgK)
# Ba2NaSr2(SbO4)3
# Ba2NbFeO6
# P6_3/mmc -> P-3m1 (395.10K, 16.82 J/kgK)
# Ba2Nd2Mg(Fe2O5)2
# Ba2NdBiO6
# Ba2NdMgBiO6
# Ba2NdMgSbO6
# Ba2NdNbO6
# Ba2NdSbO6
# Ba2NdTaO6
# Ba2NdVO6
# Ba2P2O7
# Ba2P6O17
# Ba2PrBiO6
# Ba2PrMgSbO6
# Ba2PrNbO6
# Ba2PrSbO6
# Ba2PrTaO6
# Ba2PrVO6
# Ba2Si3O8
# Ba2SmBiO6
# Ba2SmNbO6
# Ba2SmSbO6
# Fm-3m -> Pn-3 (401.32K, 12.38 J/kgK)
# Ba2SmVO6
# Ba2SnS4
# Ba2SnSe5
# Ba2SnWO6
# Ba2Sr3CaMg2(SiO4)4
# Ba2Sr3Nb10O30
# Ba2SrCrO6
# Ba2SrI6
# P-31m -> C2/c (500.03K, 55.06 J/kgK)
# P2_1/c -> P-4b2 (541.17K, 20.87 J/kgK)
# Ba2SrMgWO6
# Ba2SrUO6
# Ba2SrWO6
# Ba2Ta2O7
# Ba2TaBiO6
# Ba2TaMnO6
# Ba2TbBiO6
# Ba2TbMgBiO6
# Ba2TbMgSbO6
# Ba2TbNbO6
# Ba2TbTaO6
# Ba2TbWO6
# C2/m -> Pn-3 (587.02K, 30.36 J/kgK)
# Ba2Ti5(Bi2O9)2
# Ba2Ti6N2O11
# Ba2TiO4
# Ba2U(PO5)2
# Ba2VBiO6
# Ba2VFeO6
# Ba2Y2Mg(Fe2O5)2
# Ba2Y5Cl19
# Ba2YBiO6
# Ba2YBr7
# Ba2YCl7
# Ba2YCr3O7
# Cm -> Cm (388.38K, 7.58 J/kgK)
# Ba2YF7
# Pnma -> C2/c (396.32K, 45.97 J/kgK)
# Ba2YI7
# Ba2YMgBiO6
# Ba2YMgSbO6
# Ba2YNbO6
# Ba2YSbO6
# Fm-3m -> Pn-3 (429.69K, 16.75 J/kgK)
# Ba2YTaO6
# Ba3(BO3)2
# Ba3(BrO)2
# Ba3(ClO)2
# Ba3(InN2)2
# Ba3(PS4)2
# Ba3(YI6)2
# Ba3AlF9
# Ba3Cr2O8
# Ba3GeO5
# I4/mcm -> P4/ncc (531.82K, 23.09 J/kgK)
# Ba3In2WO9
# Ba3La2Cl12
# Ba3LaCl9
# Ba3LiTi5(SbO7)3
# Ba3LiTi5Nb3O21
# Ba3MgMn3O9
# P1 -> Cm (467.50K, 15.58 J/kgK)
# Ba3MgV2O8
# Ba3MoN4
# Ba3P4O13
# Ba3SrNb2O9
# Ba3SrTa2O9
# Ba3Ta4TiO15
# Pc -> P4/mbm (429.91K, 7.74 J/kgK)
# Ba3TiNb4O15
# Ba3UIn2O9
# Ba3WN4
# Ba3WO6
# Ba3Y2Br12
# Ba3Y2Cl12
# Ba3Y2F12
# Ba3Y2N4
# Ba3Y2O6
# Ba3Y4O9
# Ba3YI9
# Ba4Br6O
# Ba4CaZr5O15
# P4/mmm -> Cmmm (588.61K, 57.01 J/kgK)
# P4/mmm -> P4/m (485.60K, 51.92 J/kgK)
# Ba4LiNb3O12
# Ba4Lu6O13
# Ba4Nb2O9
# Ba4OF6
# Ba4Sr(SnO3)5
# Ba4Ta2O9
# Ba4Ta2TiZnO12
# Ba4Ti11O26
# Ba4Ti3O10
# Ba4Zn4B14Pb2O31
# Cc -> P3_2 (302.05K, 7.50 J/kgK)
# Ba5Ce4ZrO15
# P-1 -> C2/m (517.42K, 31.57 J/kgK)
# Ba5P3O12F
# P6_3/m -> P6_3 (475.07K, 1.07 J/kgK)
# Ba5P4
# Ba5V5O14
# Ba5Y3F19
# Ba6Br2N3Cl
# Ba6Dy2Al4O15
# Ba6Nd2Al4O15
# Ba6Ti2Nb10Si8O51
# Ba6YBr15
# Ba6YI15
# Ba8Bi4O17
# Ba8CaY2U4O24
# Cmmm -> I4/mmm (521.34K, 1.30 J/kgK)
# Ba8In6O17
# BaAl2(SiO4)2
# P2_1/c -> P-3m1 (500.39K, 54.20 J/kgK)
# BaAl2O4
# BaAl2O6
# BaAl4O7
# BaAlBO3F2
# BaAlF5
# P2_1 -> P1 (393.89K, 28.75 J/kgK)
# P2_12_12_1 -> P2_1/c (589.24K, 50.08 J/kgK)
# BaAlSi5N7O2
# BaAsHO4
# BaB2F8
# BaB4O7
# BaBPO5
# P3_221 -> P3_121 (436.74K, 0.30 J/kgK)
# BaBe2(BO3)2
# BaBe2Si2O7
# BaBi4O7
# BaBiBrO2
# BaBiClO2
# BaBrCl
# BaC2
# BaCN2
# BaCO3
# Pnn2 -> R-3c (590.24K, 31.59 J/kgK)
# R32 -> R-3c (444.16K, 20.37 J/kgK)
# BaCa(CO3)2
# BaCa2I6
# Pc -> P4_2/mnm (436.26K, 8.27 J/kgK)
# Pc -> Pbcn (357.06K, 14.77 J/kgK)
# BaCa2Mg(SiO4)2
# BaCaBiSbO6
# BaCaCeHfO6
# BaCaCeSnO6
# BaCaCeZrO6
# BaCaCrF7
# BaCaDyBiO6
# BaCaEuWO6
# BaCaGdBiO6
# BaCaGdNbO6
# BaCaGdSbO6
# P-1 -> Pnnn (487.65K, 60.28 J/kgK)
# BaCaI4
# C2/c -> I4_1/a (505.34K, 46.92 J/kgK)
# Cmc2_1 -> Pnna (475.64K, 41.67 J/kgK)
# Pbcm -> I4_1/a (519.31K, 44.77 J/kgK)
# Pbcn -> I4_1/a (599.02K, 60.43 J/kgK)
# Imma -> Pnma (531.58K, 25.89 J/kgK)
# Pbcn -> P2_1/c (589.27K, 23.29 J/kgK)
# BaCaInBiO6
# P-1 -> Pnnn (497.49K, 28.47 J/kgK)
# BaCaLaBiO6
# BaCaLaSbO6
# BaCaMg14O16
# BaCaNdBiO6
# BaCaNdNbO6
# BaCaNdSbO6
# BaCaO2
# BaCaPrBiO6
# BaCaPrSbO6
# BaCaSmBiO6
# BaCaSmNbO6
# BaCaSmSbO6
# BaCaSnWO6
# BaCaTbBiO6
# BaCaZr2O6
# BaCeO3
# Imma -> R-3c (547.42K, 20.59 J/kgK)
# BaCl2
# Fm-3m -> P-62m (395.85K, 99.14 J/kgK)
# Fm-3m -> Pnma (340.09K, 52.87 J/kgK)
# Pnma -> P-62m (473.13K, 44.94 J/kgK)
# BaCl2O11
# BaCo2(PO4)2
# BaCrO4
# BaCu(SiO3)2
# BaDy2CoO5
# BaDyNbSnO6
# P222 -> P-1 (405.66K, 24.78 J/kgK)
# BaDySnSbO6
# BaEr2CoO5
# BaF2
# Fm-3m -> Pnma (563.88K, 126.62 J/kgK)
# BaFe(Si2O5)2
# BaFe12O19
# BaFe2(P2O7)2
# BaFe2(PO4)2
# BaFeF5
# BaGa2(GeO4)2
# BaGaB4H3O10
# BaGaH5
# P2_1 -> P2_1 (554.21K, 26.88 J/kgK)
# BaGdInWO6
# F-43m -> Pnnn (360.27K, 61.74 J/kgK)
# BaGdNbSnO6
# BaGe2O5
# BaGe4O9
# BaGeO3
# BaH2
# BaH2N2O5
# BaH2S5O6
# BaH4O3
# P2_1 -> P1 (459.00K, 65.10 J/kgK)
# Pmc2_1 -> P2_1/m (424.99K, 161.73 J/kgK)
# BaHfS3
# BaHgO2
# BaHo2O4
# BaI2
# BaLa2Br8
# BaLa2Cl8
# BaLa2O4
# BaLa2Ti3O10
# BaLa2WO7
# Pc -> P2_1/c (459.71K, 20.72 J/kgK)
# BaLa3TiCr3O12
# BaLa4Ti4O15
# BaLa4TiCr4O15
# BaLa7Mg5Nb3O24
# BaLaBr5
# BaLaCl5
# C2/c -> P-1 (558.01K, 39.90 J/kgK)
# BaLaI5
# C2/c -> P1 (395.35K, 1.59 J/kgK)
# BaLaTiCrO6
# BaLi(B3O5)3
# BaLi2NiO3
# BaLi4O3
# BaLiAl3P2(HO7)2
# BaLiP
# BaLiV2Ni3(HO5)2
# BaLu2O4
# BaLuCo4O7
# BaMg(CO3)2
# R-3c -> R-3m (429.29K, 45.47 J/kgK)
# BaMg(FeO2)4
# BaMg14CdO16
# BaMg14FeO16
# BaMg14MnO16
# BaMg14NiO16
# BaMg14ZnO16
# BaMg2N2
# BaMgF4
# BaMgTiO3
# BaMnO3
# P3m1 -> P6_3cm (476.88K, 45.76 J/kgK)
# P3m1 -> P6_3mc (541.73K, 46.57 J/kgK)
# P3m1 -> R-3m (538.91K, 3.65 J/kgK)
# R-3m -> P6_3cm (471.84K, 42.08 J/kgK)
# R-3m -> P6_3mc (541.97K, 42.92 J/kgK)
# BaMnP2O7
# BaMo(PO4)2
# BaMo3O10
# BaNa2Al4(SiO4)4
# BaNa2Mg(PO4)2
# BaNa2O2
# BaNa3PCO7
# BaNa6O4
# BaNaBiWO6
# BaNaCeBiO6
# BaNaCeNbO6
# BaNaCeSbO6
# BaNaGdWO6
# Pnnn -> F-43m (594.02K, 25.84 J/kgK)
# BaNaLaWO6
# BaNaN
# BaNaNdWO6
# BaNaPO4
# BaNaPrWO6
# BaNaSmWO6
# Pnnn -> F-43m (538.36K, 75.97 J/kgK)
# BaNaZrBiO6
# BaNb2Fe2(PO4)6
# BaNb2O6
# BaNd2Ti3O10
# BaNiO3
# BaO
# BaO2
# BaP2(HO2)4
# BaP3
# BaP4O11
# BaPHO4
# BaPb2(SO4)3
# BaPrInWO6
# BaS3
# BaSO4
# BaSe
# BaSi2O5
# BaSiO3
# BaSn2S3
# BaSnF4
# BaSnHgS4
# BaSr(FeO2)4
# BaSr(SnO3)2
# BaSr2I6
# C2/c -> P1 (544.26K, 16.37 J/kgK)
# C2/c -> P4_2/mnm (487.02K, 36.93 J/kgK)
# C2/c -> Pbcn (530.27K, 31.11 J/kgK)
# P2_1/c -> Cmce (385.79K, 16.99 J/kgK)
# P1 -> P4_2/mnm (445.41K, 20.38 J/kgK)
# P1 -> Pbcn (515.14K, 14.74 J/kgK)
# BaSr4Cl10
# BaSrBiSbO6
# P-1 -> P222 (474.41K, 31.06 J/kgK)
# BaSrCaWO6
# BaSrCe2O6
# BaSrCeHfO6
# BaSrCeSnO6
# BaSrCeTiO6
# P-1 -> P222 (548.81K, 22.77 J/kgK)
# BaSrCeWO6
# P-1 -> P222 (528.69K, 45.70 J/kgK)
# BaSrCeZrO6
# BaSrDyBiO6
# BaSrDyNbO6
# BaSrDySbO6
# BaSrDyWO6
# P222 -> P-1 (325.07K, 10.97 J/kgK)
# BaSrGdBiO6
# BaSrGdNbO6
# BaSrHfZrO6
# BaSrI4
# Cmc2_1 -> P2_1/c (569.10K, 16.94 J/kgK)
# P4/mmm -> Pna2_1 (321.94K, 24.62 J/kgK)
# Pnma -> Pna2_1 (405.59K, 18.81 J/kgK)
# R-3m -> Pna2_1 (436.52K, 30.52 J/kgK)
# R-3m -> Pnma (491.75K, 11.58 J/kgK)
# BaSrLaBiO6
# BaSrLaNbO6
# BaSrLaSbO6
# BaSrLaVO6
# BaSrLaWO6
# BaSrMg14O16
# BaSrNbBiO6
# BaSrNbSbO6
# BaSrNdBiO6
# BaSrNdNbO6
# BaSrNdSbO6
# BaSrNdVO6
# BaSrNdWO6
# BaSrO2
# BaSrPrBiO6
# BaSrPrNbO6
# BaSrPrSbO6
# BaSrPrVO6
# BaSrPrWO6
# BaSrSmBiO6
# BaSrSmNbO6
# BaSrSmSbO6
# BaSrSmWO6
# BaSrTbBiO6
# BaSrTbNbO6
# BaSrTbSbO6
# P-1 -> P222 (413.76K, 19.91 J/kgK)
# BaSrTbWO6
# BaSrYBiO6
# BaSrYNbO6
# BaSrYSbO6
# BaSrYWO6
# BaSrZr2O6
# BaTa2O6
# BaTaF7
# BaTbInWO6
# F-43m -> Pnnn (344.72K, 53.00 J/kgK)
# BaTbNbSnO6
# BaTe
# BaTeMo2O9
# P2_1 -> Pca2_1 (443.57K, 46.11 J/kgK)
# BaTeO3
# BaTeO4
# BaTi(SiO3)3
# BaTi2O5
# BaTiO3
# Amm2 -> C222_1 (524.81K, 64.08 J/kgK)
# Amm2 -> P6_3/mmc (558.15K, 84.99 J/kgK)
# Amm2 -> R3m (517.10K, 50.03 J/kgK)
# R3m -> C222_1 (553.20K, 14.03 J/kgK)
# BaV2(P2O7)2
# BaV2ZnO7
# BaVOF4
# BaVSi2O7
# BaWN3
# BaWO4
# BaY2F8
# BaY3Cl11
# BaY3F11
# BaYBr5
# BaYCl5
# C2/c -> P2_1/c (597.28K, 117.85 J/kgK)
# BaYF5
# C2/c -> P2_1 (392.49K, 67.42 J/kgK)
# P4/mmm -> P2_1 (522.55K, 147.77 J/kgK)
# Pmma -> P2_1 (520.66K, 104.65 J/kgK)
# P4/mmm -> P2_12_12_1 (434.19K, 97.76 J/kgK)
# Pmma -> P2_12_12_1 (383.56K, 63.51 J/kgK)
# P4/mmm -> Pmma (527.12K, 43.76 J/kgK)
# BaYI5
# BaYInWO6
# BaYNbSnO6
# BaYSnSbO6
# BaZn2Si2O7
# BaZnCl4
# Pnna -> Pbcn (431.83K, 41.73 J/kgK)
# BaZnF4
# BaZr(PO4)2
# BaZr2SnO6
# BaZrF6
# BaZrO3
# Be(GaO2)2
# Be(HO)2
# Be(PO3)2
# Be2BH3O5
# P1 -> Cc (519.17K, 136.81 J/kgK)
# Be2P2O7
# Be2SiO4
# Be3Fe4Si3TeO12
# Be3N2
# Be4N6O19
# BeAlH5
# C2/c -> P2_1 (306.57K, 657.58 J/kgK)
# BeC2
# BeCN2
# BeCl2
# I4_1/acd -> Ibam (354.40K, 265.06 J/kgK)
# BeCrO4
# BeF2
# C2 -> I-43m (484.94K, 101.21 J/kgK)
# I-43m -> P6_222 (585.48K, 115.76 J/kgK)
# P1 -> P2_1 (421.22K, 1.83 J/kgK)
# C2 -> P6_222 (536.21K, 217.94 J/kgK)
# BeH4NF3
# BeH8(NF2)2
# BeI2
# P-1 -> Ibam (511.60K, 65.44 J/kgK)
# BeNF3
# BeO
# Warning: 2 transitions within this interval
# F-43m -> P4_2/mnm (479.75K, 124.90 J/kgK)
# P6_3mc -> P4_2/mnm (450.96K, 308.39 J/kgK)
# BeSiN2
# BeTe
# Bi(BO2)3
# P2_1/c -> P1 (581.06K, 57.17 J/kgK)
# P2_1/c -> P1 (489.47K, 76.88 J/kgK)
# Bi(W2Cl5)3
# C2/c -> P2_1/c (549.93K, 9.78 J/kgK)
# Bi14SO24
# Bi2(CN2)3
# Bi2(PSe3)3
# Bi2(PbS2)3
# Bi2(SO4)3
# Bi26Mo10O69
# Bi2B8O15
# Warning: 2 transitions within this interval
# P2_1 -> P-1 (402.54K, 3.49 J/kgK)
# Bi2CO5
# Bi2MoO6
# Pbca -> Cmce (389.10K, 16.82 J/kgK)
# Bi2O3
# Fd-3m -> P-3m1 (477.50K, 72.70 J/kgK)
# P-42_1c -> R-3c (377.99K, 75.74 J/kgK)
# P2_1/c -> Pccn (403.11K, 22.69 J/kgK)
# P2_1/c -> R-3c (453.37K, 102.55 J/kgK)
# Pa-3 -> P31c (595.12K, 62.74 J/kgK)
# Pbcn -> P31c (482.56K, 73.92 J/kgK)
# R3 -> P31c (325.65K, 54.85 J/kgK)
# Pa-3 -> R-3c (352.00K, 81.94 J/kgK)
# Pbcn -> R-3c (319.32K, 96.56 J/kgK)
# Pccn -> R-3c (468.83K, 79.66 J/kgK)
# Bi2Se3
# Bi2Te7Cl8
# Bi2W2O9
# Bi2WO6
# Bi3BrO4
# Bi3O2F5
# Bi3O4F
# Cmcm -> C2/m (584.91K, 57.92 J/kgK)
# Bi4O5F2
# Bi4S3N2
# Bi5IO7
# C2/c -> C2/m (378.47K, 11.60 J/kgK)
# Bi5O7F
# C2/m -> P-1 (451.25K, 6.48 J/kgK)
# Bi6O5F8
# Bi7(O2F3)3
# BiAsO4
# BiBPbO4
# BiBr3
# BiF3
# BiF5
# P2_1/c -> P1 (367.11K, 58.99 J/kgK)
# BiI3
# BiN
# BiO2
# BiOF
# P2_1/m -> Fdd2 (429.27K, 74.01 J/kgK)
# P2_1/m -> Fddd (438.45K, 73.71 J/kgK)
# P2_1 -> P2_1/c (372.41K, 119.48 J/kgK)
# P2_1 -> Pnma (591.04K, 118.25 J/kgK)
# Pbca -> P2_1/c (510.58K, 70.68 J/kgK)
# BiPO4
# P2_1 -> P2_1/m (421.52K, 11.34 J/kgK)
# BiSeClO3
# BiTeO4
# Cc -> C2 (308.01K, 26.62 J/kgK)
# BrCl
# Cmc2_1 -> Cmcm (339.52K, 36.65 J/kgK)
# C
# Pnma -> Cmmm (341.79K, 533.76 J/kgK)
# Fd-3m -> P6_3/mmc (591.56K, 3441.18 J/kgK)
# Fd-3m -> R-3m (555.25K, 211.75 J/kgK)
# Pa-3 -> Fm-3 (568.77K, 1118.35 J/kgK)
# Pnnm -> Fm-3 (592.04K, 980.39 J/kgK)
# R-3m -> P6_3/mmc (594.46K, 3190.57 J/kgK)
# Pa-3 -> Pnnm (470.69K, 194.71 J/kgK)
# C(ClF)2
# C(NO)2
# C18BrF13
# C2N2O5
# P1 -> P2_12_12 (466.48K, 8.05 J/kgK)
# C2SF6
# C2SNOF
# C2SeN2
# C3F5
# C3N2
# C3N4
# I-43d -> P-43m (371.44K, 821.32 J/kgK)
# P3_1 -> R3m (307.85K, 680.42 J/kgK)
# C4SBr4
# CBrN
# CCl3
# CF
# CN2
# CNCl
# CO
# CO2
# Pa-3 -> Cmce (457.99K, 209.09 J/kgK)
# Cmce -> R-3c (572.28K, 220.48 J/kgK)
# P4_12_12 -> Pbcn (335.09K, 390.46 J/kgK)
# P4_12_12 -> Pna2_1 (381.12K, 320.46 J/kgK)
# P4_12_12 -> R-3c (310.54K, 409.09 J/kgK)
# Pa-3 -> P4_2/mnm (384.45K, 166.55 J/kgK)
# Pa-3 -> Pbcn (594.77K, 330.43 J/kgK)
# Pa-3 -> R-3c (511.95K, 410.48 J/kgK)
# CS2N2O
# CSN2
# CSO
# Warning: 2 transitions within this interval
# Cm -> R3m (347.30K, 55.98 J/kgK)
# Ca(AgO2)2
# Ca(AlH4)2
# Ca(BH4)2
# P4_2 -> I-42d (546.31K, 313.43 J/kgK)
# Pbca -> I-42d (487.82K, 562.70 J/kgK)
# Pbca -> P-4 (325.85K, 203.17 J/kgK)
# Pbca -> P4_2 (422.05K, 244.69 J/kgK)
# Ca(BO2)2
# Ca(BiO2)2
# Fd-3m -> Cmcm (440.16K, 100.31 J/kgK)
# P3m1 -> Cmcm (547.18K, 101.53 J/kgK)
# Fd-3m -> Pbcm (395.54K, 85.26 J/kgK)
# P3m1 -> Pbcm (510.42K, 88.41 J/kgK)
# Ca(ClO3)2
# Ca(CoO2)2
# Ca(CoS2)2
# Ca(CrS2)2
# Fd-3m -> I4_1/amd (460.48K, 18.70 J/kgK)
# Ca(CuO2)2
# Ca(ErS2)2
# Ca(Fe2O3)4
# Ca(FeO2)2
# Ca(GaO2)2
# Pna2_1 -> P2_1/c (546.35K, 46.73 J/kgK)
# Ca(GaS2)2
# Ca(H8O5)2
# Ca(HO)2
# P-3m1 -> C2 (529.60K, 299.95 J/kgK)
# Ca(HoS2)2
# Ca(MoO2)2
# Ca(NiO2)2
# I4_1/a -> C2 (385.15K, 106.89 J/kgK)
# P1 -> C2 (449.62K, 123.62 J/kgK)
# Ca(PO3)2
# Ca(SO5)2
# Ca(SbO2)2
# I-4 -> C2/m (493.57K, 21.48 J/kgK)
# Ca(SbO3)2
# Ca(SiO2)6
# Ca(SnO2)2
# Ca(WO2)2
# Ca10P6O25
# Ca10P6SO24
# Ca10Si3S3(ClO12)2
# Ca10V6O25
# Ca12Al14O33
# Ca2Al2Si(HO4)2
# Ca2Al2SiO7
# Ca2AlBiO5
# Ca2AlFeO5
# Ca2AlH10ClO8
# Ca2AsH4F13
# P4_122 -> P4_322 (500.87K, 18.08 J/kgK)
# Ca2B2O5
# Ca2B5H2ClO10
# Ca2Bi10O17
# Ca2Bi2O5
# Ca2BiSbO6
# Ca2BiWO6
# Ca2CdAs2
# Ca2CeO4
# Ca2CoO3
# Ca2CoSi2O7
# Ca2Cr2O5
# Ca2CrSbO6
# Ca2CrWO6
# Ca2Fe2O5
# Ca2FeSbO6
# Ca2FeWO6
# Ca2Ga2Si(HO4)2
# Ca2GeO4
# Ca2H2S2O9
# Ca2La2MgTi3O12
# Ca2LaSbO6
# Ca2MgAl2(SiO4)3
# Ca2MgFe(CO3)4
# Ca2MgSi2O7
# Ca2Mn3O8
# Ca2Mn7Si10H12O35
# Ca2MnSbO6
# Ca2MnWO6
# Ca2MoWO6
# Ca2NF
# Ca2Nb2O7
# P2_1 -> Pna2_1 (407.37K, 30.42 J/kgK)
# Ca2NbInO6
# Ca2Nd2Nb3FeO14
# Ca2NiWO6
# Ca2P2O7
# Warning: 2 transitions within this interval
# P2_1/c -> P4_1 (332.54K, 42.58 J/kgK)
# Ca2PI
# Ca2S2O9
# P3_2 -> P3_1 (329.51K, 104.61 J/kgK)
# P3_2 -> P3_121 (407.59K, 70.79 J/kgK)
# Ca2SbWO6
# Ca2Si5N8
# Cc -> Pbca (529.52K, 70.80 J/kgK)
# Ca2SiO4
# Ca2Sn3O8
# Ca2Sn3S8
# Ca2SnS4
# P4_122 -> Pna2_1 (534.44K, 73.06 J/kgK)
# Ca2SnWO6
# Ca2Ta2O7
# Ca2TaCrO6
# Ca2TaWO6
# Ca2Ti3O8
# Ca2Ti6N2O11
# Ca2TiAlSi2O9F
# Ca2TiMnO6
# Ca2V3O8
# Ca2VBiO6
# Ca2VWO6
# Ca2WO5
# Ca2YBiO6
# Ca2ZnAs2(H2O5)2
# Ca2Zr5Ti2O16
# Ca3(AlN2)2
# Ca3(BN2)2
# Pnnm -> Cmce (359.17K, 72.04 J/kgK)
# Ca3(CoO3)2
# Ca3(InN2)2
# Ca3(PO4)2
# Ca3Al4CoO10
# Ca3AsN
# Ca3Be2P4(HO2)10
# Ca3CdO4
# Cmmm -> P4/mmm (305.34K, 37.32 J/kgK)
# Ca3Co2(Si2O7)2
# Ca3Er3Ge2BO13
# Ca3Fe2(WO6)2
# Ca3Ga2(SnO4)3
# Ca3MnO4
# C2/m -> Cmmm (388.28K, 85.70 J/kgK)
# Ca3N2
# Ca3Nb4(O6F)2
# Ca3Si2O7
# Ca3SiO5
# Ca3Sn2S7
# P2_1/c -> Cmc2_1 (559.91K, 39.48 J/kgK)
# Ca3SnS5
# Ca3Ta2O8
# Ca3Ta4(O6F)2
# Ca3UN4
# Ca3UO6
# P2_1/c -> P2_1 (518.85K, 16.15 J/kgK)
# Ca3V2O8
# Ca3W2O9
# Ca3WO6
# Ca3Y2N4
# Ca3Zn3(TeO6)2
# Ca4Al6MoO16
# Ca4Al6O13
# Ca4Al6SO16
# Ca4Al6WO16
# Ca4Bi6O13
# Pm -> Cm (339.80K, 9.01 J/kgK)
# Ca4Nb2O9
# Ca4Sn3S10
# Ca4SnS6
# Ca4Ta2O9
# Ca5(SiN3)2
# C2/m -> C2/c (314.47K, 43.86 J/kgK)
# Ca5BC4Cl3
# Ca5P3ClO12
# P6_3 -> P6_3/m (475.92K, 5.91 J/kgK)
# Ca5P3HO13
# Ca5P3O12F
# Ca5Ta4O15
# CaAl12O19
# CaAl2(SiO4)2
# CaAl2H4Pb2(O2F3)2
# CaAl2O4
# CaAl2Si2(H2O5)2
# Cmcm -> Pna2_1 (416.68K, 240.60 J/kgK)
# Cmcm -> Pnma (518.10K, 159.17 J/kgK)
# CaAl2Si3O10
# CaAl2SiO6
# P2/c -> C2 (422.33K, 29.11 J/kgK)
# Cc -> P2_1/c (407.66K, 52.82 J/kgK)
# CaAlF5
# CaAlH5
# CaAs3F15
# CaB2(H2O3)2
# CaB3H5O8
# CaB4O7
# CaBHO3
# CaBiCO4F
# CaBiF5
# CaBiMoO5
# CaBiSbO5
# CaBiWO5
# CaBr2
# CaC2
# Pnnm -> C2/c (392.65K, 90.67 J/kgK)
# CaC2O5
# CaCO3
# R-3c -> P6_522 (427.13K, 83.54 J/kgK)
# CaCd(NO3)4
# CaCl2
# CaCo(GeO3)2
# CaCo(SiO3)2
# CaCo6(OF5)2
# CaCoP2O7
# CaCr(GeO3)2
# CaCr2O4
# CaCr2O5
# CaCrBiO5
# CaCrF5
# CaCrO2
# CaCrP2O7
# CaF2
# Fm-3m -> Pnma (345.52K, 309.51 J/kgK)
# CaFe(GeO3)2
# P1 -> P-1 (522.23K, 37.21 J/kgK)
# CaFe(SiO3)2
# CaFe3Si2HO9
# CaFeF5
# CaFeO2
# CaFeP2O7
# CaGa4(WO6)2
# CaGaBiB2O7
# CaGd2O4
# Pnma -> Cmcm (434.96K, 28.09 J/kgK)
# CaGe2O5
# CaGe2WO6
# CaGeO3
# CaH2
# CaH2(CO2)2
# P4_32_12 -> P4_12_12 (496.92K, 23.30 J/kgK)
# Pbca -> P4_12_12 (489.88K, 119.38 J/kgK)
# Pbca -> P4_32_12 (488.24K, 99.00 J/kgK)
# CaH2C2O5
# CaH8(ClO2)2
# P2_1/c -> P-1 (330.86K, 388.46 J/kgK)
# CaHfO3
# CaLa2Fe2(TeO6)2
# CaLa2FeO6
# CaLa4Ni3WO12
# CaLaAl3O7
# CaLaCrSbO6
# CaLaCrSnO6
# CaLaFeO4
# CaLaFeSbO6
# P1 -> P1 (518.42K, 30.46 J/kgK)
# CaLaGaO4
# CaLaI5
# CaLaVFeO6
# CaMg(SiO3)2
# CaMg14CO16
# CaMg14CdO16
# CaMg14CoO16
# CaMg14MnO16
# CaMg14NiO16
# Pmmm -> P4/mmm (518.80K, 27.46 J/kgK)
# CaMg14VO16
# CaMg14ZnO16
# CaMg2(SO4)3
# CaMgAsO4F
# C2/c -> Cc (509.09K, 6.54 J/kgK)
# CaMgB2O5
# CaMn(GeO3)2
# CaMn(SiO3)2
# CaMn2O4
# I4_1/a -> P-1 (533.48K, 77.51 J/kgK)
# P1 -> P2_1/c (534.38K, 63.02 J/kgK)
# CaMn3O4
# CaMn9CdO10
# CaMnBiO5
# CaMnF5
# C2/c -> P2_1/c (599.04K, 81.89 J/kgK)
# CaMnO2
# CaMnP2O7
# CaMo2O5
# CaMoF5
# CaMoO3
# Pnma -> P-1 (512.60K, 57.31 J/kgK)
# CaMoO4
# CaN6
# CaNdCoO4
# CaNdCrO4
# CaNdGa3O7
# CaNi(GeO3)2
# CaNiF4
# CaNiO2
# CaNiP2O7
# CaO
# I4/mmm -> Cmce (454.64K, 42.98 J/kgK)
# CaP4(Br3O)4
# CaP4O11
# Cmce -> P2_1/c (491.99K, 75.97 J/kgK)
# CaPHO4
# CaPbI4
# Pmn2_1 -> C2/m (445.83K, 32.69 J/kgK)
# Pmn2_1 -> P2/m (466.72K, 35.84 J/kgK)
# CaSO4
# CaSO6
# CaSbF5
# CaSe
# CaSeO3
# CaSeO4
# I4_1/a -> P2_1/c (326.04K, 118.95 J/kgK)
# CaSi2NiO6
# CaSi2SnO6
# CaSi2WO6
# CaSiN2
# CaSiO3
# Imma -> I4/mcm (501.06K, 51.61 J/kgK)
# CaSiSnO5
# CaSm4(Mo2O7)2
# CaSn(GeO3)2
# CaSn2O5
# CaSn2S5
# CaSn4S9
# CaSnF6
# CaSnO2
# CaSnO3
# CaSnP2O7
# CaSnS3
# P-1 -> P2_1/c (373.05K, 7.18 J/kgK)
# CaTa2Bi2O9
# CaTa2O6
# CaTaAlO5
# CaTaBiO5
# CaTaNO2
# CaTb2O4
# CaTe
# CaTeO3
# Warning: 2 transitions within this interval
# P-1 -> P2_1 (354.24K, 43.72 J/kgK)
# P2_1/c -> P-1 (514.13K, 76.36 J/kgK)
# P2_1/c -> P1 (418.16K, 22.56 J/kgK)
# P2_1/c -> P2_1 (462.51K, 56.76 J/kgK)
# CaTeO4
# CaTi(GeO3)2
# CaTi2O5
# CaTi2PbO6
# CaTiF6
# CaTiFe5O8
# CaTiGeO5
# CaTiO3
# Cmcm -> I4/mcm (410.44K, 125.43 J/kgK)
# Pnma -> I4/mcm (544.15K, 183.46 J/kgK)
# Pnma -> Imma (376.02K, 110.85 J/kgK)
# CaTiSiO5
# CaUO4
# CaV(SiO3)2
# CaV2(PO5)2
# CaV2O4
# CaV2O6
# CaV5O7
# CaV6O11F
# CaVBiO5
# CaVP2O7
# CaW2O5
# CaWF5
# CaWO4
# C2/c -> C2/c (326.81K, 64.75 J/kgK)
# CaY2O4
# CaY4(BiO3)4
# CaYAl3O7
# CaZn2(PO5)2
# CaZnF2
# Fd-3m -> I4_1/amd (512.47K, 75.73 J/kgK)
# CaZr4O9
# CaZrAl9BO18
# CaZrNbFeO7
# CaZrO3
# Cd(BO2)2
# Cd(C2N3)2
# Cd(C4N3)2
# Warning: 2 transitions within this interval
# Pmna -> Cm (411.13K, 101.98 J/kgK)
# Cd(CN)2
# Cd(CoO2)2
# Cd(FeO2)2
# Cd(GaO2)2
# Cd(HO)2
# Cd(IO3)2
# Cd(InSe2)2
# I-4 -> P-42m (375.80K, 8.38 J/kgK)
# Cd(PO3)2
# Cd2H2SO6
# Cd2P3Cl
# Cd2SiO4
# Cd3(BO3)2
# Cd3(PO4)2
# Cd4SF6
# Cd5(S2Cl)2
# Cd7P10
# CdAg2GeS4
# CdBr2
# CdCl2
# CdF2
# CdGe(BiO3)2
# Pbcn -> P2_1/c (520.93K, 18.00 J/kgK)
# CdGeN2
# CdGeO3
# CdH4(C2O3)2
# CdH8(NO5)2
# CdI2
# P-3m1 -> P6_3mc (488.07K, 13.42 J/kgK)
# R3m -> P3m1 (388.34K, 16.56 J/kgK)
# CdNCl3
# CdP2
# CdPS3
# C2/m -> R-3 (457.35K, 51.11 J/kgK)
# CdS
# Warning: 2 transitions within this interval
# P3m1 -> P3m1 (403.43K, 4.15 J/kgK)
# CdSO3
# CdSO4
# CdSe
# CdSeO3
# CdSeO4
# CdSiN2
# CdSiO3
# CdSnO3
# CdTe
# P6_3mc -> F-43m (446.93K, 19.47 J/kgK)
# Ce(WO4)2
# Ce2Dy2O7
# Ce2Nd2O7
# Ce2Y2O7
# Ce2ZrO6
# Immm -> I4/mmm (551.23K, 3.40 J/kgK)
# Ce3SnO8
# R-3m -> P4/mmm (472.19K, 70.92 J/kgK)
# Ce3ZrO8
# C2/c -> P-4m2 (512.79K, 53.05 J/kgK)
# Ce4SnO10
# Ce4ZrO10
# R-3m -> I4/mmm (485.09K, 11.34 J/kgK)
# CeH8(SO6)2
# CeHfO4
# P2_13 -> Pmn2_1 (520.30K, 15.02 J/kgK)
# CeO2
# CeSe2
# I2_13 -> C2 (580.59K, 6.04 J/kgK)
# C2 -> P1 (430.32K, 3.68 J/kgK)
# I2_12_12_1 -> C2/c (587.68K, 12.03 J/kgK)
# I4_1/amd -> C2/c (331.57K, 3.68 J/kgK)
# C2/c -> P4_2/mcm (516.64K, 0.52 J/kgK)
# C2/c -> Pna2_1 (319.04K, 3.44 J/kgK)
# Ia-3d -> C2/m (458.51K, 3.75 J/kgK)
# C2/m -> P2/c (506.22K, 4.49 J/kgK)
# C2/m -> Pccn (333.75K, 4.23 J/kgK)
# Ibam -> C222 (569.17K, 6.96 J/kgK)
# Fm-3m -> C222_1 (589.36K, 0.94 J/kgK)
# P3_121 -> Cc (358.71K, 9.11 J/kgK)
# Cmc2_1 -> P4_32_12 (577.73K, 3.31 J/kgK)
# I-4c2 -> Cmcm (428.58K, 2.30 J/kgK)
# P2_1/m -> Cmcm (581.67K, 7.24 J/kgK)
# Pnc2 -> Cmcm (447.32K, 15.01 J/kgK)
# Pcca -> Cmcm (441.52K, 11.64 J/kgK)
# Cmmm -> Immm (521.41K, 3.76 J/kgK)
# Cmmm -> P2/m (514.49K, 0.47 J/kgK)
# Cmmm -> P2_1/c (354.90K, 4.62 J/kgK)
# Cmmm -> Pccn (469.11K, 6.40 J/kgK)
# Fd-3 -> P23 (428.21K, 1.60 J/kgK)
# Fdd2 -> Cmcm (357.14K, 27.89 J/kgK)
# Ia-3d -> Fddd (552.17K, 6.43 J/kgK)
# P2_1/m -> Fddd (404.16K, 2.00 J/kgK)
# Pnc2 -> Fddd (356.61K, 9.30 J/kgK)
# Pcca -> Fddd (303.68K, 5.74 J/kgK)
# Fmmm -> Immm (488.56K, 3.04 J/kgK)
# Fmmm -> P2_1/c (311.41K, 3.75 J/kgK)
# Fmmm -> Pccn (446.93K, 5.66 J/kgK)
# I2_12_12_1 -> I-4 (461.23K, 12.03 J/kgK)
# P4_2/mmc -> I-42d (543.55K, 5.88 J/kgK)
# Cm -> I-42d (588.10K, 4.76 J/kgK)
# I-42m -> I4_122 (579.19K, 6.68 J/kgK)
# I-42m -> P2_1/c (539.53K, 8.95 J/kgK)
# I-42m -> Pbam (519.25K, 8.14 J/kgK)
# I-42m -> P4_32_12 (455.15K, 4.71 J/kgK)
# I-42m -> Pccn (599.89K, 10.32 J/kgK)
# I2_12_12_1 -> Ima2 (495.61K, 13.53 J/kgK)
# I2_12_12_1 -> P4_2/mcm (584.54K, 12.55 J/kgK)
# I2_12_12_1 -> Pm-3n (446.17K, 11.19 J/kgK)
# I2_12_12_1 -> Pna2_1 (511.23K, 15.97 J/kgK)
# I2_13 -> P-31c (391.45K, 9.28 J/kgK)
# I2_13 -> P1 (518.28K, 9.82 J/kgK)
# I2_13 -> R-3 (325.63K, 2.70 J/kgK)
# Pnc2 -> I-4c2 (450.81K, 12.71 J/kgK)
# Pcca -> I-4c2 (444.77K, 9.34 J/kgK)
# I4_1/acd -> P-31c (549.23K, 12.23 J/kgK)
# P3_121 -> I4_1/acd (496.10K, 7.90 J/kgK)
# I4_1/amd -> P4_2/mcm (350.67K, 4.24 J/kgK)
# I4_1/amd -> P4_2/nbc (384.06K, 1.83 J/kgK)
# I4_1/amd -> Pna2_1 (325.46K, 7.12 J/kgK)
# Imma -> I4_122 (506.53K, 3.40 J/kgK)
# I4_122 -> P2_1/c (435.63K, 2.20 J/kgK)
# P6_3/mcm -> I4_122 (554.07K, 4.47 J/kgK)
# Ia-3d -> Immm (380.55K, 5.49 J/kgK)
# Ia-3d -> P2/c (483.93K, 8.26 J/kgK)
# Ia-3d -> Pccn (387.47K, 8.08 J/kgK)
# Ibam -> P-31m (411.97K, 1.52 J/kgK)
# Ibam -> P2_12_12 (421.06K, 7.69 J/kgK)
# Imma -> P2_1/c (477.40K, 5.62 J/kgK)
# Imma -> Pbam (437.82K, 4.76 J/kgK)
# Imma -> Pccn (571.43K, 7.08 J/kgK)
# P2/m -> Immm (522.42K, 3.28 J/kgK)
# Immm -> Pccn (402.55K, 2.59 J/kgK)
# P3_121 -> P-31c (527.72K, 20.15 J/kgK)
# R-3 -> P-31c (422.61K, 6.51 J/kgK)
# P-31m -> P2_12_12 (423.33K, 6.16 J/kgK)
# P2_1/m -> P2/c (347.85K, 3.61 J/kgK)
# Pnc2 -> P2/c (345.61K, 10.89 J/kgK)
# P2/m -> P2_1/c (339.68K, 4.11 J/kgK)
# P2/m -> Pccn (465.64K, 5.92 J/kgK)
# Pnc2 -> P2_1 (507.61K, 14.36 J/kgK)
# Pcca -> P2_1 (520.43K, 10.98 J/kgK)
# Pmmn -> P2_1 (430.82K, 3.01 J/kgK)
# P6_3/mcm -> P2_1/c (511.70K, 6.71 J/kgK)
# Pnc2 -> P2_1/m (344.50K, 7.28 J/kgK)
# P3_121 -> R-3 (588.29K, 13.40 J/kgK)
# P6_3/mcm -> Pbam (481.76K, 5.88 J/kgK)
# P4_2/nbc -> P4_2/mcm (327.21K, 2.40 J/kgK)
# P4_2/mmc -> Cm (382.30K, 1.04 J/kgK)
# P4_2/nbc -> Pna2_1 (307.17K, 5.26 J/kgK)
# P6_3/mcm -> P4_32_12 (330.21K, 2.27 J/kgK)
# P6_3/mcm -> Pccn (591.03K, 8.11 J/kgK)
# Pnc2 -> Pcca (467.98K, 3.36 J/kgK)
# Pnc2 -> Pmmn (530.42K, 11.29 J/kgK)
# Pcca -> Pmmn (559.59K, 7.89 J/kgK)
# CeTi2O6
# CeZr3O8
# P1 -> C2/c (432.75K, 35.20 J/kgK)
# CeZr7O16
# P-4m2 -> Cm (526.29K, 57.71 J/kgK)
# CeZrO4
# Warning: 2 transitions within this interval
# Fd-3m -> P2_13 (315.74K, 33.10 J/kgK)
# Cl2
# ClF3
# Co(C4N3)2
# Co(HO)2
# Co(IO3)2
# Co(PO2)2
# Co(PO3)3
# Pccn -> P2_12_12_1 (356.08K, 12.91 J/kgK)
# Co2As2O7
# Co2C2O7
# C2/c -> P2_1/c (426.20K, 41.85 J/kgK)
# Co2OF3
# Co2P2O7
# Co3(AsO4)2
# Co3(PO4)2
# Co3B7IO13
# Co3C10O9
# Co3OF5
# Amm2 -> P-1 (412.02K, 37.77 J/kgK)
# Amm2 -> P2_1 (555.78K, 139.97 J/kgK)
# Amm2 -> Pmn2_1 (432.18K, 101.36 J/kgK)
# P-1 -> Pmn2_1 (444.48K, 65.23 J/kgK)
# Co3TeO8
# Co5SbO8
# Co6OF11
# C2 -> Amm2 (446.26K, 183.18 J/kgK)
# Cm -> P1 (377.57K, 57.75 J/kgK)
# Co7(SbO6)2
# CoAgPO4
# CoAsS
# CoB10H23C13
# CoB4O7
# CoBP(HO3)2
# CoBi6(SO8)2
# CoF3
# CoH15Br2(N3O)2
# CoH15N6(ClO)2
# Cc -> P-1 (411.74K, 130.66 J/kgK)
# CoH22N7(ClO2)4
# CoH7C3NO6
# CoHCO3
# CoNiO3
# CoO
# R3m -> P3m1 (449.16K, 65.64 J/kgK)
# CoO2
# CoP2WO8
# CoP3H16N4O11
# CoP4O11
# CoPH6NO5
# CoPO4
# CoPSe
# CoSO4
# CoSb(PO4)2
# CoSeO4
# CoTe(PbO3)2
# CoTe2O5
# Cr(GeO3)2
# Cr(PO3)2
# Cr(PO3)3
# Cr2(MoO4)3
# Cr2(WO4)3
# Cr2CdH14(NO2)4
# Cr2Cu3(OF)12
# Cr2FeO4
# Cr2NiO4
# P1 -> P1 (504.05K, 58.50 J/kgK)
# P1 -> P1 (506.57K, 58.64 J/kgK)
# Cr2O3
# Cr2O5
# Cr2P4Pb3O16
# P2_1/c -> P4_12_12 (354.48K, 10.63 J/kgK)
# Cr2PO5
# Cr3(FeO6)2
# Cr3(PO4)2
# Cr3B7ClO13
# Cr3O4
# Cr3O8
# Cr4OF11
# Warning: 2 transitions within this interval
# P1 -> P-1 (362.88K, 65.95 J/kgK)
# P1 -> P1 (322.46K, 99.36 J/kgK)
# CrAgO2
# CrAgS2
# P1 -> P1 (576.37K, 41.72 J/kgK)
# P1 -> P1 (388.07K, 34.71 J/kgK)
# P1 -> P1 (472.20K, 27.78 J/kgK)
# CrAsO4
# CrBiO3
# CrBiO4
# CrCdO4
# CrCl3
# CrCoO4
# CrCuO2
# CrF3
# CrF4
# CrF5
# CrFe(PO4)2
# CrH14N4Cl3O
# CrH17N4Cl2O3
# CrH20N2O6F5
# CrHO2
# CrHSe3O8
# CrHgO4
# P2_1/c -> Cmcm (468.61K, 29.59 J/kgK)
# CrO2
# CrO3
# CrOF
# CrOF4
# C2/c -> P2_1/c (548.67K, 36.53 J/kgK)
# CrP2O7
# P2_1 -> P2_1/c (552.98K, 48.47 J/kgK)
# CrP4O11
# CrPO4
# CrPO5
# CrPbO4
# CrSO4
# CrSbO4
# CrWO6
# Cs2BeO2
# Cs2CdBr4
# P2_1/c -> P1 (339.39K, 16.32 J/kgK)
# Cs2CdI4
# Cs2CeO3
# P1 -> P2_1 (545.31K, 4.53 J/kgK)
# Cs2Hf(WO4)3
# Cs2HfO3
# Cs2HgBr4
# P2_1/c -> Pnma (362.67K, 31.88 J/kgK)
# Cs2HgCl4
# P2_1/c -> Pnma (483.44K, 2.63 J/kgK)
# Cs2HgI4
# Cs2HgTe
# Cs2I4O11
# P6_3 -> P2_1/c (356.02K, 48.48 J/kgK)
# Cs2K2B10O17
# Cs2Li3I5
# Cs2LiCr(CN)6
# Cs2LiInCl6
# Cs2MgH4
# Cs2MgMo2(O2F3)2
# Cs2Mo(SO)2
# C2/c -> Pbcn (452.03K, 29.15 J/kgK)
# Cs2MoN(Cl2O)2
# Cs2NaAlF6
# Cs2NaFeF6
# Cs2NaGaF6
# Cs2Ni3S4
# P6_3/mmc -> Fmmm (344.23K, 27.00 J/kgK)
# Cs2NiH12(SO7)2
# Cs2O
# Cs2PbO3
# Cmc2_1 -> Cmcm (365.84K, 1.29 J/kgK)
# Cs2Pd(IBr2)2
# C2/m -> I4/mmm (523.84K, 38.23 J/kgK)
# Cs2PdCl4
# Cs2S
# Cs2SbF5
# Cs2Se
# R-3m -> P2_1/c (504.73K, 22.73 J/kgK)
# R-3m -> Pnma (504.87K, 26.47 J/kgK)
# P2_1/c -> Pnma (505.72K, 3.74 J/kgK)
# Cs2Tb6Te7N2
# Cs2Ti(PO4)2
# Cs2Ti(Si2O5)3
# Cs2U2O7
# Cs2WO4
# Cs2ZnI4
# Pna2_1 -> P1 (490.82K, 14.06 J/kgK)
# Cs3As2Cl9
# Cs3Bi2Br9
# Cs3Bi2Cl9
# Cs3Bi2I9
# Cs3BiCl6
# Cs3BiF6
# Cs3Cr2I9
# Cs3DyO3
# P2_1/c -> C2/m (470.55K, 12.74 J/kgK)
# Cs3ErCl6
# Cs3ErO3
# Cs3Fe2F9
# Cs3FeF6
# Cs3GaO3
# Cs3H(SeO4)2
# C2/c -> C2/m (593.48K, 8.66 J/kgK)
# Cm -> C2/m (388.44K, 8.69 J/kgK)
# Cs3HoCl6
# Cs3HoO3
# Cs3LaBr6
# Cs3LaCl6
# Cs3LaO3
# Cs3LiCl4
# Cs3MgH5
# Cs3NO4
# Cs3PrCl6
# Cs3Sb2Cl9
# Cs3Sb2I9
# P1 -> P-3m1 (327.63K, 5.52 J/kgK)
# Cs3SbF6
# Cs3YF6
# Cs3YO3
# Cs4BiSbCl12
# Cs4CO4
# I-42m -> P-43m (484.75K, 57.97 J/kgK)
# I-42m -> R3 (422.23K, 96.02 J/kgK)
# Cs4Na2MgV2O8
# Cs5Bi(MoO4)4
# Cs5YO4
# Cs8Mg(Sn2O3)4
# P1 -> P-1 (571.01K, 24.02 J/kgK)
# Cs8Na4Y3HoCl24
# CsAgBr2
# CsAgCl2
# CsAlF4
# P-62m -> I4/mcm (454.66K, 88.97 J/kgK)
# P-62m -> Pnma (333.41K, 102.58 J/kgK)
# CsAlSiO4
# CsAsO3
# CsAsSe2
# CsAu(IO3)4
# CsAu(SO4)2
# CsB3H8
# CsB5(H2O3)4
# CsB5O8
# CsBeF3
# CsBr
# CsC3(SeN)3
# CsCN
# CsCaCl3
# CsCaI3
# CsCdBr3
# CsCdCl3
# P6_3/mmc -> Pm-3m (336.73K, 41.75 J/kgK)
# CsCl
# CsClO3
# CsClO4
# CsCoH18N6(ClO2)4
# CsCoO2
# CsCoPO4
# P2_1/c -> P2_1 (416.72K, 21.88 J/kgK)
# CsCuCl3
# CsDyS2
# R-3m -> P-6m2 (427.57K, 12.60 J/kgK)
# CsEr(MoO4)2
# P2/c -> Pccm (497.01K, 20.58 J/kgK)
# CsEr(WO4)2
# CsEr2Cu3Se5
# CsF
# CsFe(MoO4)2
# P-3m1 -> P-3 (500.40K, 33.38 J/kgK)
# CsFeO2
# CsGaH4
# CsGaO2
# CsGaP3HO10
# Pca2_1 -> P2/c (393.99K, 11.51 J/kgK)
# CsGd(MoO4)2
# CsGe
# CsGeBr3
# R3m -> Cm (397.79K, 20.99 J/kgK)
# CsGeI3
# Cm -> Cm (324.10K, 22.99 J/kgK)
# CsH
# Pm-3m -> Fm-3m (421.13K, 84.92 J/kgK)
# CsH2SNO3
# CsH3O2
# CsH6Rh(N3O4)2
# CsHF2
# CsHO
# CsHSO4
# P2_1/m -> P2_1/c (568.10K, 116.52 J/kgK)
# CsHgCl3
# CsHo(MoO4)2
# CsHo2Cu3Se5
# CsHoS2
# R-3m -> P6_3/mmc (438.01K, 10.31 J/kgK)
# CsI
# CsLi(B3O5)2
# CsLi2Cl3
# CsLiCl2
# CsLiO
# CsLiSO4
# CsLu(MoO4)2
# CsLuS2
# R-3m -> P6_3/mmc (351.44K, 4.58 J/kgK)
# CsMg6BO7
# CsMgH3
# R-3m -> Pmmn (421.92K, 90.91 J/kgK)
# CsMo2P3O13
# CsN3
# P4/mmm -> I4/mcm (371.92K, 33.02 J/kgK)
# CsNO3
# Pmmn -> P1 (388.06K, 54.53 J/kgK)
# CsNb(PO4)2
# CsNbN2
# CsNbO3
# CsNd(MoO4)2
# CsNd(PO3)4
# CsNdS2
# CsNiF3
# CsP(HO2)2
# P2_1 -> P2_1 (560.94K, 26.18 J/kgK)
# CsP2H5O8
# CsP7
# CsPO3
# CsPSO2
# P2_1/c -> P-1 (586.47K, 61.81 J/kgK)
# CsPSe6
# Pc -> P-42_1c (513.14K, 28.35 J/kgK)
# CsPb2Cl5
# CsPbBr3
# CsPbCl3
# CsPbF3
# R3c -> Pm-3m (407.92K, 44.61 J/kgK)
# CsPbI3
# CsPr(PO3)4
# CsPrS2
# CsSb
# CsSi
# CsSi2HO5
# CsSm(MoO4)2
# CsSm(PO3)4
# CsSn
# P-43n -> I4_1/acd (407.95K, 15.83 J/kgK)
# CsSnBr3
# CsSnCl3
# CsSnF3
# CsSnI3
# CsSrBr3
# CsSrCl3
# Cm -> Pm-3m (468.82K, 6.76 J/kgK)
# CsSrI3
# CsTb(MoO4)2
# CsTbS2
# R-3m -> P6_3/mmc (375.27K, 9.90 J/kgK)
# CsTi3P5O19
# CsTiCu3Se4
# CsVSO6
# P2_1/c -> Pbca (339.57K, 97.72 J/kgK)
# CsW3Br7
# CsY(MoO4)2
# P2/c -> Pccm (453.15K, 32.20 J/kgK)
# CsZnPO4
# Cu2H10C6S3N4
# Cu2SO4
# Cu2SiS3
# Cu2WO4
# Cu2WS4
# CuAgS
# CuBi(WO4)2
# CuBi3PbS6
# CuBiO2
# CuCSN
# CuCl
# R3m -> P6_3mc (591.33K, 91.69 J/kgK)
# CuClO2
# CuH12C5S4N
# CuH12N2(Cl2O)2
# CuH2CN2Cl
# CuHgSBr
# CuI
# Pc -> P-3m1 (458.35K, 64.82 J/kgK)
# Pc -> P3m1 (592.60K, 47.84 J/kgK)
# Pc -> P-3m1 (437.51K, 67.39 J/kgK)
# Pc -> P3m1 (548.90K, 51.24 J/kgK)
# CuN3
# CuP2(HO)4
# Pbca -> P2_1/c (512.91K, 62.48 J/kgK)
# CuP4S3Br
# Cmce -> P-1 (372.82K, 86.80 J/kgK)
# CuPO3
# CuW3Br7
# Pn-3 -> Pbca (468.59K, 4.30 J/kgK)
# Dy(ClO4)3
# Dy(PO3)3
# Dy2(MoO4)3
# Dy2(SeO4)3
# Dy2CO5
# Dy2Ge2O7
# P2_1/c -> Fd-3m (557.60K, 74.69 J/kgK)
# Dy2MgS4
# Dy2MgSe4
# Pnma -> Pca2_1 (434.76K, 9.88 J/kgK)
# Dy2MgV2O7
# Dy2O3
# Dy2P4O13
# Dy2S2O
# Dy2S3
# Dy2SO2
# Dy2Sb2O7
# Dy2SeO2
# Dy2Si2O7
# P-1 -> P1 (553.92K, 20.57 J/kgK)
# Dy2SiO5
# Dy2Te4O11
# Dy2TeO6
# Dy2Ti2O7
# Dy2TiO5
# Cmcm -> C2/c (559.43K, 60.67 J/kgK)
# Dy2WO6
# Dy2Zr2O7
# P2_1 -> Fd-3m (313.30K, 40.26 J/kgK)
# Dy3NbO7
# Dy3TaO7
# Dy6Mg(Sb5O12)2
# Cm -> R3m (447.39K, 20.77 J/kgK)
# DyAgTe2
# DyAlO3
# DyBO3
# DyClO
# DyCu(WO4)2
# DyCuS2
# P2_12_12_1 -> P2_12_12_1 (312.94K, 6.59 J/kgK)
# DyF3
# DyFe3(BO3)4
# DyGaO3
# DyH9C5(NO4)2
# C222_1 -> C2 (572.72K, 633.06 J/kgK)
# DyHO2
# DyInO3
# DyNbO4
# C2/c -> P2/c (525.15K, 27.42 J/kgK)
# DyP5O14
# DySbO4
# DyTaO4
# DyVO4
# DyWO4
# Er(CuS)3
# Er(PO3)3
# Er2(WO4)3
# Er2CdS4
# Er2GeO5
# Er2MgS4
# Er2MgSe4
# Er2O3
# Er2P4O13
# Er2PbS4
# Er2S3
# Er2Se3
# Er2Si2O7
# P2_1/c -> C2/m (374.98K, 33.25 J/kgK)
# Er2SiO5
# Er2TeO2
# Er2TeO6
# Er2TiO5
# Er2WO6
# Er2Zr2O7
# C2/m -> Fd-3m (329.92K, 99.26 J/kgK)
# Er3TaO7
# Er5Mg(MoO6)2
# ErAgS2
# I4_1md -> I4_1/amd (582.38K, 32.07 J/kgK)
# ErAgTe2
# ErAlO3
# ErBO3
# ErBiO3
# ErBiW2O9
# ErClO
# ErCu(WO4)2
# P2/c -> P-1 (593.57K, 21.01 J/kgK)
# P2/c -> P1 (455.57K, 17.45 J/kgK)
# ErCuS2
# ErGaO3
# ErH3(SO4)3
# ErInO3
# ErNbO4
# ErP5O14
# ErPaO4
# ErSbO4
# ErTa3O9
# ErTaO4
# ErVO4
# Eu(BH4)2
# EuBr2
# EuCl2
# EuI2
# P2_1/c -> Pbca (583.40K, 24.03 J/kgK)
# F2
# Fe(BO2)2
# Fe(CO)5
# Fe(HO)2
# Fe(PO3)3
# Fe(SbO2)2
# Fe10O11F9
# Fe10O9F11
# Fe10OF19
# Fe15O16
# Fe2(MoO4)3
# Fe2(WO4)3
# Fe21HO32
# Fe2BO4
# Fe2C2O7
# Fe2CoO4
# Fe2CuAs2(HO5)2
# Fe2NiO4
# Fe2O3
# Fe2OF3
# Amm2 -> C2 (360.40K, 33.44 J/kgK)
# C2/m -> P1 (517.69K, 88.20 J/kgK)
# C2/m -> Pnma (539.62K, 160.04 J/kgK)
# P1 -> Pnma (573.32K, 68.03 J/kgK)
# Fe2P2O7
# Fe2PClO4
# P1 -> P1 (351.14K, 9.97 J/kgK)
# Fe2SiO4
# Fe3(OF)2
# Fe3(OF2)2
# Fe3(P2O7)2
# Fe3(SiO4)2
# Fe3B7BrO13
# Fe3B7IO13
# Fe3BO5
# Fe3H9S2O15
# Fe3O4
# Pbcm -> Cmcm (357.51K, 45.13 J/kgK)
# Fe3OF5
# C2/m -> Cmmm (591.81K, 142.65 J/kgK)
# C2/m -> P2/m (599.18K, 114.28 J/kgK)
# C2/m -> Pmn2_1 (583.31K, 92.82 J/kgK)
# Warning: 2 transitions within this interval
# Cmmm -> P2/m (436.60K, 14.35 J/kgK)
# Cmmm -> Pmn2_1 (390.74K, 38.24 J/kgK)
# P2/m -> Pmn2_1 (346.73K, 19.55 J/kgK)
# Fe3OF7
# R3m -> Cc (302.12K, 56.79 J/kgK)
# Fe4(PO4)3
# Fe4As2O11
# Fe4As5O13
# Fe4Bi2O9
# Fe4H14O13
# Fe4O3F5
# Cmcm -> Imm2 (480.28K, 33.88 J/kgK)
# Pc -> P2_1 (463.12K, 7.29 J/kgK)
# Fe4OF6
# P1 -> P1 (433.54K, 12.20 J/kgK)
# P1 -> P1 (540.13K, 94.09 J/kgK)
# Fe4OF7
# Imm2 -> Amm2 (580.28K, 99.05 J/kgK)
# Cc -> Cmc2_1 (414.20K, 58.18 J/kgK)
# P-1 -> Cm (365.76K, 81.88 J/kgK)
# P-1 -> Cmc2_1 (354.82K, 94.88 J/kgK)
# P2_1 -> Cmc2_1 (508.49K, 70.29 J/kgK)
# Imm2 -> Cmcm (511.22K, 33.53 J/kgK)
# Fe5(OF4)2
# Fe5(SiO4)3
# Fe5O3F7
# P1 -> P-1 (454.14K, 33.82 J/kgK)
# P1 -> Pm (333.40K, 29.93 J/kgK)
# Fe5P3O13
# Fe6O5F7
# C2 -> Amm2 (434.55K, 60.49 J/kgK)
# Pm -> Cm (377.51K, 28.59 J/kgK)
# Fe6OF11
# Fe8O9
# FeAgO2
# FeAsO4
# FeBO3
# FeBP(HO3)2
# FeBi25O39
# FeBiO3
# P4mm -> R3m (351.31K, 13.38 J/kgK)
# FeF3
# P-1 -> C2/c (535.22K, 242.08 J/kgK)
# Cmcm -> P321 (530.88K, 185.80 J/kgK)
# P-1 -> P321 (328.07K, 119.20 J/kgK)
# FeH7C3NO6
# FeHO2
# Pmc2_1 -> P-1 (354.03K, 167.21 J/kgK)
# FeMoClO4
# P2_1/m -> P4/nmm (493.86K, 47.50 J/kgK)
# FeO
# C2/m -> P31c (478.68K, 35.54 J/kgK)
# FeOF
# Ama2 -> C2 (468.53K, 14.42 J/kgK)
# Pmn2_1 -> Ama2 (585.01K, 113.41 J/kgK)
# Pmn2_1 -> C2 (570.46K, 128.14 J/kgK)
# Pnma -> P-1 (568.77K, 52.96 J/kgK)
# R3 -> P2/m (398.19K, 80.90 J/kgK)
# FeP(H2O3)2
# FeP4
# FeP4O11
# FePH5CO4
# FePH5NO4F
# FePH6(NO2)2
# Pnma -> P2_1/c (328.29K, 43.90 J/kgK)
# FePH6NO5
# P1 -> P1 (338.97K, 16.56 J/kgK)
# FePO4
# Pna2_1 -> P1 (562.73K, 100.58 J/kgK)
# Cmcm -> Pnma (366.27K, 165.76 J/kgK)
# Cmcm -> R3 (411.25K, 129.52 J/kgK)
# Pca2_1 -> Pbca (500.42K, 24.20 J/kgK)
# FeSO4
# FeSO4F
# FeSbO4
# FeSiO3
# FeSiO4
# FeSnO3
# FeTe(PO4)2
# Ga2(SO4)3
# Ga2CoO4
# Ga2HgO4
# Ga2NiO4
# Ga2O3
# Ga2PbO4
# Ga2PbSe4
# Ga2S3
# Cc -> Imm2 (431.77K, 63.27 J/kgK)
# Ga2Se3
# Ga2WO6
# Ga3Bi5Cl12
# Ga3NO3
# R-3m -> P1 (469.94K, 114.42 J/kgK)
# Ga4B2O9
# Ga4Bi2O9
# Ga6SnTe10
# GaAg(PSe3)2
# GaAgO2
# P6_3/mmc -> R-3m (375.08K, 0.72 J/kgK)
# GaAgS2
# GaAgSeS
# I2_12_12_1 -> Cc (308.95K, 7.48 J/kgK)
# GaAsO4
# GaBiN2
# GaBiO3
# GaBr2
# GaCl3
# GaCuO2
# GaH20C2S2NO14
# GaHO2
# GaHg2SbCl4
# GaHg3AsSCl4
# GaN
# GaN5O14
# I-4 -> C2 (404.72K, 110.39 J/kgK)
# GaP
# GaP2H15C5(NO4)2
# GaPO4
# C222_1 -> I-4 (542.99K, 40.08 J/kgK)
# GaS
# GaSe
# R3m -> P-6m2 (429.56K, 79.01 J/kgK)
# R3m -> P6_3/mmc (398.39K, 77.53 J/kgK)
# R3m -> P6_3mc (452.49K, 86.81 J/kgK)
# GaTe
# Gd(BO2)3
# Gd(PO3)3
# Gd2(MoO4)3
# Gd2(WO4)3
# Gd2B4O9
# Gd2HfO5
# Gd2MgS4
# Gd2O3
# C2/m -> P-3m1 (560.76K, 18.09 J/kgK)
# Gd2P4O13
# Gd2S3
# Gd2Si2O7
# Gd2TiO5
# Gd2V2O7
# Gd2W2O9
# Gd2W4O15
# Gd2Zr2O7
# P2_1/c -> Pmna (530.33K, 47.31 J/kgK)
# Gd3AsO7
# Pnma -> C222_1 (540.90K, 13.37 J/kgK)
# Gd3InO6
# Gd3InS6
# Gd3NbO7
# C222_1 -> P-1 (468.87K, 21.73 J/kgK)
# Gd3SbO7
# Gd3TaO7
# Gd3Y13O24
# P1 -> C2 (597.27K, 31.74 J/kgK)
# Gd3YO6
# Gd4(SiS4)3
# Gd6MgWO12
# GdAl3(BO3)4
# GdAlO3
# GdAsO4
# GdB2HO5
# GdBO3
# GdCrO3
# GdFe3(BO3)4
# GdInO3
# GdOF
# GdPO4
# GdTa3O9
# GdTiCdSbO7
# GdZr3F15
# Ge(BrF5)2
# Ge(PbS2)2
# Ge(SeO3)2
# Ge2MoO6
# Ge2N2O
# I4_1/amd -> P-3m1 (449.99K, 40.71 J/kgK)
# I4_1/amd -> Pc (363.59K, 129.73 J/kgK)
# P-3m1 -> Pc (339.74K, 114.64 J/kgK)
# Ge2WO6
# Ge3N4
# Ge3Pb3O10
# Ge3Pb5O11
# Ge4PbO9
# GeBi2O5
# GeBr2
# GeBr4
# Pa-3 -> P2_1/c (543.06K, 6.89 J/kgK)
# GeC
# GeCN2
# GeF2
# GeH4
# GeI2
# GeO2
# Pnnm -> P4_2/mnm (348.92K, 44.98 J/kgK)
# GePb3O5
# GePbN2
# GePbO3
# GeS
# GeS2
# GeSe2
# Fdd2 -> I-42d (525.03K, 70.64 J/kgK)
# GeTe
# GeWO4
# H(CO)2
# Warning: 2 transitions within this interval
# Cm -> P2_1/m (341.63K, 188.47 J/kgK)
# H(WO3)2
# H10C3NClO4
# H12C4N2O9
# Pnma -> P2_1/c (407.03K, 622.15 J/kgK)
# H13S2N3O8
# H13Se2N3O8
# H16PdC4S4(N4Cl)2
# H2
# I4/mmm -> P2_1/c (328.05K, 6929.08 J/kgK)
# I4/mmm -> Cmcm (566.22K, 19875.69 J/kgK)
# H24C8S(NO2)2
# H2C(NO)2
# H2CBrCl
# C2/c -> P2_12_12 (428.45K, 187.53 J/kgK)
# H2CN2
# H2CO
# I4_1/a -> C222_1 (540.09K, 581.13 J/kgK)
# I4_1/a -> Pbcn (367.02K, 1066.27 J/kgK)
# H2O
# C222_1 -> Cc (443.62K, 281.47 J/kgK)
# P1 -> I4_1/amd (553.33K, 405.85 J/kgK)
# P4_12_12 -> I4_1/amd (466.42K, 971.43 J/kgK)
# R-3 -> I4_1/amd (448.86K, 252.23 J/kgK)
# P4_12_12 -> P1 (411.55K, 555.29 J/kgK)
# P4_12_12 -> R-3 (472.75K, 718.95 J/kgK)
# H2S
# P1 -> Ibca (341.30K, 237.48 J/kgK)
# P1 -> P4_2 (583.61K, 494.79 J/kgK)
# H2SO4
# C2/c -> C2 (502.09K, 192.10 J/kgK)
# H2SeO3
# H2SeO4
# H2W2O7
# H3BrO
# H3CI
# H3CSNOF2
# H3ClO5
# H3N
# H3NCl
# H3NO
# H3S
# H4BrN
# H4C(N2O)2
# H4C2O
# H4CN2O
# H4CS(NO)2
# H4CSN2
# H4IN
# H4N2O3
# H4NClO4
# H4NF
# H4PbI3N
# H4Pd(NO4)2
# H4SO5
# H5BrO2
# P1 -> P2_1/c (492.35K, 130.94 J/kgK)
# H5CN3
# H5ClO6
# H5IO6
# P2_1 -> Pc (501.32K, 217.95 J/kgK)
# H5NO
# H5SeNO4
# H6C(NO)2
# H6C(SN)2
# H6C2SO4
# H6CIN
# H6CN2O3
# H6CNF
# H6N4O9
# H6PbCBr3N
# H6PbCI3N
# H6PbCNCl3
# H7BrO3
# H7C4(N3O2)3
# H7ClO3
# H7NO6
# H7SIO10
# H8C2BrN
# H8C2NCl
# H8C3N2O
# H8N2O
# H8Pd(NCl3)2
# H8S(NO2)2
# H8W3Se(NO6)2
# H9BrO4
# H9CN9
# HAuO2
# Pmn2_1 -> C2/m (485.97K, 197.64 J/kgK)
# HBr
# Fmmm -> Fmmm (382.37K, 63.77 J/kgK)
# HC
# HC2N3
# Cm -> P1 (491.21K, 295.09 J/kgK)
# Cm -> P1 (489.47K, 256.54 J/kgK)
# Cm -> Pbam (428.43K, 395.40 J/kgK)
# Cm -> Pm (394.89K, 609.05 J/kgK)
# P1 -> P1 (502.33K, 39.27 J/kgK)
# Pbam -> P1 (594.20K, 336.32 J/kgK)
# HCN
# HCl
# HF
# HIO3
# HIO4
# HN
# HNO
# HNO3
# HPbClO
# Pnma -> C2/m (431.28K, 60.93 J/kgK)
# HS3N
# Hf(MoO4)2
# Hf(PS3)2
# Hf2N2O
# C2/c -> C2 (541.47K, 19.45 J/kgK)
# P2_1/c -> Cm (480.33K, 66.05 J/kgK)
# I4_1/amd -> P-3m1 (419.34K, 27.08 J/kgK)
# I4_1/amd -> P2_1/m (493.18K, 37.05 J/kgK)
# Pm -> P-3m1 (320.30K, 24.24 J/kgK)
# P2_1/c -> P2/c (309.67K, 71.39 J/kgK)
# Pm -> P2/c (586.59K, 42.51 J/kgK)
# Pm -> P2_1/m (412.63K, 35.58 J/kgK)
# Hf2P2O9
# Hf2SN2
# Hf3N2O3
# Hf3N4
# HfBrN
# HfCrAgS4
# Pnma -> Pm (485.16K, 34.60 J/kgK)
# HfCrCuS4
# HfCrO4
# HfI4
# HfMg30BO31
# P4mm -> Pmm2 (497.70K, 50.72 J/kgK)
# HfN2
# HfO2
# P2_12_12 -> Fm-3m (531.01K, 76.29 J/kgK)
# Pbca -> Pbcn (579.26K, 49.06 J/kgK)
# HfP2O7
# HfPbO3
# HfSO
# HfTaNO3
# HfTi4(PbO3)5
# HfTiO4
# HfZrO4
# Cmmm -> I4_1/a (543.34K, 54.14 J/kgK)
# Hg
# Hg(CO2)2
# Hg15(As2Cl3)4
# Pna2_1 -> P2_1/c (325.32K, 3.47 J/kgK)
# Hg2ClO
# Hg2GeO4
# Hg2Mo2O7
# P-1 -> C2/c (518.19K, 13.04 J/kgK)
# Hg2MoO4
# Hg2N2O3
# Hg2SeO3
# Cmc2_1 -> P2_1/c (460.97K, 17.78 J/kgK)
# Hg2Te2O7
# Hg2W2O7
# C2/c -> P-1 (409.28K, 19.63 J/kgK)
# P2/c -> C2/c (445.94K, 7.84 J/kgK)
# P2/c -> P-1 (419.42K, 27.49 J/kgK)
# Hg3(SCl)2
# Hg3(SeI)2
# Hg3SO6
# Hg3TeO6
# HgB4O7
# HgBr2
# HgBrCl
# HgC2(SN)2
# HgCN2
# Pbca -> P2_1/c (426.34K, 129.47 J/kgK)
# HgF2
# HgH16(Br3N2)2
# HgI2
# Cmc2_1 -> P4_2/nmc (457.15K, 3.51 J/kgK)
# C2/c -> P1 (409.78K, 5.83 J/kgK)
# HgN6
# HgO
# C2 -> P2_1/m (522.09K, 46.64 J/kgK)
# P3_221 -> P2_1/m (420.45K, 54.64 J/kgK)
# Pnma -> P2_1/m (556.52K, 66.00 J/kgK)
# HgS
# HgSeO3
# Pnma -> P2_1/c (309.20K, 19.72 J/kgK)
# HgWO4
# Ho(ClO4)3
# Ho14(PbS8)3
# Ho2(MoO4)3
# Pba2 -> P-42_1m (533.20K, 6.07 J/kgK)
# Ho2(SO4)3
# Ho2(SeO3)3
# Ho2(SeO4)3
# Ho2(WO4)3
# Ho2B4O9
# Ho2CdS4
# Ho2CdSe4
# Ho2Ge2O7
# Ho2MgAg2(WO4)4
# P1 -> C2/m (537.87K, 16.72 J/kgK)
# Ho2MgMo2(ClO4)2
# Ho2MgS4
# Ho2MgSe4
# Ho2MgV2O7
# Ho2O3
# Ho2P4O13
# Ho2PbS4
# Ho2S3
# Ho2SO2
# Ho2Sb2O7
# Ho2Se3
# Ho2Si2O7
# Ho2TeO2
# Ho2TeO6
# Ho2Ti2O7
# Ho2TiO5
# Ho2WO6
# Ho2Zr2O7
# P2_1 -> Fd-3m (438.51K, 51.43 J/kgK)
# Ho3TaO7
# Ho6MgWO12
# HoAgS2
# P4_12_12 -> P2_1 (430.31K, 5.24 J/kgK)
# HoAgSe2
# HoAgTe2
# HoAl3(BO3)4
# C2/c -> R32 (492.13K, 50.68 J/kgK)
# HoAsO4
# HoBO3
# HoBiO3
# HoBrO
# P4/nmm -> R-3m (420.69K, 22.70 J/kgK)
# HoCuO2
# HoCuS2
# HoCuSe2
# HoErO3
# HoFe3(BO3)4
# HoGaO3
# HoH9C5(NO4)2
# C222_1 -> C2 (584.75K, 453.39 J/kgK)
# HoHO2
# Pmn2_1 -> P1 (365.09K, 6.43 J/kgK)
# HoIO
# HoInO3
# HoP5O14
# HoPaO4
# HoSbO4
# HoTa3O9
# HoTaO4
# HoVO4
# IF7
# In(HO)3
# In(IO3)3
# In(PO3)3
# In10(Pb2S7)3
# In2(SO4)3
# In2(WO4)3
# In2Br3
# In2Ge2O7
# In2O3
# In2S3
# Cc -> Imm2 (563.73K, 37.65 J/kgK)
# In2Se3
# In2Si2O7
# In2Te5
# In2WO6
# In3SnI5
# In4(SnO4)3
# P-1 -> P1 (533.91K, 30.01 J/kgK)
# In4Br7
# In5(BiS4)3
# In5Br7
# InBN2
# InBiO3
# InCl
# InGaS3
# InGeCl3
# InHO2
# InHSeO4
# InOF
# InP(H2O3)2
# InP2H9(NO4)2
# Fdd2 -> Cc (473.69K, 14.87 J/kgK)
# InPO4
# Cmcm -> Pnma (351.23K, 66.44 J/kgK)
# InPbCl3
# InSe
# InSnBr3
# InSnCl3
# K2(NbBr3)3
# K2Al2B2O7
# C2 -> C2 (300.05K, 128.09 J/kgK)
# K2BaLiCo(NO2)6
# K2BaNi(NO2)6
# K2BeF4
# K2C7N4O
# P2_1/c -> P-1 (524.28K, 138.72 J/kgK)
# K2CO3
# K2Ca2(SO4)3
# K2Ca3Si3O10
# K2Cd2(SO4)3
# K2Ce(NO3)6
# K2Ce(PO4)2
# I4_1/amd -> P2_1/c (378.45K, 170.81 J/kgK)
# K2CoCl4
# K2CoP4(HO2)8
# K2Cr2AsHO10
# K2Cr2O7
# K2CrO4
# K2Cu(CO3)2
# K2Dy4Cu4S9
# K2FeF5
# C2/m -> Pbam (311.16K, 22.47 J/kgK)
# C2/m -> Pbcn (359.99K, 96.33 J/kgK)
# C2/m -> Pnma (368.38K, 27.33 J/kgK)
# Pbam -> Pbcn (376.44K, 73.55 J/kgK)
# Pnma -> Pbcn (356.72K, 68.99 J/kgK)
# K2FeH8(SO6)2
# P2_1/c -> C2 (577.53K, 296.61 J/kgK)
# K2FeO4
# K2Ge2Se5
# P2_1/m -> P2_1/c (362.96K, 7.74 J/kgK)
# K2GeF6
# P6_3mc -> P-3m1 (377.19K, 64.67 J/kgK)
# K2HS2NO6
# K2HfF6
# K2Hg3(GeS4)2
# K2HgCl4
# K2Ho4Cu4S9
# K2LiAlF6
# K2LiAlH6
# K2LiMn2O4
# K2LiNbO4
# K2LiS2(O2F)2
# K2Mg(CO3)2
# K2Mg(CoO2)2
# K2Mg(FeO2)2
# K2Mg2(MoO4)3
# K2Mg2O3
# K2MgFe4P6(O4F3)4
# K2MgH8(SO6)2
# K2MgMn2P6(HO10)2
# K2MgMn3V2(HO5)2
# K2MgZn4P4(HO8)2
# K2Mn2Be3F12
# K2MnF6
# K2MnH8(SO6)2
# C2/c -> P1 (400.61K, 30.29 J/kgK)
# K2MnSO4F3
# Pbcn -> P2_1/c (463.25K, 11.68 J/kgK)
# K2Mo(SO)2
# K2Mo2P2O11
# K2Mo4O13
# K2NaAl3F12
# K2NaCl3
# P-3m1 -> I4/mmm (565.07K, 167.28 J/kgK)
# K2NaMo(OF)3
# K2NaNb(OF2)2
# K2NbAgS4
# K2Ni3S4
# K2O
# C2/m -> P4_2/nmc (342.14K, 122.85 J/kgK)
# K2O2
# K2P2H2O7
# K2P3
# Fmmm -> Fddd (503.96K, 20.87 J/kgK)
# K2PbO3
# K2Pd3Se4
# K2PdN2(ClO2)2
# K2S
# K2SO4
# K2SbF5
# Cmcm -> P2_1/c (513.35K, 111.67 J/kgK)
# K2SeO4
# K2Si3SnO9
# K2Si4O9
# K2SiF6
# K2Sm2Mg(MoO4)4
# K2Sn2O3
# K2SnBr6
# K2SnCl6
# Fm-3m -> P2_1/c (308.32K, 26.22 J/kgK)
# P4/mnc -> Fm-3m (515.38K, 42.91 J/kgK)
# P4/mnc -> P2_1/c (423.60K, 71.28 J/kgK)
# K2SnF6
# K2SnH2OF6
# C2/c -> Fddd (577.57K, 182.40 J/kgK)
# K2SrCl4
# K2TaAgS4
# K2TaF7
# K2TaNbO6
# K2Te(WO4)3
# K2TeBr6
# K2TeH6SeO10
# K2Ti(Si2O5)3
# K2Ti(SiO3)3
# K2TiCr(PO4)3
# K2U2O7
# K2VAgS4
# K2VAgSe4
# K2VCuS4
# K2VCuSe4
# K2VOF4
# K2WO4
# K2YHf(PO4)3
# K2YTi(PO4)3
# K2Zn(CN)4
# K2Zn(H2N)4
# K2Zn3S4
# Ibam -> Pnma (528.55K, 121.60 J/kgK)
# K2Zn6O7
# K2ZnBr4
# P2_1 -> P2_1/m (378.63K, 10.85 J/kgK)
# K2ZnCl4
# K2ZrF6
# K2ZrFe(PO4)3
# K2ZrSi2O7
# K2ZrSi3O10
# P2_12_12_1 -> P2_1/c (480.91K, 33.06 J/kgK)
# K3AlF6
# K3AlH6
# K3AsF6
# K3AsS4
# K3AuF6
# P-1 -> Fm-3m (483.07K, 215.75 J/kgK)
# K3B12H12Br
# K3ClO
# K3Co(CN)6
# K3CoPCO7
# K3Cr(CN)6
# K3CrF6
# K3DyCl6
# K3DyF6
# K3ErCl6
# K3ErF6
# K3FePCO7
# K3GdCl6
# K3H(SO4)2
# K3H(SeO4)2
# K3HoCl6
# K3HoF6
# K3IO5
# K3In(PO4)2
# P1 -> C2/c (559.73K, 18.49 J/kgK)
# K3InCl6
# K3InF6
# K3Li2Nb5O15
# K3Lu(PO4)2
# K3LuF6
# K3MgSbS4
# K3MoCl6
# K3Na(SeO4)2
# K3Na3TeP6(HO4)6
# K3NaCr2O8
# C2/c -> P-3m1 (587.21K, 63.85 J/kgK)
# K3NaMgCr2O8
# K3NaP4(H2O7)2
# K3Nb3(BO6)2
# K3Nb3Si2O13
# K3NiO2
# K3PrCl6
# K3RhF6
# K3SO4F
# K3Sb5O14
# Pba2 -> Pbam (495.04K, 7.80 J/kgK)
# K3SbS4
# K3SmF6
# K3Ta2S11
# K3TbF6
# K3VO4
# K3YCl6
# K3YF6
# K4(BSe)9
# K4BaTi6S20O
# K4BaU3O12
# K4CO4
# C2 -> I-4 (475.14K, 74.40 J/kgK)
# Cm -> I-4 (397.89K, 101.82 J/kgK)
# K4Gd2C3O9F4
# K4GeO4
# K4Mg(MoO4)2
# K4MgMo2(SO3)2
# K4MgV2O7
# K4MgV4O10
# K4MgV6O16
# K4NaCl5
# I4/m -> Immm (314.19K, 19.72 J/kgK)
# I4/mmm -> Immm (494.11K, 40.82 J/kgK)
# K4PH5Se3O16
# P1 -> P-1 (414.86K, 24.82 J/kgK)
# K4Sr(SiO3)3
# K4Sr2SnAs4
# K4Ta2S11
# K4TiO4
# K5HfIn(MoO4)6
# K5In(MoO4)4
# K6Ba2CaU6O24
# K6BiH3(Cl2F)4
# K6InP3
# K6Mg(SbS4)2
# K6MgV2(SO3)2
# K6Sb2H18S8O9
# K6Ti2O7
# K8MgCo2(Mo4O15)2
# KAgCO3
# KAgO2
# KAl(SO4)2
# KAl(SiO3)2
# KAl11O17
# R3m -> Cmcm (414.18K, 86.53 J/kgK)
# KAl2P2H5O11
# KAl3(SiO4)3
# KAl3Si3(HO6)2
# KAlF4
# P2_1/m -> P4/mbm (356.56K, 181.99 J/kgK)
# P2_1/m -> P4/mmm (416.52K, 313.83 J/kgK)
# P2_1/m -> Pnma (443.57K, 60.44 J/kgK)
# P4/mbm -> P4/mmm (520.43K, 126.49 J/kgK)
# Pnma -> P4/mbm (319.02K, 119.36 J/kgK)
# Pnma -> P4/mmm (410.31K, 253.24 J/kgK)
# KAlH4
# KAlO2
# KAlSi3O8
# KAlSiO4
# KAlTe2
# KAs(HO2)2
# Fdd2 -> I-42d (414.34K, 58.15 J/kgK)
# KAsF6
# KAsO3
# KAsOF5
# KAu(IO3)4
# KAuCl4
# KAuO2
# KB3O5
# KBF4
# KBH4
# F-43m -> P2_1/m (408.36K, 278.51 J/kgK)
# KBaBiWO6
# F-43m -> Pnnn (429.07K, 21.47 J/kgK)
# KBaCeBiO6
# KBaCr2(PO4)3
# KBaGdWO6
# F-43m -> Pnnn (319.49K, 44.72 J/kgK)
# KBaLaSeO6
# KBaLaWO6
# KBaLiZnF6
# KBaNdWO6
# KBaPrWO6
# KBe2B3O7
# KBe2BO3F2
# KBi(PSe3)2
# P2_1 -> P2_1/c (451.74K, 35.18 J/kgK)
# KBiF4
# KBiF6
# KBr
# KC
# KC(NO2)3
# KC2N3
# KCN
# KCNO
# KCSN
# KCa2Nb3O10
# KCaBr3
# KCaCeBiO6
# KCaCeNbO6
# KCaCl3
# Pm-3m -> Cm (346.26K, 9.61 J/kgK)
# KCaF3
# KCaLaWO6
# KCaNdWO6
# KCaPrWO6
# KCdF3
# KCdN
# KCeNbSnO6
# KCl
# KClO3
# KClO4
# KCo(CO)4
# KCoH3(CO2)3
# KCoO2
# KCr(SO4)2
# KCrF3
# KCrH18N6(ClO2)4
# KCrO2
# P6_3/mmc -> R-3m (391.62K, 182.92 J/kgK)
# KCuO
# KDy(MoO4)2
# KDy(PO3)4
# KEr(MoO4)2
# KEr(PO3)4
# KEr2F7
# KEr3F10
# KF
# KFe(MoO4)2
# KFe(SO4)2
# KFeBP2HO9
# KFeF4
# KFeO2
# KFePO4
# KGaTe2
# KGd(MoO4)2
# KGd(PO3)4
# KGdSnWO6
# P4_2/mmc -> F-43m (543.74K, 128.01 J/kgK)
# KGe
# KGeBr3
# KGeCl3
# KGeN
# Cm -> P6_3mc (379.42K, 106.90 J/kgK)
# KH(IO3)2
# KH3(SeO3)2
# KH8W(NF3)2
# KH8WN2(OF)3
# KHCO3
# KHO
# KHS
# KHgC3(SN)3
# P2_1/c -> P2_1/m (302.65K, 14.88 J/kgK)
# KHo(MoO4)2
# KHo2Cu(MoO4)4
# KHo2F7
# Cm -> C2/m (565.57K, 12.48 J/kgK)
# KI
# KIO3
# R3 -> Cm (533.04K, 31.37 J/kgK)
# KIn5S8
# KInBr3
# KInSe2
# KLa(PO3)4
# KLa(WO4)2
# KLaCeHfO6
# KLaCeSnO6
# KLaDyBiO6
# KLaF4
# Cm -> Pnma (583.49K, 23.43 J/kgK)
# KLaMg14O16
# KLaMnWO6
# KLaPrSbO6
# KLaSiS4
# KLaSmSbO6
# KLaTbBiO6
# KLaTiO4
# KLaYBiO6
# KLi(PO3)2
# KLi2FeO3
# KLiMg30O31
# KLiMoO4
# P2_1 -> P2_1/c (410.47K, 6.24 J/kgK)
# KLiS
# KLiSO4
# Cc -> P6_3 (488.33K, 24.72 J/kgK)
# P31c -> P6_3 (306.01K, 13.58 J/kgK)
# KLiWO4
# KLiZnP2O7
# KLu(MoO4)2
# KLu3F10
# KMg14AlO16
# KMg14BO16
# KMg14BiO16
# KMg14GaO16
# KMg14SbO16
# KMg14WO16
# KMg3(SiO3)4
# KMg30BO31
# KMg3AlSi3(O5F)2
# KMgAg2SbS4
# KMgFe(PO4)2
# KMgIn(MoO4)3
# KMgNi2H3(SeO5)2
# KMn2O4
# KMn4(PO4)3
# KMnF3
# KMnIO6
# KMnO2
# KMnP3HO10
# KMnSn3O8
# P1 -> P1 (350.01K, 22.89 J/kgK)
# KMo2P3O13
# P2_1/c -> C2/c (309.90K, 35.85 J/kgK)
# KMoIO6
# KNO2
# KNO3
# KNa(BH4)2
# R-3m -> P3m1 (464.92K, 148.63 J/kgK)
# KNa3Al4(SiO4)4
# KNa4Cl5
# C2/m -> I4/mmm (382.81K, 85.14 J/kgK)
# R-3m -> I4/mmm (572.43K, 103.70 J/kgK)
# KNaAl6Si6(HO6)4
# P2 -> P1 (464.96K, 66.73 J/kgK)
# KNaMg2F6
# KNaMg30O31
# KNaNb2O6
# KNaNbOF5
# KNaSO4
# KNaSe
# KNaTi4(BiO6)2
# KNb(BO3)2
# KNb4AsO13
# Cmc2_1 -> P1 (578.53K, 1.02 J/kgK)
# KNb5Pb2O15
# KNbCl6
# P2_1 -> R3m (542.28K, 130.35 J/kgK)
# Pmn2_1 -> P2_1/c (451.32K, 35.44 J/kgK)
# P2_1/c -> R3m (383.94K, 127.62 J/kgK)
# Pmn2_1 -> R3m (397.70K, 163.42 J/kgK)
# KNbF6
# KNbO3
# R3m -> Amm2 (574.03K, 35.26 J/kgK)
# KNd(PO3)4
# C2/c -> P2_1 (585.54K, 21.28 J/kgK)
# KNd(SO4)2
# KNdO2
# R-3m -> C2/m (522.91K, 42.15 J/kgK)
# KNdSnWO6
# KO3
# Imm2 -> I4/mcm (366.54K, 86.86 J/kgK)
# KP(HO2)2
# Cc -> I-42d (434.53K, 158.48 J/kgK)
# Cc -> P2_1 (562.59K, 213.71 J/kgK)
# Fdd2 -> I-42d (398.30K, 152.85 J/kgK)
# Fdd2 -> P2_1 (530.46K, 211.61 J/kgK)
# I-4 -> P2_12_12_1 (519.72K, 258.33 J/kgK)
# Pc -> I-42d (304.85K, 115.75 J/kgK)
# P2_1/c -> P-1 (561.42K, 327.61 J/kgK)
# Pc -> P-1 (571.55K, 374.97 J/kgK)
# P2_1/c -> P2_1 (417.82K, 134.68 J/kgK)
# Pc -> P2_1 (468.47K, 184.98 J/kgK)
# KPF6
# R-3 -> Pa-3 (332.90K, 180.73 J/kgK)
# KPO3
# KPSe3
# KPb2Cl5
# KPbN
# KPr(PO3)4
# KS2N(O2F)2
# P2_1/c -> Pbca (309.61K, 39.88 J/kgK)
# KSO2F
# KSb2PO8
# KSb4F13
# KSb5O13
# KSbF6
# KSbO3
# KSbSe2
# KSi
# KSi2HO5
# KSm(MoO4)2
# KSm(WO4)2
# KSmSnWO6
# KSn2F5
# KSnN
# KSrBiWO6
# KSrCeBiO6
# KSrCeNbO6
# KSrCeSbO6
# KSrGdWO6
# KSrLaWO6
# KSrNdWO6
# KSrPrWO6
# KSrSbWO6
# KSrSmWO6
# Pnnn -> F-43m (523.74K, 121.18 J/kgK)
# KSrVO4
# KSrZrBiO6
# KTaF6
# KTb(MoO4)2
# KTbSnWO6
# P4_2/mmc -> F-43m (510.91K, 140.42 J/kgK)
# KTeOF3
# KTi2(PO4)3
# KUN3O11
# KUP3O11
# KV2PO8
# KVPO5
# KY(PO3)4
# KY3F10
# KYF4
# KYMg14O16
# KYP2O7
# KYSnWO6
# P4_2/mmc -> F-43m (461.06K, 149.35 J/kgK)
# KZnP2H5O9
# KZnPO4
# Kr
# Im-3m -> Fm-3m (459.81K, 16.20 J/kgK)
# C2/m -> Fm-3m (456.38K, 43.34 J/kgK)
# C2/m -> Im-3m (454.35K, 27.15 J/kgK)
# La(BO2)3
# La(ClO4)3
# La(HO)3
# P1 -> Pm (401.74K, 65.79 J/kgK)
# P2_1/m -> Pm (581.56K, 79.53 J/kgK)
# P6_3 -> Pm (336.11K, 48.39 J/kgK)
# Pm -> Pm (562.40K, 78.87 J/kgK)
# La2(SiO3)3
# La20S29O
# La2CO5
# La2Ce2O7
# La2CrO6
# La2Fe(SeO)2
# La2Ge2O7
# P-1 -> P1 (458.88K, 16.39 J/kgK)
# La2Hf2O7
# La2HfO5
# C2/c -> Cmcm (536.59K, 28.25 J/kgK)
# La2Mg(FeO3)2
# La2Mg(NiO3)2
# La2MgFe2(TeO6)2
# La2MgMnZnO6
# P1 -> P1 (506.90K, 31.47 J/kgK)
# La2MgMoO6
# La2MgO4
# La2MgS4
# La2MgSe4
# La2MgSnO6
# La2MgTiO6
# La2MgTiZnO6
# La2Mn(SeO)2
# La2MnCrO6
# La2MnNiO6
# La2MoO6
# La2Nb2N2O5
# La2Ni2O5
# La2O3
# La2P4O13
# La2S2O
# P2_1/c -> Pnma (531.77K, 17.84 J/kgK)
# La2S3
# La2Se2O
# Pnma -> P2_1/c (400.67K, 34.68 J/kgK)
# La2Si(IO2)2
# La2Si2O7
# P4_1 -> P-1 (430.06K, 23.97 J/kgK)
# La2SiO5
# La2TeO6
# La2Ti2O7
# La2Ti3(BiO6)2
# La2Ti3O9
# P2_1 -> Pnma (374.40K, 31.17 J/kgK)
# La2TiZnO6
# La2WO6
# La2Zr2O7
# La3NbO7
# La3Nd(GaO3)4
# La3SbO7
# La3Si2ClO8
# La3TaO7
# La3Ti2N3O4
# La4Al2O9
# La4Al6O15
# La4FeSe6O
# P1 -> P1 (551.85K, 5.97 J/kgK)
# La4MgCr2O12
# La4MnO8
# La4MnS6O
# La4Ti3O12
# La5C2I9
# La6MgWO12
# La6NbGa11O28
# La6TaGa11O28
# LaAgO2
# LaAlO3
# R-3c -> I4/mcm (519.90K, 14.29 J/kgK)
# Warning: 2 transitions within this interval
# Pm-3m -> Imma (330.57K, 32.06 J/kgK)
# LaAsO4
# P2_1/c -> I4_1/a (346.37K, 16.33 J/kgK)
# LaAuO2
# LaBO3
# LaBiO3
# LaClO2
# LaCoO3
# Pnma -> C2/c (412.67K, 18.16 J/kgK)
# LaCrO3
# LaCrTeO6
# LaErS3
# LaF3
# Cmme -> I4/mmm (578.91K, 190.69 J/kgK)
# LaFeO3
# P1 -> Pm-3m (531.60K, 198.42 J/kgK)
# LaFeTeO6
# LaGaO3
# LaGaS3
# LaH3CSO7
# LaH6S3(NO3)3
# LaHoO3
# LaMgCrMoO6
# LaMgFeSnO6
# LaMgI5
# ...
# SnPSe3
# Pc -> P2_1/c (520.27K, 21.74 J/kgK)
# SnPbO3
# SnPbS2
# SnS
# SnS2
# SnSO4
# SnSe
# SnWO4
# Sr(AlCl4)2
# Sr(AlS2)2
# Cccm -> Fddd (405.93K, 22.38 J/kgK)
# Sr(AsO3)2
# Sr(BO2)2
# Sr(BS2)2
# Sr(BrO3)2
# Sr(C4N3)2
# Sr(ClO)2
# Sr(ErS2)2
# Sr(GaS2)2
# Sr(H2N)2
# Sr(H2O3)2
# Sr(H8O5)2
# Sr(HO)2
# Pnma -> Pmc2_1 (394.05K, 66.47 J/kgK)
# Sr(IO)2
# Sr(IO3)2
# P2_12_12_1 -> P2_1 (510.93K, 30.61 J/kgK)
# Sr(InTe2)2
# Sr(PO3)2
# Sr(SO5)2
# P6_2 -> P3_2 (517.82K, 51.52 J/kgK)
# Sr(SbO3)2
# Sr(YS2)2
# Sr10P6BrO24F
# Sr10P6ClO24F
# Sr20P12Br(O16F)3
# Sr2AlGaCo2O7
# Sr2As2O7
# Sr2Bi2O5
# P2_1/m -> Pnma (373.66K, 10.01 J/kgK)
# Sr2Bi2Se3O2
# P2_1/c -> C2/m (315.01K, 7.04 J/kgK)
# Sr2BiSbO6
# Sr2CaI6
# Sr2CaMoO6
# Pmm2 -> Fm-3m (480.34K, 23.92 J/kgK)
# Sr2CaTi3O9
# Pm -> P1 (569.29K, 17.84 J/kgK)
# Sr2CaV2(Si2O7)2
# Sr2CaWO6
# Fm-3m -> Pmm2 (378.06K, 9.89 J/kgK)
# Sr2CdWO6
# Pmm2 -> Fm-3m (489.86K, 21.24 J/kgK)
# Sr2CeHfO6
# Sr2CeSnO6
# Sr2CeZrO6
# Sr2Co(ClO)2
# I4/mmm -> P1 (558.99K, 131.27 J/kgK)
# Sr2CoGe2O7
# Sr2CoO3
# Sr2CoSbO6
# Sr2CoWO6
# C2/m -> P2_1/c (429.76K, 38.33 J/kgK)
# Sr2CrSbO6
# Sr2DyBiO6
# Sr2DySbO6
# Sr2Fe2O5
# Sr2FeO3F
# Sr2FeSbO6
# Sr2FeWO6
# Sr2GaSbO6
# Sr2GdBiO6
# Sr2GdNbO6
# Sr2GdSbO6
# Sr2GeO4
# P2_1/c -> Pna2_1 (504.99K, 11.70 J/kgK)
# Sr2HfMgCrO6
# Sr2HfO4
# I4/mmm -> Pbam (435.55K, 119.50 J/kgK)
# P4_2/ncm -> I4_1/acd (546.93K, 33.52 J/kgK)
# I4_1/acd -> Pbam (592.03K, 126.85 J/kgK)
# P4_2/ncm -> Pbam (582.54K, 158.27 J/kgK)
# Sr2HfTiO6
# Sr2InSbO6
# Sr2La2MgTi3O12
# Sr2La2MnZnO8
# Sr2LaBiO6
# Sr2LaCl7
# Sr2LaI7
# P2_1 -> P2_1/c (501.37K, 13.35 J/kgK)
# Sr2LaMn2O7
# Sr2LaNbO6
# Sr2LaSbO6
# Sr2LiCdWO6
# Sr2LiCoWO6
# Sr2LiFeO3F
# Sr2LiV2(Si2O7)2
# Sr2LiZrCrO6
# Sr2LuNbO6
# Sr2LuTaO6
# Pnn2 -> Fm-3m (519.35K, 22.34 J/kgK)
# Sr2Mg(H4O3)2
# Sr2MgCdWO6
# Sr2MgCrO4
# Sr2MgCuMoO6
# Sr2MgCuWO6
# Sr2MgMoO6
# Sr2MgSi2O7
# Sr2MgTiFeO6
# Sr2MgV2(Si2O7)2
# Sr2MgWO6
# Sr2MgZn2Sn2(PO4)4
# Sr2MgZnMoO6
# Sr2MgZnWO6
# Sr2MgZrCrO6
# Sr2MgZrMnO6
# Sr2MnGaO5
# Sr2MnMoO6
# Sr2MnNbO6
# P1 -> P1 (590.37K, 89.97 J/kgK)
# P1 -> P1 (517.89K, 76.85 J/kgK)
# Sr2MnWO6
# Sr2Nb2O7
# Pna2_1 -> Cmc2_1 (520.84K, 49.74 J/kgK)
# Sr2NbBiO6
# Sr2NbCoO6
# Sr2NbFeO6
# Sr2NbGaO6
# Sr2NbInO6
# Sr2NbSbO6
# Sr2NdBiO6
# Sr2NdNbO6
# Sr2NdSbO6
# Sr2NiMoO6
# Sr2NiTeO6
# Sr2PrBiO6
# Sr2PrNbO6
# Sr2PrSbO6
# Sr2SiO4
# Sr2SmBiO6
# Sr2SmNbO6
# Sr2SmSbO6
# Sr2SnO4
# Sr2Ta2O7
# Cmcm -> Cmc2_1 (406.51K, 15.22 J/kgK)
# Sr2TaAlO6
# Sr2TaCoO6
# Sr2TaCrO6
# Sr2TaFeO6
# Sr2TaInO6
# Sr2TaMnO6
# Sr2TbBiO6
# Sr2TbNbO6
# Sr2TbSbO6
# Sr2TiMnO6
# I4/m -> Fm-3m (516.15K, 2.39 J/kgK)
# Sr2V2O7
# P4_1 -> P-1 (526.36K, 29.95 J/kgK)
# Sr2V3O9
# P1 -> Cc (419.70K, 38.14 J/kgK)
# P2_1/c -> Cc (549.61K, 36.78 J/kgK)
# Sr2VMoO6
# Sr2YBiO6
# Sr2YI7
# Sr2YMgCrO6
# Sr2YNbO6
# Sr2YSbO6
# Sr2YTaO6
# Sr2ZnMoO6
# Sr2ZnWO6
# I4/m -> P2_1/c (391.75K, 25.73 J/kgK)
# Sr2ZrTiO6
# Sr2ZrVO6
# Sr3(AsO4)2
# Sr3(BN2)2
# Sr3(CoO3)2
# P1 -> R-3c (535.74K, 11.21 J/kgK)
# Sr3(InN2)2
# Sr3As4
# Sr3CaI8
# Cm -> I4/mmm (397.56K, 1.84 J/kgK)
# Sr3GeO5
# P4/ncc -> I4cm (560.14K, 19.20 J/kgK)
# Sr3Hf2O7
# Sr3InNiO6
# Sr3La4O9
# Sr3LaMn2(WO6)2
# Sr3Li4Nb6O20
# Sr3Mg(FeO3)2
# Sr3MgO4
# Sr3MoN4
# C2/c -> Pbca (335.39K, 16.63 J/kgK)
# Sr3NbCoO7
# Sr3NbGa3(SiO7)2
# Sr3Nd4O9
# Sr3P4
# Sr3SiO5
# Sr3TaCoO7
# Sr3Te4O11
# P1 -> P1 (413.04K, 24.77 J/kgK)
# Sr3TeO6
# Sr3UO6
# Sr3W2O9
# Sr3WO6
# Cc -> P1 (525.26K, 7.77 J/kgK)
# Sr3Y2(BO3)4
# Sr4Al6CrO16
# Sr4Al6MoO16
# Sr4Al6WO16
# Sr4Bi2O
# Sr4Br6O
# Sr4BrN2Cl
# Sr4CaMn2Ga2O11
# Sr4GeN4
# Sr4LaCl11
# P1 -> I4/mmm (302.34K, 40.50 J/kgK)
# Sr4Mg(Fe2O5)2
# Sr4MgFe4O11
# Sr4Nb2O9
# P1 -> Immm (464.08K, 21.46 J/kgK)
# Sr4Ta2O9
# Sr4ZrTi3O12
# Sr5Cr3ClO12
# Sr5Nb4O15
# Sr5Ta4O15
# Sr5W3O14
# Pbca -> Cc (485.95K, 8.72 J/kgK)
# Sr5ZrTi4O15
# Sr6Bi2O11
# Sr6Mg(W2O9)2
# Sr8MgMn6O20
# SrAl12O19
# SrAl2(SiO4)2
# SrAl2B2O7
# SrAl2O4
# SrAl4O7
# SrAlF5
# SrAlSi5N7O2
# SrB4O7
# Pmn2_1 -> P3 (541.07K, 54.88 J/kgK)
# SrBPO5
# SrBr2
# SrBrCl
# SrC2
# SrCN2
# SrCO3
# Warning: 2 transitions within this interval
# R32 -> C2/m (361.87K, 60.77 J/kgK)
# SrCa2I6
# P-31m -> Pbcn (579.41K, 19.64 J/kgK)
# SrCa3Zr16(PO4)24
# SrCaBiSbO6
# SrCaDyBiO6
# SrCaGdBiO6
# SrCaGdNbO6
# SrCaI4
# Imma -> Pbcn (383.05K, 28.13 J/kgK)
# SrCaLaBiO6
# SrCaLaSbO6
# SrCaMg14O16
# SrCaNdSbO6
# SrCaPrSbO6
# SrCaSmBiO6
# SrCaSmNbO6
# SrCaSmSbO6
# SrCaTbBiO6
# SrCaTi2O6
# SrCaTiMnO6
# SrCaYBiO6
# SrCdB2O5
# Warning: 2 transitions within this interval
# C2/c -> Pbca (318.21K, 47.73 J/kgK)
# SrCeN2
# P1 -> I4_1/amd (592.77K, 122.87 J/kgK)
# SrCo(GeO3)2
# P1 -> P1 (355.63K, 29.93 J/kgK)
# SrCo2(AsO4)2
# SrCrF4
# SrCrP2O7
# SrCu2GeS4
# SrEr2O4
# SrF2
# SrFe12O19
# SrGa2(SiO4)2
# SrGaBO4
# Pbam -> P2_12_12 (336.94K, 31.06 J/kgK)
# SrGe(PO4)2
# SrGeO3
# C2/c -> P-1 (312.93K, 20.11 J/kgK)
# SrH2
# SrH2(CO2)2
# SrH4O3
# SrHfO3
# Cmcm -> Imma (369.90K, 39.88 J/kgK)
# P4mm -> Pm-3m (411.66K, 0.42 J/kgK)
# SrI2
# Pnma -> Pbca (526.62K, 36.75 J/kgK)
# SrLa11Mg3Ga9O34
# Cm -> P1 (517.99K, 7.95 J/kgK)
# SrLa2Cl8
# SrLa2O4
# SrLa3Mn4O10
# SrLa4TiAl4O15
# SrLa7TiGa7O24
# SrLaCl5
# SrLaCoO4
# SrLaDySnO6
# SrLaFeO4
# SrLaI5
# Cc -> C2/c (483.27K, 1.88 J/kgK)
# SrLaTaNiO6
# SrLaTiFeO6
# SrLaTiMnO6
# SrLaVFeO6
# SrLi2Nb2O7
# SrLi2Ta2O7
# Cmcm -> I4/mmm (452.18K, 61.08 J/kgK)
# SrLi4NiO4
# SrLiAlF6
# SrLiAlO3
# SrLiLa3MnO8
# SrLiNb2O6F
# SrLiNdCoO4
# SrLiP
# SrLiPrTeO6
# SrLiSb
# SrLiTi4CrO11
# SrLu2O4
# SrMg14CO16
# SrMg14CdO16
# SrMg14CoO16
# SrMg14FeO16
# SrMg14MnO16
# SrMg14NiO16
# SrMg14VO16
# SrMg14ZnO16
# Pmmm -> P4/mmm (568.77K, 11.99 J/kgK)
# SrMg3O4
# SrMgF4
# SrMgFe2(SeO3)4
# SrMgO2
# SrMnO3
# P6_3mc -> P6_3mc (556.31K, 109.76 J/kgK)
# SrMoO4
# SrN6
# SrNd2O4
# SrNdCoO4
# SrO
# SrO2
# SrS
# SrSO4
# SrSeO3
# SrSiO3
# SrSm2O4
# SrSmCoO4
# SrSn(PO4)2
# SrSnN2
# SrSnO3
# I4/mcm -> Imma (447.87K, 31.98 J/kgK)
# SrTa2Bi2O9
# Aea2 -> I4/mmm (476.52K, 11.82 J/kgK)
# SrTaNO2
# Pm -> Pmc2_1 (582.68K, 24.36 J/kgK)
# SrTeO3
# SrTi(PO4)2
# SrTiO3
# Warning: 2 transitions within this interval
# I4/mcm -> Pm-3m (303.93K, 40.60 J/kgK)
# SrUO4
# SrV2(AsO5)2
# SrV2(PO5)2
# SrV3O7
# Pmmn -> Pnma (520.63K, 54.67 J/kgK)
# SrV4O10
# SrVSi2O7
# SrWN3
# SrZnF2
# SrZr2SnO6
# SrZrO3
# Ta2Co4O9
# P-3c1 -> P1 (547.41K, 34.90 J/kgK)
# Ta2CrNO5
# P2_1 -> Cmmm (364.84K, 26.40 J/kgK)
# Pm -> Cmmm (486.62K, 42.98 J/kgK)
# Ta2CrO6
# Ta2FeO6
# P2_12_12 -> P2 (469.34K, 32.00 J/kgK)
# P4_2/mnm -> P2 (392.26K, 53.34 J/kgK)
# Ta2H4O7
# Ta2Mn4O9
# Ta2MnO6
# Pbcn -> C2/c (522.26K, 39.21 J/kgK)
# Pnnm -> P2/c (592.36K, 68.27 J/kgK)
# Ta2O5
# Warning: 2 transitions within this interval
# Pmmn -> P2/m (355.85K, 14.34 J/kgK)
# Ta2Pb2O7
# Ta2PbO6
# Ta2WO8
# Ta2Zn2CrO8
# Ta2Zn4O9
# Ta2ZnO6
# Ta3AgO8
# Ta3Bi7O18
# Ta3InO9
# Ta6Pb4O19
# Ta7BiO19
# TaAgO3
# TaAl(WO4)2
# TaAlO4
# TaAsO4
# TaAsO5
# TaBi3O7
# TaBi4ClO8
# TaBiO4
# TaBr5
# Pnma -> C2/m (392.01K, 11.68 J/kgK)
# TaCr3(AgS4)2
# TaCrO4
# TaF5
# TaFeO4
# Pna2_1 -> Cmmm (433.07K, 71.97 J/kgK)
# TaGaO4
# TaIn3O7
# C222_1 -> Pnma (319.37K, 47.90 J/kgK)
# TaMnO4
# TaNO
# TaNb(AgO3)2
# TaNbO5
# TaO2F
# TaOF3
# TaP4(SCl)5
# TaPO5
# TaSb3O8
# Pc -> P1 (380.69K, 18.65 J/kgK)
# TaTeCl9
# TaVO4
# TaVO5
# TaZn2WO6
# TaZnBiO5
# Tb(BO2)3
# Tb(HO)3
# Tb2(MoO4)3
# Tb2(WO4)3
# Tb2Mg(NiO3)2
# Tb2MgS4
# Tb2MgSe4
# Tb2O3
# Tb2Pb2O7
# Tb2S3
# Tb2SeO2
# Tb2Te4O11
# Tb2Ti2O7
# Fd-3m -> P4_12_12 (409.23K, 24.79 J/kgK)
# Tb2TiO5
# Tb2WO6
# Tb2Zr2O7
# Tb3Fe5O12
# Tb3NbO7
# Tb3SbO7
# Tb3TaO7
# Tb5Mg(MoO6)2
# TbAl3(BO3)4
# C2/c -> R32 (408.21K, 15.85 J/kgK)
# TbCl3
# TbCuSe2
# P2_1/c -> P3m1 (528.67K, 55.07 J/kgK)
# TbCuTe2
# TbErO3
# TbFe3(BO3)4
# TbGaO3
# TbHO2
# TbNbO4
# TbOF
# TbPO4
# TbPaO4
# TbSbO4
# TbTa3O9
# TbTaO4
# Te(HO)6
# Te(HO2)2
# Te(S2O7)2
# Te(WO4)2
# Te2Mo
# Te2Pb3(ClO3)2
# Te2W
# P-6m2 -> P3m1 (305.64K, 15.31 J/kgK)
# P6_3/mmc -> P3m1 (404.54K, 34.57 J/kgK)
# P6_3/mmc -> P-6m2 (512.95K, 18.14 J/kgK)
# Te3WO12
# Te4As2S(OF6)2
# Te4Mo(OF4)5
# Te4MoW
# Te6Mo2W
# Te6MoW2
# Te7(OF5)6
# TeAs(SeF3)2
# TeF6
# TeHO3
# TeI
# TeI4
# TeO2
# P4_12_12 -> P4_32_12 (533.33K, 7.87 J/kgK)
# Pbca -> P4_32_12 (326.80K, 11.38 J/kgK)
# TeO3
# TePb
# TePb2O5
# Cc -> C2/c (332.43K, 32.56 J/kgK)
# TePbO3
# TeSeO4
# P1 -> P1 (342.31K, 19.34 J/kgK)
# TeWO6
# Ti(FeO2)2
# Ti(FeO2)3
# Ti(GeO3)2
# Ti(PO3)4
# Ti(PS3)2
# Ti(SO4)2
# Ti(SiO3)2
# Ti(WO4)2
# Ti2Bi2O7
# Ti2CdO6
# Ti2CoO5
# Ti2Fe4O9
# Cc -> P-1 (501.64K, 66.32 J/kgK)
# Ti2FeO5
# Ti2ZnO5
# Ti3(BiO3)4
# Ti3Fe(BiO3)5
# Ti3Fe5O12
# Ti3Fe9O16
# Ti3H2O7
# Ti3N2O3
# Ti3V5O16
# Cm -> P1 (301.83K, 19.04 J/kgK)
# Ti3Zn2O8
# Ti4Bi2O11
# Ti4Fe(PO4)6
# Ti4Zn3SnO12
# TiAl2O5
# TiAs2O7
# TiBi2O5
# TiBr4
# P2_1/c -> Pa-3 (519.30K, 8.12 J/kgK)
# TiCdO3
# Pna2_1 -> Pnma (505.78K, 22.36 J/kgK)
# TiCo3O8
# TiF4
# TiFe11O16
# TiFe2O5
# TiFeO3
# TiGa2O5
# TiMn(PO4)2
# TiMn2O6
# TiMn3O8
# TiMnO3
# TiNF
# TiNb(BiO3)3
# TiNb2O7
# TiNi(PO4)2
# TiO2
# Pmm2 -> Fm-3m (478.58K, 62.64 J/kgK)
# Pmmn -> P1 (551.65K, 45.09 J/kgK)
# R-3m -> P1 (374.37K, 65.51 J/kgK)
# Pbcn -> Imma (466.48K, 82.72 J/kgK)
# TiOF2
# TiP2O7
# TiPHO5
# TiPN3
# TiPO4F
# TiPbO3
# P4mm -> P-1 (404.25K, 6.95 J/kgK)
# TiS2
# TiSCl6O
# TiSO5
# TiSiO4
# TiSnO3
# TiSnO4
# TiV3O8
# P1 -> P1 (561.95K, 49.06 J/kgK)
# TiVO4
# P1 -> Cm (302.47K, 2.60 J/kgK)
# Cm -> Pmn2_1 (405.85K, 10.30 J/kgK)
# P1 -> Pmn2_1 (382.36K, 12.98 J/kgK)
# TiZn(BiO3)2
# TiZn(GeO3)2
# TiZn2O4
# TiZnO3
# TiZnSnO4
# U(HO2)2
# Cmce -> Cmc2_1 (562.64K, 75.02 J/kgK)
# U(MoO6)2
# U(OF)2
# U3(HO5)2
# UAg2(WO5)2
# UBi4(AsO8)2
# UCO5
# UCdO4
# UO3
# Fddd -> I4_1/amd (363.93K, 20.48 J/kgK)
# UOF4
# US2O9
# USO6
# UTeO5
# V(CO3)2
# P1 -> P1 (533.35K, 118.90 J/kgK)
# V(GeO3)2
# V(PO3)3
# V(PO3)4
# C2/m -> C2/c (509.60K, 68.65 J/kgK)
# V(SO4)2
# V(SiO3)2
# V(WO4)2
# V2(OF)3
# V2(SO4)3
# V2Bi4O11
# V2Bi8O17
# V2CdO6
# V2CoO6
# V2CrO6
# V2FeO4
# V2FeO6
# V2MoO8
# V2NiO6
# V2O3
# V2O3F
# Amm2 -> C2/m (454.21K, 85.14 J/kgK)
# Amm2 -> Amm2 (531.88K, 32.34 J/kgK)
# C2 -> C2/m (497.32K, 115.12 J/kgK)
# Amm2 -> C2/m (474.41K, 117.77 J/kgK)
# P1 -> Pna2_1 (478.69K, 154.00 J/kgK)
# V2O5
# Warning: 2 transitions within this interval
# C2/m -> P2/c (425.28K, 84.08 J/kgK)
# V2OF5
# C2 -> P3_121 (450.42K, 235.21 J/kgK)
# P1 -> P1 (306.17K, 199.76 J/kgK)
# P1 -> P1 (377.68K, 138.43 J/kgK)
# P1 -> P3_121 (504.51K, 166.56 J/kgK)
# V2OF7
# V2P2O7
# V2P2O9
# V2Pb3O8
# V2PbO6
# V2Si2O7
# V2SiO4
# V2Te2O9
# V2Zn2O7
# V2ZnO4
# V2ZnO5
# V2ZnO6
# C2/m -> C2 (493.86K, 98.17 J/kgK)
# V3(H3O5)2
# P1 -> P4bm (486.02K, 32.59 J/kgK)
# V3(HO2)4
# V3(O2F)2
# C2/m -> Cm (580.50K, 198.70 J/kgK)
# C2/m -> P1 (403.01K, 126.30 J/kgK)
# P-1 -> P1 (495.64K, 188.24 J/kgK)
# P4_2nm -> P1 (581.08K, 178.16 J/kgK)
# V3(OF3)2
# V3(PO4)2
# V3(PO4)4
# V3As2O9
# V3CoO8
# V3CrO8
# V3O2F5
# V3O5
# V3O5F
# V3O7
# V3O8
# V3OF11
# V3OF7
# V3Pb2O9
# V3Zn2O8
# V4(OF3)3
# V4O5F7
# V4OF11
# P1 -> P-1 (300.68K, 105.46 J/kgK)
# P1 -> P1 (487.29K, 16.37 J/kgK)
# V4ZnO10
# V5O12
# V5O9
# V5W3O20
# P-1 -> P1 (588.39K, 57.48 J/kgK)
# V6H2Pb4Se3O26
# V6O7F5
# C2 -> P1 (512.16K, 35.17 J/kgK)
# V7O13
# V9O22
# VAg3O4
# VAgO3
# VAs2H4O9
# VAsO5
# VBO4
# VBi(PbO3)2
# P2_1/c -> Pc (387.41K, 0.93 J/kgK)
# VBiO4
# C2/c -> Pbcn (490.52K, 2.51 J/kgK)
# VBiPbO5
# VCd2N3
# VCl2O
# Warning: 2 transitions within this interval
# P1 -> P-1 (310.76K, 66.24 J/kgK)
# VCrO3
# VCrO4
# Cmcm -> C2/m (502.07K, 106.81 J/kgK)
# VCuO3
# VF3
# VF4
# Pnma -> C2/c (540.36K, 168.58 J/kgK)
# P2_1/c -> Pbam (346.33K, 84.96 J/kgK)
# Pnma -> Pc (301.49K, 70.30 J/kgK)
# VF5
# P2_1 -> Cmce (535.62K, 134.39 J/kgK)
# P2_12_12_1 -> Cmce (556.90K, 134.16 J/kgK)
# VFeO4
# VH10SO10
# VHO3
# VInO4
# VMoO5
# P1 -> P1 (367.64K, 58.48 J/kgK)
# VO
# VO2
# P1 -> P1 (483.13K, 30.53 J/kgK)
# VO2F
# Cc -> P1 (474.95K, 63.49 J/kgK)
# P2_1/c -> Cc (504.46K, 105.21 J/kgK)
# P2_1/c -> P1 (493.14K, 168.78 J/kgK)
# P1 -> P1 (593.98K, 266.74 J/kgK)
# P2_1/c -> P2_12_12_1 (408.99K, 150.11 J/kgK)
# P1 -> P2_12_12_1 (536.92K, 254.42 J/kgK)
# VOF
# P-1 -> Cmmm (559.02K, 33.98 J/kgK)
# P-1 -> P-1 (350.43K, 103.30 J/kgK)
# P2/m -> P2_1/c (449.14K, 36.21 J/kgK)
# P-1 -> Pm (432.99K, 86.82 J/kgK)
# VOF2
# Cc -> P-1 (567.31K, 348.57 J/kgK)
# P-1 -> P-1 (394.77K, 98.88 J/kgK)
# P1 -> P-1 (423.23K, 214.54 J/kgK)
# P1 -> P-1 (585.69K, 163.39 J/kgK)
# P1 -> P-1 (570.78K, 386.75 J/kgK)
# Cc -> P1 (551.56K, 185.02 J/kgK)
# P1 -> P-1 (449.29K, 115.22 J/kgK)
# P1 -> P1 (310.89K, 43.46 J/kgK)
# P1 -> P1 (560.11K, 223.26 J/kgK)
# VOF3
# P2_1/c -> C2 (566.58K, 106.42 J/kgK)
# Pna2_1 -> C2 (310.25K, 32.51 J/kgK)
# P-42_1m -> Pc (587.61K, 217.13 J/kgK)
# P1 -> Pc (350.33K, 136.23 J/kgK)
# P2_1 -> Pc (456.76K, 145.75 J/kgK)
# P2_12_12_1 -> Pc (424.45K, 165.59 J/kgK)
# VP2O7
# VPO4
# VPO4F
# VPO5
# C2/m -> P4/n (361.13K, 107.19 J/kgK)
# C2/m -> P4/nmm (489.65K, 81.31 J/kgK)
# P4_2/mbc -> Cc (580.33K, 85.11 J/kgK)
# Cc -> Pnma (592.39K, 145.57 J/kgK)
# P4_2/mbc -> Pnma (587.86K, 225.79 J/kgK)
# VPPbO6
# VPb2N3
# VSO5
# VWO4
# VZn(SiO3)2
# VZn2WO6
# VZnBiO5
# VZnP2O7
# VZnPO5
# W(BrO)2
# W(ClO)2
# W(OF)2
# W2O5
# W3(Se2S)2
# W3(SeS2)2
# W3O8
# W5(O2F11)2
# W7(OF5)6
# WBr4O
# WCl6
# R-3 -> P-3m1 (502.03K, 130.50 J/kgK)
# WF5
# WN2
# P-6m2 -> C2/m (305.67K, 170.88 J/kgK)
# I-42d -> Pna2_1 (491.76K, 49.50 J/kgK)
# Pna2_1 -> Pna2_1 (366.05K, 40.60 J/kgK)
# P-6m2 -> P6_3/mmc (308.72K, 141.92 J/kgK)
# Pna2_1 -> P3_121 (470.26K, 27.95 J/kgK)
# WO2
# WO3
# P2_1/m -> Pnma (505.64K, 24.93 J/kgK)
# P4/ncc -> P-1 (446.01K, 5.08 J/kgK)
# Pbcm -> Pbcn (419.91K, 32.31 J/kgK)
# Pm-3m -> Pmma (530.34K, 93.96 J/kgK)
# WOF4
# C2/c -> P2_1/c (447.79K, 62.46 J/kgK)
# WS2
# P3m1 -> P6_3/mmc (433.50K, 43.23 J/kgK)
# WSCl4
# WSe2
# WSeS
# Xe
# Cmce -> R-3m (492.52K, 2.03 J/kgK)
# R-3m -> P6_3/mmc (554.84K, 1.93 J/kgK)
# XeF6
# Y(BO2)3
# Y(FeO2)2
# Y(HO)3
# P6_3/m -> P6_3 (539.08K, 33.70 J/kgK)
# Y(PO3)3
# Cc -> P2_1/c (550.51K, 15.39 J/kgK)
# R-3 -> P2_1/m (361.48K, 60.04 J/kgK)
# Y2(MoO4)3
# Pba2 -> P-42_1m (348.51K, 30.86 J/kgK)
# Y2(SO4)3
# Y2(SeO4)3
# Y2AlN3
# Y2BeAlBO7
# Y2C(NO)2
# Y2Cr3O12
# Y2GaN3
# Y2Ge2O7
# Y2GeO5
# Y2Hf2O7
# Y2HfO5
# P2_1/m -> C2/c (583.94K, 36.51 J/kgK)
# C2/c -> Pnma (435.38K, 66.58 J/kgK)
# P2_1/m -> Pnma (483.22K, 104.11 J/kgK)
# Y2Hg2O5
# Y2HgO4
# Y2MgBi2O7
# Y2MgMo2(ClO4)2
# Y2MgS4
# Y2MgSe4
# Y2MgV2O7
# Y2O3
# P-3m1 -> R-3c (310.68K, 18.98 J/kgK)
# Y2S3
# Y2Se3
# Y2SeO2
# Y2Si2O7
# Y2SiO5
# Y2TeO6
# Y2Ti2O7
# Y2W2O9
# Pbcn -> C222_1 (555.46K, 56.83 J/kgK)
# Y2WO6
# Y2ZnS4
# Y2Zr2O7
# Y3AlO6
# Y3NbO7
# Y3TaO7
# Y4Ga2O9
# Y4Mg(BiO3)4
# Y4S3N2
# Y4Zr3O12
# Y5Mg(MoO6)2
# Y5O4F7
# Y6O5F8
# Warning: 2 transitions within this interval
# P2_1/c -> P2_12_12 (357.15K, 2.85 J/kgK)
# Y7(O2F3)3
# YAg(WO4)2
# YAgS2
# YAgSe2
# YAgTe2
# YAlN2
# YAlO3
# YB3(H6N)4
# YBO3
# YBi(WO4)2
# YBiO3
# YBr3
# YBrO
# P4/nmm -> R-3m (442.70K, 9.24 J/kgK)
# YClO
# YCrO3
# YCu(WO4)2
# P2/c -> P-1 (396.10K, 13.89 J/kgK)
# P2/c -> P1 (369.35K, 14.14 J/kgK)
# YCuO2
# P6_3/mmc -> R-3m (356.98K, 34.93 J/kgK)
# YCuPbS3
# YCuS2
# YF3
# YFe(WO4)2
# YFe3(BO3)4
# YFeO3
# YGaN2
# YHO2
# YIO
# YLuO3
# YMg14NiO16
# YMgAg(WO4)2
# YMgCu(WO4)2
# YMgMo3O8
# YMn(WO4)2
# YMo(WO4)2
# YMo3O8
# YN
# YNO4
# YNb2NO5
# YNbO4
# YOF
# YP5O14
# YPO4
# YPaO4
# YSF
# YSb(PbO3)2
# YSbO3
# YSeF
# YSeO3F
# YSiNO2
# YSnF7
# YTa(WO4)2
# YTa3O9
# YTaO4
# YTi(WO4)2
# YV(WO4)2
# YVO3
# YVO4
# YW3O8
# YWN3
# Pmc2_1 -> Ama2 (324.44K, 93.63 J/kgK)
# YZr3F15
# Zn(BH4)2
# Zn(BiO2)2
# Zn(C4N3)2
# Pmna -> Cm (597.16K, 221.10 J/kgK)
# Zn(CN)2
# P4_2nm -> P-43m (359.94K, 86.43 J/kgK)
# Zn(FeO2)2
# Cmcm -> Pbcm (301.07K, 33.47 J/kgK)
# Zn(GaS2)2
# Zn(HO)2
# Zn(InS2)2
# Zn(InSe2)2
# Zn(MoO2)2
# Zn(NCl2)2
# Zn(NO3)2
# Zn(PO3)2
# Zn(PbN)2
# Zn(SbO2)2
# Zn(SbO3)2
# Zn(SnO2)2
# Zn(WO2)2
# Zn2As2O7
# Zn2BiWO6
# Zn2CoWO6
# Zn2CrWO6
# Zn2FeWO6
# Zn2Ga2S5
# Zn2MoWO6
# Zn2P2O7
# Zn2PHO5
# P-1 -> Pnnm (588.20K, 71.42 J/kgK)
# Zn2SbWO6
# Zn2SeCl2O3
# Zn2SeS
# Zn2SiH2O5
# Zn2SiO4
# Zn2Sn3O8
# Zn2SnWO6
# Zn3(AsO3)2
# Zn3(BO3)2
# C2/c -> Cc (394.38K, 3.46 J/kgK)
# P-1 -> C2/c (426.81K, 37.26 J/kgK)
# P-1 -> Cc (423.92K, 41.71 J/kgK)
# Zn3(PO4)2
# Zn3B7IO13
# Zn3BPO7
# Zn3CdSe4
# Zn3In2O6
# Zn3TeP2Pb3O14
# Zn4CdSe5
# Zn5(SiN3)2
# Zn8B4H3O15F
# ZnAg2C4(SN)4
# ZnAgF3
# ZnAgPO4
# ZnAu2(CN)4
# ZnB4O7
# ZnBiF5
# ZnBiMoO5
# ZnBiSbO5
# ZnBiWO5
# ZnBr2
# C2/m -> R-3m (357.46K, 116.86 J/kgK)
# ZnCdS2
# ZnCdSe2
# P3m1 -> R3m (321.92K, 8.95 J/kgK)
# ZnCdTe2
# ZnCl2
# Pna2_1 -> I-42d (431.64K, 48.65 J/kgK)
# ZnCo(GeO3)2
# ZnCo(SiO3)2
# ZnCoF5
# ZnCoO2
# ZnCoP2O7
# ZnCr2O4
# Pbcm -> Pnma (524.61K, 48.28 J/kgK)
# ZnCrBiO5
# ZnCrF5
# ZnCrO4
# ZnCrP2O7
# ZnCu2SiS4
# ZnCuF4
# P1 -> Ima2 (419.03K, 13.81 J/kgK)
# ZnF2
# P4_2/mnm -> Pbcn (458.40K, 52.22 J/kgK)
# ZnFe(GeO3)2
# ZnFe(SiO3)2
# ZnFe4CoO8
# ZnFeF5
# ZnFeP2O7
# ZnFePO5
# ZnGaP2H4NO8
# P2_1 -> P1 (348.75K, 139.51 J/kgK)
# ZnGe2WO6
# ZnGeN2
# ZnGeO3
# ZnH2(CO2)2
# ZnH6
# ZnH7C3NO6
# ZnI2
# ZnMoF5
# ZnMoO4
# ZnN6
# ZnNi(GeO3)2
# P2_1/c -> P1 (534.12K, 45.14 J/kgK)
# ZnNiO2
# ZnNiP2O7
# ZnNiP2WO9
# ZnO
# ZnO2
# ZnP2
# P4_32_12 -> P2_1/c (361.71K, 53.39 J/kgK)
# ZnP2(H4O5)2
# ZnP4O11
# ZnPH5C2N4O3
# ZnS
# F-43m -> P3m1 (461.08K, 85.46 J/kgK)
# F-43m -> P6_3mc (447.27K, 75.55 J/kgK)
# P6_3mc -> P3m1 (584.36K, 9.60 J/kgK)
# ZnSO4
# ZnSbF5
# ZnSe
# ZnSeO3
# ZnSeO4
# Pnma -> Cmcm (334.00K, 21.59 J/kgK)
# ZnSi2NiO6
# ZnSi2SnO6
# ZnSiO3
# ZnSn(GeO3)2
# ZnSn2(PO4)2
# ZnSnO2
# ZnSnO3
# ZnSnP2O7
# ZnTe
# ZnTe(H2N)4
# ZnTe2O5
# ZnWO4
# Zr(MoO4)2
# Zr(PO3)4
# Zr(Se2Cl3)2
# Warning: 2 transitions within this interval
# Pccn -> P4_2/ncm (367.83K, 15.41 J/kgK)
# Zr(WO4)2
# Zr11VO24
# Zr2Bi2O7
# P2_1 -> Fd-3m (441.27K, 36.51 J/kgK)
# Zr2N2O
# Cc -> C2 (456.56K, 29.06 J/kgK)
# Cc -> C2/c (571.98K, 41.40 J/kgK)
# P-1 -> C2/m (429.04K, 10.63 J/kgK)
# P1 -> C2/m (574.99K, 28.60 J/kgK)
# Zr2P2O9
# Warning: 2 transitions within this interval
# Cmce -> C2/m (528.92K, 29.92 J/kgK)
# Zr2P2SO12
# Zr2SN2
# Zr2Ti(PbO3)3
# Zr2Ti3(PbO3)5
# Zr3BiF15
# Zr3N2O3
# Zr3N4
# Zr3Ti(PbO3)4
# Zr3Ti2(PbO3)5
# Zr4N2O5
# Zr4Ti(PbO3)5
# Zr5Ti7O24
# Zr7(NO2)4
# Zr7VO16
# ZrBrN
# ZrCrAgS4
# ZrCrCuS4
# ZrF4
# C2/c -> P2_1/c (314.75K, 41.83 J/kgK)
# ZrH6O3F4
# ZrI4
# ZrIN
# ZrMnO3
# ZrMoWO8
# ZrNCl
# ZrO2
# Pbca -> Pca2_1 (469.86K, 99.51 J/kgK)
# ZrP2(HO3)2
# ZrP2O7
# ZrPbO3
# ZrSO
# P2_13 -> P4/nmm (457.68K, 269.22 J/kgK)
# ZrSeO
# ZrSiO4
# ZrTi(PbO3)2
# ZrTi2(PbO3)3
# ZrTiO4

# %% [markdown]
# # Visualize the results

# %%
# Convert to panda data-frames for easy handling
stable_transition_phases   = pd.DataFrame(stable_transition_phases)
metastable_transition_phases = pd.DataFrame(metastable_transition_phases)

# %%
stable_transition_phases_low_uncert   = stable_transition_phases[stable_transition_phases['uncert-ML']     < 200]
metastable_transition_phases_low_uncert = metastable_transition_phases[metastable_transition_phases['uncert-ML'] < 200]

# %% [markdown]
# ## First N stable materials highest entropy changes

# %%
# Save to excel
df_es_stp = stable_transition_phases_low_uncert.sort_values(by='entropy-change', ascending=False)
df_es_stp.to_excel(f'{output_folder}/high-entropy stable transitions.xlsx')
df_es_stp
# Out:
#          compound polymorph-1 polymorph-2  transition-temperature  \
# 83              C        R-3m    P6_3/mmc              594.464853
# 23           BHO2       P-43n      P2_1/c              370.649853
# 451  LuH9C5(NO4)2      C222_1          C2              535.636410
# 188  DyH9C5(NO4)2      C222_1          C2              572.724425
# 483          MgO2        Pa-3        R-3m              595.059156
# ..            ...         ...         ...                     ...
# 218        HPbClO        Pnma        C2/m              431.278696
# 588         Pb3O4        Pbam    P4_2/mbc              554.251545
# 673       TbCuSe2      P2_1/c        P3m1              528.665519
# 265      KBaGdWO6       F-43m        Pnnn              319.492605
# 297       La2Se2O        Pnma      P2_1/c              400.673128
#
#      entropy-change  centrosymmetry  conductivity-change  LTC-1  LTC-2  \
# 83      3190.565583               2                  NaN    NaN    NaN
# 23       985.601026               1                  NaN    NaN    NaN
# 451      677.830458               0                  NaN    NaN    NaN
# 188      633.064859               0                  NaN    NaN    NaN
# 483      618.290294               2                  NaN    NaN    NaN
# ..              ...             ...                  ...    ...    ...
# 218       60.926344               2                  NaN    NaN    NaN
# 588       57.912452               2                  NaN    NaN    NaN
# 673       55.069363               1                  NaN    NaN    NaN
# 265       44.721603               1                  NaN    NaN    NaN
# 297       34.675404               2                  NaN    NaN    NaN
#
#       uncert-ML  uncert-DFT
# 83    62.401471   13.738127
# 23    98.981330   49.071970
# 451  124.187744   44.093297
# 188  139.678280   48.802709
# 483  136.281770   39.248485
# ..          ...         ...
# 218  190.492750   89.591409
# 588  125.411226   71.084264
# 673  156.417918   95.458781
# 265  197.386172  159.058690
# 297  175.317398  147.011967
#
# [76 rows x 11 columns]
