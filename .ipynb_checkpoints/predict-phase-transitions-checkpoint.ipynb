# %%
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd
import seaborn           as sns
import os
import torch
import json

from libraries.model   import Helmholtz_free_energy_function, make_predictions, GCNN, compute_coefficients
from libraries.dataset import load_atomic_masses, include_temperatures, create_predictions_dataset, standardize_dataset_from_keys

# Checking if pytorch can run in GPU, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

sns.set_theme()

# %% [markdown]
# In this notebook you are able to load an use a pre-trained model for predicting the lattice contribution to the free-energy over an input database. The model, $GCNN$, predicts the lattice contribution to the free-energy, $F_v(m, T) = GCNN(m, T)$, for material $m$ at temperature $T$. Then, knowing the ground-state energy of material $m$, $E_0 (m)$ (typically estimated from DFT), the Helmholtz free-energy reads from:
#
# \begin{equation}
#     F(m, T) = E_0 (m) + F_v(m, T)
# \end{equation}
#
# Importantly, this approach disregards any other contribution to the free-energy that just vibrational (e.g., metallic materials should be avoided).
#
# The baseline pretrained model has been trained in the 100 to 700 K temperature range, thus it is recommended to make predictions within the 200 to 600 K range, in order to avoid the misbehaviour of $C_p$ at high temperature.
#
# We implemented a tool which allows estimating the quality of the predicted free energy regarding 1) the chemistry of the target material and 2) the temperature at which the prediction is made. This approach is valid for any other input model, as it directly checks the proximity of the hyper-representation that the GCNN creates for the target material and this from any known prediction.
#
# Ferromagnetic transitions are estimated based on pure geometrical reasons, predicted as any transition involving a non-centrosymmmetric space group.
#
# The input database should contain on each folder a POSCAR file with the structure, a file name EPA with the energy per atom in eV/atom (typically from DFT) and, optionally, a file name LTC with the lattice thermal conductivity in W/mK. It should be strucuture like:
#
# **database**
# &nbsp;**material-1**
# &nbsp;&nbsp;&nbsp;**polymorph-1**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- POSCAR
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- EPA
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- LTC (opt)
# &nbsp;&nbsp;&nbsp;**polymorph-2**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- POSCAR
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- EPA
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;- LTC (opt)
# &nbsp;&nbsp;&nbsp;**polymorph-...**
# &nbsp;**material-2**
# &nbsp;&nbsp;&nbsp;**polymorph-...**
# &nbsp;**material-...**

# %% [markdown]
# # Define parameters

# %%
model_folder    = 'model'  # Pre-trained model and dataset parameters
data_folder     = 'example-data'  # Example coefficients and labels of the target database
output_folder   = 'output'  # Output files and figures
input_folder    = 'input'  # General files (e.g., atomic masses information)
target_database = 'target_dataset'  # Target database

# Whether to plot the harmonic extrapolations of Fv (very time-consuming) or not
plot_extrapolations = False

# Defining the range of temperatures
Ti = 300
Tf = 600
dT = 50
temperatures = np.arange(Ti, Tf+dT, dT)  # Temperatures for prediction of free-energies

# Loading dictionary of atomic masses
atomic_masses = load_atomic_masses(f'{input_folder}/atomic_masses.dat')

# %% [markdown]
# # Perform predictions

# %% [markdown]
# For the sake of optimization, we first predict all free-energies in the target database. In order to do that, we read the parameters needed for standardizing the target dataset, load the pre-trained model, perform the predictions and smooth those with a fitting to a fourth-order polynomial (with respect to temperature).

# %%
if os.path.exists(f'{data_folder}/coefficients.txt') and os.path.exists(f'{data_folder}/labels.txt'):
    coefficients = np.loadtxt(f'{data_folder}/coefficients.txt')
    labels = [f'{label[0]} {label[1]}' for label in np.loadtxt(f'{data_folder}/labels.txt', dtype=str)]
else:
    # Load the data from the JSON file
    with open(f'{model_folder}/standardized_parameters.json', 'r') as json_file:
        numpy_dict = json.load(json_file)

    # Convert NumPy arrays back to PyTorch tensors
    standardized_parameters = {}
    for key, value in numpy_dict.items():
        try:
            standardized_parameters[key] = torch.tensor(value)
        except:
            standardized_parameters[key] = value

    # Load reference dataset for uncertainty estimation
    reference_dataset = torch.load(f'{model_folder}/ref_std_dataset.pt', weights_only=False)

    # Create dataset for predictions
    dataset = create_predictions_dataset(target_database)
    
    labels = [graph.label for graph in dataset]

    # Standardize properties
    std_dataset = standardize_dataset_from_keys(dataset, standardized_parameters)

    # Load Graph Neural Network model (making room for temperature as node attribute) to device
    # Dropout for initializing the model, not used at all while predicting
    model = GCNN(features_channels=dataset[0].num_node_features+1,
                 pdropout=0).to(device)

    # Free-up CUDA
    del dataset

    # Load and evaluate Graph Neural Network model
    model.load_state_dict(torch.load(f'{model_folder}/model.pt', map_location=torch.device(device)))
    model.eval()

    # Include temperatures
    std_dataset_w_temp = include_temperatures(std_dataset, temperatures, standardized_parameters)

    # Free-up CUDA
    del std_dataset

    # Compute predictions and corresponding uncertainties
    shot_predictions, shot_uncertainties = make_predictions(reference_dataset, std_dataset_w_temp, model, standardized_parameters)

    # Free-up CUDA
    del std_dataset_w_temp, reference_dataset

    # Computing the coefficients and uncertainties from fitting
    coefficients = compute_coefficients(temperatures, shot_predictions, shot_uncertainties, s=0.5)

    np.savetxt(f'{data_folder}/coefficients.txt', coefficients)
    np.savetxt(f'{data_folder}/labels.txt',       labels, fmt='%s')

# %% [markdown]
# coefficients = compute_coefficients(temperatures, shot_predictions, shot_uncertainties, s=0.6)
#
# count = 0
# for a in coefficients[0]:
#     count += np.isnan(a)
# count

# %% [markdown]
# # Compute phase transitions

# %% [markdown]
# Then, we have already computed the free-energies for each material in the intended temperature range and also the parameters of the fourth-order polynomial which smooths the predictions. With that information, we can look for phase transitions for each materials presenting at least two polymorphs in the target dataset and, for those, extract transition temperature, entropy change or whether this is or not a ferroelectric transition.

# %%
# Ordering by families
indexes       = np.argsort(labels)  # This way we put all the polymorphs from a same material together
labels        = np.array(labels)[indexes]
coefficients  = coefficients[:, indexes]

# Separating compounds and polymorphes
compounds, polymorphs = zip(*(line.split() for line in labels))

# Reading ground state energies (energy per atom)
# From eV/atom to meV/atom
gs_energies = [float(np.loadtxt(f'{target_database}/{comp}/{poly}/EPA')) * 1e3 for comp, poly in zip(compounds, polymorphs)]

# Reading conductivities (lattice thermal conductivities)
# In W/mK
conductivities = [float(np.loadtxt(f'{target_database}/{comp}/{poly}/LTC'))
                  if os.path.isfile(f'{target_database}/{comp}/{poly}/LTC') else np.nan for comp, poly in zip(compounds, polymorphs)]

# Reading centrosymmetris (1 is centrosymmetric, 0 is not)
centrosymmetries_list = np.array([np.loadtxt(f'{target_database}/{comp}/{poly}/is_centrosymmetric', dtype=int) for comp, poly in zip(compounds, polymorphs)])
space_groups_list     = np.array([np.loadtxt(f'{target_database}/{comp}/{poly}/space_group', dtype=str) for comp, poly in zip(compounds, polymorphs)])

# Unique compounds (not considering polymorphes)
unique_compounds, unique_counts = np.unique(compounds, return_counts=True)
unique_indexes = np.append([0], np.cumsum(unique_counts))  # So it starts with 0

# %%
# Initializing files with data
stable_transition_phases   = []
unstable_transition_phases = []
for i, compound in enumerate(unique_compounds):
    # Getting corresponding predictions
    index1 = unique_indexes[i]
    index2 = unique_indexes[i+1]

    static_energies          = gs_energies[index1:index2]
    lattice_conductivities   = conductivities[index1:index2]
    centrosymmetries         = centrosymmetries_list[index1:index2]
    space_groups             = space_groups_list[index1:index2]
    vibrational_coefficients = coefficients[:, index1:index2]

    n_polymorphs = index2 - index1
    if n_polymorphs > 1:
        print(compound)
        if plot_extrapolations:
            fig = plt.figure(figsize=(5, 5))

        free_energies = np.array([
            static_energies[k] + Helmholtz_free_energy_function(temperatures, *vibrational_coefficients[:, k])
            for k in range(n_polymorphs)
        ])

        for k in range(n_polymorphs):
            _beta_1         = vibrational_coefficients[:, k]
            static_energy_1 = static_energies[k]
            LTC_1           = lattice_conductivities[k]
            is_cts_1        = centrosymmetries[k]
            space_group_1   = space_groups[k]
            free_energies_1 = free_energies[k]

            # Plotting
            if plot_extrapolations:
                # Temperature range for plotting
                temperatures_plot = np.arange(Ti, Tf+dT, 0.1)

                # Smooth Gibbs energy for plotting
                gibbs_energy_plot = static_energy_1 + Helmholtz_free_energy_function(temperatures_plot, *_beta_1)
                plt.plot(temperatures_plot, gibbs_energy_plot, label=space_group_1)

            # Looking for phase transitions
            for m in np.arange(k+1, n_polymorphs):
                _beta_2         = vibrational_coefficients[:, m]
                static_energy_2 = static_energies[m]
                LTC_2           = lattice_conductivities[m]
                is_cts_2        = centrosymmetries[m]
                space_group_2   = space_groups[m]
                free_energies_2 = free_energies[m]

                # Computing the entropy change provoked by the transition
                d_E0 = static_energy_2 - static_energy_1
                d_alpha, d_beta, d_gamma = _beta_2 - _beta_1
                
                # We scaled parameters for fitting, so now we re-scale them
                d_beta  *= 1e-5
                d_gamma *= 1e-10
                
                # Two possible transition temperatures
                temp_root_1 = (-d_beta + np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha) * d_gamma)) / (2 * d_gamma)
                temp_root_2 = (-d_beta - np.sqrt(d_beta**2 - 4 * (d_E0 + d_alpha) * d_gamma)) / (2 * d_gamma)

                # Filter valid transition within the temperature range of interest
                c_valid_temperatures = [x for x in [np.sqrt(temp_root_1), np.sqrt(temp_root_2)] if Ti < x < Tf]

                # Determine if there is any transition within the temperature interval
                if not len(c_valid_temperatures):  # There is not a transition between these polymorphs
                    continue
                elif len(c_valid_temperatures) > 1:
                    print(f'Warning: {len(c_valid_temperatures)} transitions within this interval')

                # Get the expected critical temperature and free energy
                c_temperature = np.min(c_valid_temperatures)

                # Compute free energy and slope changes 
                c_free_energy = static_energy_1 + Helmholtz_free_energy_function(c_temperature, *_beta_1)
                d_slope       = c_temperature * np.abs(2 * d_beta + 4 * d_gamma * c_temperature**2)
                
                # Read atomic information for entropy change estimation
                with open(f'{target_database}/{compound}/{polymorphs[index1+k]}/POSCAR', 'r') as POSCAR_file:
                    POSCAR_lines = POSCAR_file.readlines()
                composition   = POSCAR_lines[5].split()
                concentration = np.array(POSCAR_lines[6].split(), dtype=float)

                # Get atomic mass involved in the transition
                total_mass = sum(float(atomic_masses[el]) * conc for el, conc in zip(composition, concentration))

                # Compute entropy change, from meV/atomK to J/kgK (1e3 as g goes to kg)
                c_entropy   = d_slope * 6.022 * 1.6 * 1e4 * concentration.sum() / total_mass

                # Check which has lower energy at lower temperature
                c_free_energy_1 = static_energy_1 + Helmholtz_free_energy_function(c_temperature-5, *_beta_1)
                c_free_energy_2 = static_energy_2 + Helmholtz_free_energy_function(c_temperature-5, *_beta_2)

                first_polymorph, last_polymorph = (space_group_1, space_group_2) if c_free_energy_1 < c_free_energy_2 else (space_group_2, space_group_1)
                first_LTC,       last_LTC       = (LTC_1,         LTC_2)         if c_free_energy_1 < c_free_energy_2 else (LTC_2,         LTC_1)
                label = f'{first_polymorph} -> {last_polymorph} ({c_temperature:.2f}K, {c_entropy:.2f} J/kgK)'
                print(label)
                
                if plot_extrapolations:
                    plt.plot(c_temperature, c_free_energy, 'o', label=label)

                # 0, 1, 2 if none, one or both are centrosymmetric, respectively
                centrosymmetric = is_cts_1 + is_cts_2
                
                # Get lattice thermal conductivity change
                
                # Divide by the centrysymmetric (nonpolar) polymorph LTC
                LTC_change = None
                if centrosymmetric == 1:
                    LTC_change = (last_LTC - first_LTC) / first_LTC

                # Appending information (compound name, involved phases in order,
                # temperature of transition, entropy change involved in the transition,
                # whether a non-centrosymmetric phase is involved or not, and lattice
                # thermal conductivity change)
                transition_data = {'compound': compound, 'polymorph-1': first_polymorph, 'polymorph-2': last_polymorph,
                                   'transition-temperature': c_temperature, 'entropy-change': c_entropy,
                                   'centrosymmetry': centrosymmetric, 'conductivity-change': LTC_change,
                                  'LTC-1': first_LTC, 'LTC-2': last_LTC}

                min_vib_energy = min(
                    static_energies[j] + Helmholtz_free_energy_function(c_temperature, *vibrational_coefficients[:, j])
                    for j in range(n_polymorphs)
                )

                if np.isclose(c_free_energy, min_vib_energy):
                    stable_transition_phases.append(transition_data)
                else:
                    unstable_transition_phases.append(transition_data)

        if plot_extrapolations:
            plt.title(compound)
            plt.xlabel('$T$ (K)')
            plt.ylabel(r'$F_{v}$ (meV/atom)')
            plt.legend(loc=(1.05, 0.5))
            plt.savefig(f'{model_folder}/{compound}.eps', dpi=50, bbox_inches='tight')
            plt.show()
# Out:
# Ag(CO)2
# Ag10Te4Br3
# Ag2B8O13
# P2_1 -> P2_1/c (544.02K, 42.17 J/kgK)
# Ag2HgI4
# Ag2Mo2O7
# Ag2PS3
# Ag2S
# P2_1/m -> P2_1 (577.70K, 62.01 J/kgK)
# Ag2SO4
# Ag2Se
# Ag2WO4
# Pnnm -> Pnn2 (422.57K, 19.84 J/kgK)
# Ag3AsS3
# Ag3AsSe3
# Ag3SI
# Ag3SbS3
# AgAsS2
# R-3 -> C2/c (537.98K, 36.61 J/kgK)
# AgBiO2
# P6_3/mmc -> R-3m (535.87K, 0.53 J/kgK)
# AgBr
# AgBrO4
# AgC2N3
# AgC3N3O2
# AgCNO
# AgCSN
# AgCl
# AgClO2
# C2/c -> Pcca (445.90K, 188.00 J/kgK)
# AgClO3
# AgClO4
# AgGe2N3
# AgH8C3S2ClO4
# AgHgSI
# AgI
# P6_3mc -> F-43m (439.87K, 65.74 J/kgK)
# P4/nmm -> I-4m2 (324.09K, 63.78 J/kgK)
# P6_3mc -> I-4m2 (516.79K, 76.87 J/kgK)
# AgI3O8
# AgIO3
# AgN3
# AgNO2
# AgNO3
# Pbca -> P2_12_12_1 (333.47K, 38.17 J/kgK)
# AgSb3PbS6
# AgSbC2N2(ClF3)2
# AgSbS2
# AgTeO3
# Al(CN)3
# Al(HO)3
# Al(PO3)3
# Al(SiO3)2
# Al10Si2O19
# Al11AgO17
# Al15Fe9O32
# Al2(MoO4)3
# Al2(SO4)3
# Al2(SeO4)3
# Al2(WO4)3
# P2_1/c -> P2_1 (468.47K, 31.43 J/kgK)
# P2_1/c -> P2_1 (405.80K, 24.21 J/kgK)
# P2_1/c -> P2_12_12 (487.77K, 30.80 J/kgK)
# P2_1/c -> P2_12_12 (426.29K, 23.75 J/kgK)
# Al2CO
# Al2CdS4
# Al2CdSe4
# Al2CoO4
# Al2FeO4
# Al2H12(SeO5)3
# Al2HgS4
# Al2Mo2O7
# Al2NiO4
# Al2O3
# P-31c -> C2/m (429.76K, 120.60 J/kgK)
# Cm -> Pbca (375.07K, 130.37 J/kgK)
# P321 -> P1 (318.57K, 191.52 J/kgK)
# Al2PbSe4
# Al2S3
# P6_1 -> I4_1/amd (509.52K, 68.10 J/kgK)
# Al2Se3
# Al2Si2H4O9
# Al2Si2O7
# Al2Si2PbO8
# Al2Si3H8(NO5)2
# Al2SiO5
# Al2Te3
# Al2W2O7
# Al2Zn(SeS)2
# Al2Zn2S5
# R-3m -> P6_3/mmc (553.94K, 60.35 J/kgK)
# Al2ZnO4
# Al2ZnS4
# Al2ZnSe4
# Al3BC3
# Al3CrO6
# R3 -> Pc (318.27K, 154.21 J/kgK)
# Al3GaN4
# Al3NO3
# Al3Pb5F19
# I4cm -> P4/n (542.55K, 138.54 J/kgK)
# Al4B2O9
# Al4Si2H(O3F)3
# Warning: 2 transitions within this interval
# P2_1 -> Pc (355.11K, 20.59 J/kgK)
# Al5(FeO4)3
# Al5C3N
# Al8SiO14
# AlAg(WO4)2
# AlAgO2
# AlAgS2
# AlAs
# Warning: 2 transitions within this interval
# F-43m -> P6_3mc (469.83K, 54.45 J/kgK)
# AlAsO4
# AlBPbO4
# AlBiN2
# AlBiO3
# AlCoO3
# AlCr(WO4)2
# P1 -> P1 (389.17K, 30.99 J/kgK)
# AlCrO3
# AlCu(WO4)2
# AlCuCl4
# AlCuO2
# AlCuS2
# AlF3
# C2/c -> P4/nmm (405.25K, 170.77 J/kgK)
# Pm-3m -> P4/nmm (385.84K, 149.44 J/kgK)
# AlFe(WO4)2
# AlFeO3
# AlGa3N4
# AlGaN2
# AlGaO3
# AlH10C3N
# AlH12(NO5)3
# AlH12(OF)5
# AlH3
# AlH4NF4
# AlHO2
# AlHg2SbCl4
# AlInN2
# AlInO3
# AlMo(WO4)2
# AlMoO3
# AlN
# P6_3mc -> F-43m (392.29K, 293.26 J/kgK)
# AlNi(WO4)2
# AlP
# F-43m -> P6_3mc (496.00K, 37.07 J/kgK)
# AlP(H2O3)2
# AlP2H4O8F
# AlPO4
# Aem2 -> Pca2_1 (441.11K, 53.98 J/kgK)
# C2/c -> C2/m (405.23K, 35.28 J/kgK)
# C2/c -> Cmc2_1 (569.15K, 91.61 J/kgK)
# P2/c -> C222_1 (401.53K, 29.15 J/kgK)
# P3_121 -> C222_1 (435.24K, 98.60 J/kgK)
# P3_221 -> C222_1 (423.60K, 108.35 J/kgK)
# Pbca -> Cmc2_1 (481.49K, 53.04 J/kgK)
# P6_3mc -> Iba2 (436.15K, 47.18 J/kgK)
# Iba2 -> Pca2_1 (547.98K, 56.81 J/kgK)
# Warning: 2 transitions within this interval
# Iba2 -> Pnn2 (388.78K, 29.33 J/kgK)
# P6_3mc -> Ima2 (494.91K, 53.64 J/kgK)
# Ima2 -> Pca2_1 (523.18K, 42.33 J/kgK)
# P-1 -> Pca2_1 (301.08K, 63.90 J/kgK)
# P-1 -> Pcc2 (420.44K, 32.85 J/kgK)
# Warning: 2 transitions within this interval
# P3_121 -> P2/c (453.92K, 49.70 J/kgK)
# Warning: 2 transitions within this interval
# P3_221 -> P2/c (432.97K, 69.08 J/kgK)
# P6_3mc -> Pca2_1 (508.02K, 88.49 J/kgK)
# P6_3mc -> Pnn2 (419.49K, 75.35 J/kgK)
# P6cc -> Pca2_1 (363.29K, 98.35 J/kgK)
# P6cc -> Pcc2 (488.00K, 38.78 J/kgK)
# Pnn2 -> Pca2_1 (567.59K, 78.73 J/kgK)
# AlPS4
# AlSb
# AlSb(WO4)2
# AlSbO3
# AlSn3Se2ClO8
# AlTeCl7
# P-1 -> P2_1/c (422.39K, 44.79 J/kgK)
# AlVO3
# AlW3O8
# AlWO3
# As2O3
# As2O5
# P2_12_12_1 -> P4_12_12 (560.69K, 15.71 J/kgK)
# P2_12_12_1 -> P4_32_12 (563.31K, 15.55 J/kgK)
# P4_32_12 -> P4_12_12 (348.62K, 0.15 J/kgK)
# As2S2O9
# As2S3
# As2Se3
# As3HO6
# As3Pb5ClO12
# As3Pb5ClO9
# AsH6NO4
# AsHPbO4
# AsNO4
# AsS
# AsS3(NF3)2
# AsS4N4F5
# AsSClOF8
# AsSXeNF10
# AsXe2F9
# P1 -> C2/c (454.44K, 6.73 J/kgK)
# Au2O3
# AuBr
# AuC2N3
# AuCl
# AuClO2
# B
# B(HO)3
# B10H11C2
# B10H13
# B10H18C2S
# B2(CN2)3
# B2O3
# P3_121 -> Cmc2_1 (573.56K, 368.59 J/kgK)
# B2S3
# B3H5
# B4C
# B5H9
# B8O
# B9H11
# BAs
# BAsO4
# BC2N
# BCl
# BF3
# BH2S3N3F4
# BH4N
# BH6N
# BHO2
# BN
# BNF8
# BP
# BPO4
# BSbO3
# Ba(AlTe2)2
# Ba(BO2)2
# Ba(BiS2)2
# Ba(BrO3)2
# Ba(C4N3)2
# Ba(CO2)2
# Ba(CuS)2
# Pnma -> I4/mmm (306.83K, 77.55 J/kgK)
# Ba(FeO2)2
# Ba(GaO2)2
# Ba(H2O3)2
# Ba(H8O5)2
# Ba(HO)2
# Ba(InTe2)2
# Ba(NdS2)2
# Ba(PO3)2
# Ba(ZnN)2
# Ba10IBr4N5
# Ba10MgAs6(ClO12)2
# Ba10MgMn6(O12F)2
# Ba2As6O11
# Ba2B2O5
# Ba2BiSbO6
# Ba2CaI6
# P4_2/mnm -> P-4b2 (391.08K, 27.81 J/kgK)
# Ba2CaV2(Si2O7)2
# Ba2CaWO6
# Ba2CeHfO6
# Ba2CeSnO6
# Ba2CeZrO6
# Ba2CoSi2O7
# Ba2CrO4
# Pna2_1 -> Pnma (541.34K, 11.12 J/kgK)
# Ba2DyBiO6
# Ba2DyNbO6
# Ba2DySbO6
# Ba2ErMgSbO6
# Ba2Fe2O5
# Ba2FeMoO6
# Ba2GdBiO6
# Ba2GdSbO6
# Ba2GdTaO6
# Ba2GeO4
# Ba2HoMgSbO6
# Ba2HoTaO6
# Ba2In2O5
# Ba2La2MgTi3O12
# Ba2LaBiO6
# Ba2LaCl7
# Ba2LaI7
# Ba2LaMgBiO6
# Ba2LaMgSbO6
# Ba2LaNbO6
# Ba2LaSbO6
# P2_1/c -> Fm-3m (361.51K, 16.37 J/kgK)
# Pn-3 -> Fm-3m (500.57K, 18.89 J/kgK)
# Ba2LaTaO6
# Ba2LaVO6
# Ba2Li(NiO2)2
# Ba2LiMn2O6
# Ba2LiTbSnO6
# Ba2LiV2(Si2O7)2
# Ba2LiY2(Fe2O5)2
# Ba2LuBiO6
# Ba2LuMgSbO6
# Ba2Mg(BiO3)2
# Ba2Mg(CoO3)2
# Ba2Mg(NiO3)2
# Ba2MgCoMoO6
# Ba2MgCoWO6
# Ba2MgCrMoO6
# Immm -> Cm (313.50K, 40.66 J/kgK)
# Ba2MgFeMoO6
# Ba2MgFeWO6
# Ba2MgMn2O6
# Ba2MgMnWO6
# Ba2MgMo4(P2O7)4
# Ba2MgMo4(Se2O11)2
# Ba2MgNiMoO6
# Ba2MgNiWO6
# Ba2MgSi2O7
# Ba2MgV2(Si2O7)2
# Ba2MgVMoO6
# Ba2MgZnWO6
# Ba2MnNbO6
# Ba2MnO3
# Ba2NF
# Ba2Na2O3
# Ba2NaNb5O15
# Ba2NaSr2(SbO4)3
# Ba2NbFeO6
# P-3m1 -> P6_3/mmc (470.92K, 47.48 J/kgK)
# Ba2Nd2Mg(Fe2O5)2
# Ba2NdBiO6
# Ba2NdMgBiO6
# Ba2NdMgSbO6
# Ba2NdNbO6
# Ba2NdSbO6
# Fm-3m -> Pn-3 (587.35K, 2.83 J/kgK)
# Ba2NdTaO6
# Ba2NdVO6
# Ba2P2O7
# Ba2P6O17
# Ba2PrBiO6
# Ba2PrMgSbO6
# Ba2PrNbO6
# Ba2PrSbO6
# Ba2PrTaO6
# Ba2PrVO6
# Ba2Si3O8
# Ba2SmBiO6
# Ba2SmNbO6
# Warning: 2 transitions within this interval
# Fm-3m -> Pn-3 (333.16K, 5.66 J/kgK)
# Ba2SmSbO6
# Ba2SmVO6
# Fm-3m -> Pn-3 (349.91K, 38.46 J/kgK)
# Ba2SnS4
# P2_1/c -> Pna2_1 (394.09K, 16.31 J/kgK)
# Ba2SnSe5
# Ba2SnWO6
# Ba2Sr3CaMg2(SiO4)4
# Ba2Sr3Nb10O30
# P1 -> P2 (355.13K, 28.26 J/kgK)
# Ba2SrCrO6
# Ba2SrI6
# P-31m -> C2/c (551.11K, 46.26 J/kgK)
# P2_1/c -> P-4b2 (321.07K, 18.04 J/kgK)
# P321 -> P-62m (376.31K, 18.08 J/kgK)
# Ba2SrMgWO6
# Ba2SrUO6
# Ba2SrWO6
# C2/m -> R-3 (445.87K, 10.50 J/kgK)
# Ba2Ta2O7
# Ba2TaBiO6
# Ba2TaMnO6
# P1 -> Pnma (580.60K, 11.11 J/kgK)
# Ba2TbBiO6
# Ba2TbMgBiO6
# Ba2TbMgSbO6
# Ba2TbNbO6
# Ba2TbTaO6
# Ba2TbWO6
# Ba2Ti5(Bi2O9)2
# Ba2Ti6N2O11
# Cm -> C2/m (411.91K, 18.31 J/kgK)
# Ba2TiO4
# Ba2U(PO5)2
# Ba2VBiO6
# Ba2VFeO6
# Ba2Y2Mg(Fe2O5)2
# Ba2Y5Cl19
# Ba2YBiO6
# Ba2YBr7
# Ba2YCl7
# Ba2YCr3O7
# Ba2YF7
# Ba2YI7
# Ba2YMgBiO6
# Ba2YMgSbO6
# Ba2YNbO6
# Ba2YSbO6
# Ba2YTaO6
# Ba3(BO3)2
# Ba3(BrO)2
# Pnma -> P2_1/c (409.07K, 33.76 J/kgK)
# Ba3(ClO)2
# Ba3(InN2)2
# Ba3(PS4)2
# Ba3(YI6)2
# Ba3AlF9
# Ba3Cr2O8
# Ba3GeO5
# P4/ncc -> I4/mcm (487.30K, 30.69 J/kgK)
# Ba3In2WO9
# Ba3La2Cl12
# Ba3LaCl9
# Ba3LiTi5(SbO7)3
# Ba3LiTi5Nb3O21
# Cmc2_1 -> P1 (397.45K, 12.73 J/kgK)
# Ba3MgMn3O9
# Ba3MgV2O8
# Ba3MoN4
# Ba3P4O13
# Ba3SrNb2O9
# Ba3SrTa2O9
# Ba3Ta4TiO15
# Ba3TiNb4O15
# Ba3UIn2O9
# Ba3WN4
# Ba3WO6
# Ba3Y2Br12
# Ba3Y2Cl12
# Ba3Y2F12
# Ba3Y2N4
# Ba3Y2O6
# Ba3Y4O9
# Ba3YI9
# Ba4Br6O
# Ba4CaZr5O15
# P4/mmm -> Cmmm (568.54K, 32.12 J/kgK)
# P4/mmm -> P4/m (451.57K, 26.11 J/kgK)
# Ba4LiNb3O12
# Ba4Lu6O13
# Ba4Nb2O9
# Ba4OF6
# Ba4Sr(SnO3)5
# Ba4Ta2O9
# Ba4Ta2TiZnO12
# Ba4Ti11O26
# Ba4Ti3O10
# Ba4Zn4B14Pb2O31
# Ba5Ce4ZrO15
# Ba5P3O12F
# P6_3/m -> P6_3 (335.78K, 17.42 J/kgK)
# Ba5P4
# Cmce -> Pnma (532.44K, 2.99 J/kgK)
# Ba5V5O14
# Ba5Y3F19
# I4cm -> P-1 (585.58K, 14.72 J/kgK)
# Ba6Br2N3Cl
# Ba6Dy2Al4O15
# Ba6Nd2Al4O15
# Ba6Ti2Nb10Si8O51
# Ba6YBr15
# Ba6YI15
# Ba8Bi4O17
# Ba8CaY2U4O24
# Ba8In6O17
# BaAl2(SiO4)2
# P2_1/c -> C2/c (547.04K, 64.76 J/kgK)
# BaAl2O4
# BaAl2O6
# BaAl4O7
# BaAlBO3F2
# BaAlF5
# P2_12_12_1 -> P1 (346.02K, 28.46 J/kgK)
# BaAlSi5N7O2
# BaAsHO4
# BaB2F8
# BaB4O7
# BaBPO5
# BaBe2(BO3)2
# BaBe2Si2O7
# BaBi4O7
# BaBiBrO2
# BaBiClO2
# BaBrCl
# BaC2
# BaCN2
# BaCO3
# R3m -> C2/m (427.69K, 63.08 J/kgK)
# BaCa(CO3)2
# P2_1 -> P2_1/m (355.18K, 20.56 J/kgK)
# BaCa2I6
# Pc -> P4_2/mnm (387.57K, 17.47 J/kgK)
# BaCa2Mg(SiO4)2
# BaCaBiSbO6
# BaCaCeHfO6
# BaCaCeSnO6
# BaCaCeZrO6
# BaCaCrF7
# BaCaDyBiO6
# BaCaEuWO6
# BaCaGdBiO6
# BaCaGdNbO6
# BaCaGdSbO6
# Pnnn -> P-1 (598.04K, 19.80 J/kgK)
# BaCaI4
# C2/m -> P4/mmm (481.63K, 29.07 J/kgK)
# C2/m -> Pmm2 (500.11K, 26.70 J/kgK)
# C2/m -> R-3m (457.95K, 45.28 J/kgK)
# Imma -> Cm (559.25K, 48.58 J/kgK)
# Pbcn -> Cm (344.91K, 10.60 J/kgK)
# Cmc2_1 -> Pnna (507.37K, 32.25 J/kgK)
# Pbcm -> I4_1/a (513.79K, 7.03 J/kgK)
# Imma -> Pnma (495.92K, 45.75 J/kgK)
# Pmm2 -> P4/mmm (305.23K, 2.13 J/kgK)
# P4/mmm -> R-3m (418.17K, 16.11 J/kgK)
# Pmm2 -> R-3m (402.91K, 18.33 J/kgK)
# BaCaInBiO6
# BaCaLaBiO6
# BaCaLaSbO6
# BaCaMg14O16
# BaCaNdBiO6
# BaCaNdNbO6
# BaCaNdSbO6
# BaCaO2
# BaCaPrBiO6
# BaCaPrSbO6
# BaCaSmBiO6
# BaCaSmNbO6
# BaCaSmSbO6
# BaCaSnWO6
# BaCaTbBiO6
# P-1 -> P222 (361.59K, 6.34 J/kgK)
# BaCaZr2O6
# BaCeO3
# BaCl2
# BaCl2O11
# BaCo2(PO4)2
# BaCrO4
# BaCu(SiO3)2
# BaDy2CoO5
# BaDyNbSnO6
# P222 -> P-1 (416.54K, 3.19 J/kgK)
# BaDySnSbO6
# BaEr2CoO5
# BaF2
# BaFe(Si2O5)2
# BaFe12O19
# BaFe2(P2O7)2
# BaFe2(PO4)2
# BaFeF5
# BaGa2(GeO4)2
# BaGaB4H3O10
# BaGaH5
# Pmn2_1 -> P2_1 (447.88K, 3.97 J/kgK)
# BaGdInWO6
# BaGdNbSnO6
# BaGe2O5
# BaGe4O9
# P321 -> P3 (462.63K, 50.70 J/kgK)
# BaGeO3
# BaH2
# Pnma -> P6_3/mmc (529.70K, 183.80 J/kgK)
# BaH2N2O5
# BaH2S5O6
# BaH4O3
# P2_1/m -> Pmc2_1 (567.55K, 181.41 J/kgK)
# BaHfS3
# BaHgO2
# BaHo2O4
# BaI2
# Pnma -> P-62m (524.74K, 11.40 J/kgK)
# BaLa2Br8
# BaLa2Cl8
# BaLa2O4
# BaLa2Ti3O10
# BaLa2WO7
# BaLa3TiCr3O12
# BaLa4Ti4O15
# BaLa4TiCr4O15
# BaLa7Mg5Nb3O24
# BaLaBr5
# BaLaCl5
# P2_1/c -> C2/c (402.81K, 13.00 J/kgK)
# C2/c -> Pnma (591.61K, 84.43 J/kgK)
# P-1 -> Pnma (530.90K, 75.33 J/kgK)
# P2_1/c -> Pnma (561.58K, 98.27 J/kgK)
# P2_1/m -> Pnma (393.11K, 80.18 J/kgK)
# BaLaI5
# P1 -> C2/c (345.62K, 5.54 J/kgK)
# BaLaTiCrO6
# BaLi(B3O5)3
# BaLi2NiO3
# BaLi4O3
# BaLiAl3P2(HO7)2
# BaLiP
# BaLiV2Ni3(HO5)2
# BaLu2O4
# BaLuCo4O7
# BaMg(CO3)2
# BaMg(FeO2)4
# BaMg14CdO16
# BaMg14FeO16
# BaMg14MnO16
# BaMg14NiO16
# BaMg14ZnO16
# BaMg2N2
# BaMgF4
# BaMgTiO3
# BaMnO3
# BaMnP2O7
# BaMo(PO4)2
# Warning: 2 transitions within this interval
# P-1 -> C2/m (359.38K, 20.21 J/kgK)
# BaMo3O10
# BaNa2Al4(SiO4)4
# BaNa2Mg(PO4)2
# BaNa2O2
# BaNa3PCO7
# BaNa6O4
# BaNaBiWO6
# BaNaCeBiO6
# BaNaCeNbO6
# BaNaCeSbO6
# BaNaGdWO6
# BaNaLaWO6
# BaNaN
# BaNaNdWO6
# BaNaPO4
# BaNaPrWO6
# BaNaSmWO6
# BaNaZrBiO6
# BaNb2Fe2(PO4)6
# BaNb2O6
# BaNd2Ti3O10
# BaNiO3
# BaO
# BaO2
# BaP2(HO2)4
# BaP3
# BaP4O11
# BaPHO4
# BaPb2(SO4)3
# P1 -> Pm (509.93K, 2.35 J/kgK)
# BaPrInWO6
# BaS3
# BaSO4
# BaSe
# BaSi2O5
# BaSiO3
# BaSn2S3
# BaSnF4
# BaSnHgS4
# BaSr(FeO2)4
# BaSr(SnO3)2
# BaSr2I6
# Pbcn -> C2/m (554.69K, 7.44 J/kgK)
# Pbcn -> P321 (455.27K, 5.71 J/kgK)
# BaSr4Cl10
# BaSrBiSbO6
# BaSrCaWO6
# BaSrCe2O6
# BaSrCeHfO6
# BaSrCeSnO6
# BaSrCeTiO6
# BaSrCeWO6
# BaSrCeZrO6
# BaSrDyBiO6
# BaSrDyNbO6
# BaSrDySbO6
# BaSrDyWO6
# BaSrGdBiO6
# BaSrGdNbO6
# BaSrHfZrO6
# BaSrI4
# Cmc2_1 -> P2_1/c (307.87K, 9.81 J/kgK)
# Pna2_1 -> R-3m (385.31K, 34.52 J/kgK)
# Pnma -> R-3m (415.95K, 41.77 J/kgK)
# Pnna -> R-3m (351.08K, 29.01 J/kgK)
# BaSrLaBiO6
# BaSrLaNbO6
# BaSrLaSbO6
# BaSrLaVO6
# BaSrLaWO6
# BaSrMg14O16
# BaSrNbBiO6
# BaSrNbSbO6
# BaSrNdBiO6
# BaSrNdNbO6
# BaSrNdSbO6
# BaSrNdVO6
# BaSrNdWO6
# BaSrO2
# R-3m -> P4/mmm (471.57K, 61.65 J/kgK)
# BaSrPrBiO6
# BaSrPrNbO6
# BaSrPrSbO6
# BaSrPrVO6
# BaSrPrWO6
# BaSrSmBiO6
# BaSrSmNbO6
# BaSrSmSbO6
# BaSrSmWO6
# BaSrTbBiO6
# BaSrTbNbO6
# BaSrTbSbO6
# BaSrTbWO6
# BaSrYBiO6
# BaSrYNbO6
# BaSrYSbO6
# BaSrYWO6
# BaSrZr2O6
# BaTa2O6
# BaTaF7
# BaTbInWO6
# BaTbNbSnO6
# BaTe
# BaTeMo2O9
# Pca2_1 -> P2_1 (425.63K, 35.14 J/kgK)
# BaTeO3
# BaTeO4
# BaTi(SiO3)3
# BaTi2O5
# BaTiO3
# Amm2 -> C222_1 (561.48K, 20.15 J/kgK)
# Amm2 -> P6_3/mmc (541.60K, 26.72 J/kgK)
# C222_1 -> P6_3/mmc (484.55K, 6.51 J/kgK)
# R3m -> C222_1 (461.93K, 20.62 J/kgK)
# R3m -> P6_3/mmc (467.27K, 27.14 J/kgK)
# BaV2(P2O7)2
# BaV2ZnO7
# BaVOF4
# BaVSi2O7
# BaWN3
# BaWO4
# I4_1/a -> C2/c (457.98K, 12.97 J/kgK)
# BaY2F8
# BaY3Cl11
# BaY3F11
# BaYBr5
# P2_1/c -> C2/c (314.48K, 20.23 J/kgK)
# BaYCl5
# BaYF5
# P2_1 -> C2/c (550.86K, 59.27 J/kgK)
# P2_12_12_1 -> C2/c (577.62K, 78.84 J/kgK)
# P4/mmm -> C2/c (583.27K, 175.96 J/kgK)
# Pmma -> C2/c (551.06K, 160.16 J/kgK)
# Pmma -> P2_1 (551.18K, 100.89 J/kgK)
# P4/mmm -> P2_12_12_1 (587.90K, 97.11 J/kgK)
# Pmma -> P2_12_12_1 (526.43K, 81.14 J/kgK)
# BaYI5
# C2/c -> P2_1 (513.20K, 77.36 J/kgK)
# P2_12_12_1 -> P2_1 (399.08K, 33.24 J/kgK)
# BaYInWO6
# Pnnn -> F-43m (368.70K, 38.74 J/kgK)
# BaYNbSnO6
# P-1 -> P222 (321.42K, 14.90 J/kgK)
# BaYSnSbO6
# BaZn2Si2O7
# Cmc2_1 -> Cmcm (314.48K, 53.23 J/kgK)
# BaZnCl4
# BaZnF4
# BaZr(PO4)2
# BaZr2SnO6
# P4_2/mmc -> Pm-3m (566.11K, 21.78 J/kgK)
# BaZrF6
# BaZrO3
# Be(GaO2)2
# Be(HO)2
# Be(PO3)2
# Be2BH3O5
# Be2P2O7
# Be2SiO4
# Be3Fe4Si3TeO12
# Be3N2
# Be4N6O19
# BeAlH5
# BeC2
# BeCN2
# BeCl2
# I4_1/acd -> I-43m (406.33K, 521.11 J/kgK)
# Ibam -> I-43m (396.30K, 537.22 J/kgK)
# I4_1/acd -> P3_221 (515.41K, 156.12 J/kgK)
# Ibam -> P3_221 (476.06K, 310.32 J/kgK)
# BeCrO4
# BeF2
# P2_1 -> P1 (568.13K, 4.40 J/kgK)
# BeH4NF3
# BeH8(NF2)2
# BeI2
# BeNF3
# BeO
# BeSiN2
# BeTe
# Bi(BO2)3
# P1 -> P1 (583.63K, 4.19 J/kgK)
# P1 -> Pca2_1 (371.53K, 119.46 J/kgK)
# P1 -> Pca2_1 (365.23K, 114.01 J/kgK)
# P2_1/c -> Pca2_1 (411.26K, 154.56 J/kgK)
# Bi(W2Cl5)3
# Bi14SO24
# Bi2(CN2)3
# Bi2(PSe3)3
# P2_1/c -> P-1 (590.38K, 19.58 J/kgK)
# Bi2(PbS2)3
# Bi2(SO4)3
# Bi26Mo10O69
# Bi2B8O15
# Bi2CO5
# Bi2MoO6
# Bi2O3
# Pm -> Cm (304.54K, 14.40 J/kgK)
# P6_3mc -> Fd-3m (559.22K, 42.06 J/kgK)
# R-3c -> Pa-3 (418.32K, 12.53 J/kgK)
# Bi2Se3
# Bi2Te7Cl8
# Bi2W2O9
# Pna2_1 -> Pbcn (346.53K, 9.34 J/kgK)
# Bi2WO6
# Bi3BrO4
# Bi3O2F5
# Bi3O4F
# Bi4O5F2
# Bi4S3N2
# Bi5IO7
# Bi5O7F
# Bi6O5F8
# Bi7(O2F3)3
# BiAsO4
# BiBPbO4
# BiBr3
# BiF3
# P-43m -> Fm-3m (523.34K, 10.86 J/kgK)
# BiF5
# BiI3
# BiN
# BiO2
# BiOF
# P2_1 -> P2_1/c (460.58K, 73.54 J/kgK)
# P2_1 -> Pbca (525.99K, 36.21 J/kgK)
# Pbca -> P2_1/c (404.00K, 36.69 J/kgK)
# BiPO4
# P2_1/m -> P3_121 (557.07K, 65.17 J/kgK)
# BiSeClO3
# BiTeO4
# Cc -> C2 (415.88K, 32.46 J/kgK)
# BrCl
# C
# C(ClF)2
# C(NO)2
# C18BrF13
# C2N2O5
# C2SF6
# C2SNOF
# C2SeN2
# C3F5
# C3N2
# C3N4
# C4SBr4
# CBrN
# CCl3
# CF
# CN2
# CNCl
# CO
# P2_12_12_1 -> R3c (324.91K, 161.92 J/kgK)
# CO2
# Pbcn -> P4_2/mnm (467.05K, 124.52 J/kgK)
# CS2N2O
# CSN2
# CSO
# Ca(AgO2)2
# Ca(AlH4)2
# Ca(BH4)2
# P4_2 -> P4_2/m (377.96K, 388.08 J/kgK)
# Ca(BO2)2
# Pna2_1 -> Pbcn (562.38K, 214.74 J/kgK)
# Ca(BiO2)2
# Pbcm -> Fd-3m (514.17K, 54.13 J/kgK)
# Pnma -> P3m1 (553.75K, 61.37 J/kgK)
# Ca(ClO3)2
# P2_1/c -> Fdd2 (336.41K, 138.60 J/kgK)
# Ca(CoO2)2
# Pnma -> I4_1/a (442.57K, 124.58 J/kgK)
# Ca(CoS2)2
# Fd-3m -> I4_1/amd (345.81K, 27.84 J/kgK)
# Ca(CrS2)2
# Ca(CuO2)2
# Ca(ErS2)2
# Ca(Fe2O3)4
# Ca(FeO2)2
# Ca(GaO2)2
# Ca(GaS2)2
# Ca(H8O5)2
# Ca(HO)2
# Ca(HoS2)2
# Ca(MoO2)2
# Ca(NiO2)2
# I4_1/a -> I4_1/amd (376.91K, 156.16 J/kgK)
# Warning: 2 transitions within this interval
# P-1 -> I4_1/amd (460.55K, 69.47 J/kgK)
# Ca(PO3)2
# Ca(SO5)2
# P6_4 -> P6_2 (507.57K, 51.31 J/kgK)
# Ca(SbO2)2
# Ca(SbO3)2
# Ca(SiO2)6
# Ca(SnO2)2
# Ca(WO2)2
# Ca10P6O25
# Ca10P6SO24
# Ca10Si3S3(ClO12)2
# Pm -> P-6 (598.85K, 33.60 J/kgK)
# Ca10V6O25
# Ca12Al14O33
# Ca2Al2Si(HO4)2
# Ca2Al2SiO7
# Ca2AlBiO5
# Ca2AlFeO5
# Ca2AlH10ClO8
# Ca2AsH4F13
# Ca2B2O5
# Ca2B5H2ClO10
# Ca2Bi10O17
# Ca2Bi2O5
# Ca2BiSbO6
# Ca2BiWO6
# Ca2CdAs2
# Ca2CeO4
# Ca2CoO3
# Ca2CoSi2O7
# Ca2Cr2O5
# Ca2CrSbO6
# Ca2CrWO6
# Ca2Fe2O5
# Ca2FeSbO6
# Ca2FeWO6
# Ca2Ga2Si(HO4)2
# Ca2GeO4
# Ca2H2S2O9
# Ca2La2MgTi3O12
# Ca2LaSbO6
# Ca2MgAl2(SiO4)3
# Ca2MgFe(CO3)4
# Ca2MgSi2O7
# Ca2Mn3O8
# Ca2Mn7Si10H12O35
# Ca2MnSbO6
# Ca2MnWO6
# Ca2MoWO6
# Ca2NF
# Ca2Nb2O7
# Ca2NbInO6
# Ca2Nd2Nb3FeO14
# C2/m -> P2/c (365.11K, 17.05 J/kgK)
# Ca2NiWO6
# P2_1/c -> C2 (348.99K, 40.15 J/kgK)
# Ca2P2O7
# Ca2PI
# Ca2S2O9
# Ca2SbWO6
# Ca2Si5N8
# Ca2SiO4
# Ca2Sn3O8
# Ca2Sn3S8
# Ca2SnS4
# P2_1/c -> C2/m (498.71K, 82.10 J/kgK)
# Ca2SnWO6
# Ca2Ta2O7
# C2 -> C222_1 (402.95K, 9.32 J/kgK)
# Ca2TaCrO6
# Ca2TaWO6
# Ca2Ti3O8
# Ca2Ti6N2O11
# Ca2TiAlSi2O9F
# Ca2TiMnO6
# Ca2V3O8
# Ca2VBiO6
# Ca2VWO6
# Ca2WO5
# Ca2YBiO6
# Ca2ZnAs2(H2O5)2
# P2_1/c -> P-1 (544.17K, 45.22 J/kgK)
# Ca2Zr5Ti2O16
# Ca3(AlN2)2
# P2_12_12_1 -> C2/c (457.29K, 58.10 J/kgK)
# Ca3(BN2)2
# Ca3(CoO3)2
# Ca3(InN2)2
# Ca3(PO4)2
# Ca3Al4CoO10
# Ca3AsN
# Ca3Be2P4(HO2)10
# Ca3CdO4
# Cmmm -> P4/mmm (558.01K, 158.52 J/kgK)
# Ca3Co2(Si2O7)2
# Ca3Er3Ge2BO13
# Ca3Fe2(WO6)2
# Ca3Ga2(SnO4)3
# Ca3MnO4
# Ca3N2
# Ca3Nb4(O6F)2
# Ca3Si2O7
# Ima2 -> P2_1/c (482.90K, 79.24 J/kgK)
# Ca3SiO5
# Ca3Sn2S7
# Ca3SnS5
# Ca3Ta2O8
# Ca3Ta4(O6F)2
# Ca3UN4
# Ca3UO6
# P2_1 -> P2_1/c (344.99K, 20.17 J/kgK)
# Ca3V2O8
# Ca3W2O9
# Ca3WO6
# Ca3Y2N4
# Ca3Zn3(TeO6)2
# Ca4Al6MoO16
# Ca4Al6O13
# Ca4Al6SO16
# Ca4Al6WO16
# Ca4Bi6O13
# Pm -> Cm (388.43K, 21.50 J/kgK)
# Ca4Nb2O9
# Ca4Sn3S10
# Ca4SnS6
# Ca4Ta2O9
# Ca5(SiN3)2
# Ca5BC4Cl3
# Ca5P3ClO12
# Ca5P3HO13
# P6_3 -> P2_1/c (508.44K, 21.09 J/kgK)
# Ca5P3O12F
# P6_3 -> P6_3 (542.68K, 6.05 J/kgK)
# Ca5Ta4O15
# CaAl12O19
# CaAl2(SiO4)2
# CaAl2H4Pb2(O2F3)2
# CaAl2O4
# CaAl2Si2(H2O5)2
# CaAl2Si3O10
# CaAl2SiO6
# P2/c -> C2 (318.88K, 53.64 J/kgK)
# CaAlF5
# Warning: 2 transitions within this interval
# C2/c -> P2_1/c (385.69K, 18.76 J/kgK)
# CaAlH5
# CaAs3F15
# CaB2(H2O3)2
# CaB3H5O8
# CaB4O7
# CaBHO3
# CaBiCO4F
# CaBiF5
# CaBiMoO5
# CaBiSbO5
# CaBiWO5
# CaBr2
# CaC2
# CaC2O5
# CaCO3
# C2 -> C2/c (406.29K, 148.08 J/kgK)
# P2_1/c -> C2/c (551.35K, 208.68 J/kgK)
# R-3c -> C2/c (479.91K, 124.83 J/kgK)
# P2_1/c -> P6_522 (370.42K, 157.71 J/kgK)
# CaCd(NO3)4
# CaCl2
# CaCo(GeO3)2
# CaCo(SiO3)2
# CaCo6(OF5)2
# CaCoP2O7
# CaCr(GeO3)2
# CaCr2O4
# CaCr2O5
# CaCrBiO5
# CaCrF5
# CaCrO2
# CaCrP2O7
# CaF2
# Fm-3m -> Pnma (432.56K, 224.45 J/kgK)
# CaFe(GeO3)2
# CaFe(SiO3)2
# CaFe3Si2HO9
# CaFeF5
# CaFeO2
# CaFeP2O7
# CaGa4(WO6)2
# CaGaBiB2O7
# CaGd2O4
# Cmcm -> Pnma (526.96K, 11.75 J/kgK)
# CaGe2O5
# C2/c -> P-1 (510.69K, 26.06 J/kgK)
# CaGe2WO6
# CaGeO3
# CaH2
# CaH2(CO2)2
# CaH2C2O5
# CaH8(ClO2)2
# CaHfO3
# CaLa2Fe2(TeO6)2
# CaLa2FeO6
# CaLa4Ni3WO12
# CaLaAl3O7
# CaLaCrSbO6
# CaLaCrSnO6
# CaLaFeO4
# CaLaFeSbO6
# P1 -> P1 (402.83K, 21.29 J/kgK)
# CaLaGaO4
# CaLaI5
# CaLaVFeO6
# CaMg(SiO3)2
# CaMg14CO16
# CaMg14CdO16
# CaMg14CoO16
# CaMg14MnO16
# CaMg14NiO16
# CaMg14VO16
# CaMg14ZnO16
# CaMg2(SO4)3
# P6_3/m -> P2_1 (592.01K, 37.34 J/kgK)
# CaMgAsO4F
# CaMgB2O5
# CaMn(GeO3)2
# CaMn(SiO3)2
# CaMn2O4
# I4_1/a -> I4_1/amd (318.56K, 58.69 J/kgK)
# CaMn3O4
# CaMn9CdO10
# CaMnBiO5
# CaMnF5
# CaMnO2
# CaMnP2O7
# CaMo2O5
# CaMoF5
# CaMoO3
# CaMoO4
# CaN6
# CaNdCoO4
# CaNdCrO4
# CaNdGa3O7
# CaNi(GeO3)2
# CaNiF4
# CaNiO2
# CaNiP2O7
# CaO
# CaP4(Br3O)4
# CaP4O11
# CaPHO4
# CaPbI4
# C2/m -> P2/m (304.84K, 1.74 J/kgK)
# CaSO4
# P6_222 -> P2_1/c (367.57K, 88.98 J/kgK)
# P6_422 -> P2_1/c (338.17K, 107.95 J/kgK)
# CaSO6
# CaSbF5
# CaSe
# CaSeO3
# CaSeO4
# I4_1/a -> Cmce (344.40K, 21.57 J/kgK)
# CaSi2NiO6
# CaSi2SnO6
# CaSi2WO6
# CaSiN2
# CaSiO3
# Warning: 2 transitions within this interval
# Imma -> P4/mbm (334.04K, 105.38 J/kgK)
# Pnma -> Imma (584.86K, 266.57 J/kgK)
# CaSiSnO5
# CaSm4(Mo2O7)2
# CaSn(GeO3)2
# CaSn2O5
# CaSn2S5
# CaSn4S9
# CaSnF6
# CaSnO2
# CaSnO3
# CaSnP2O7
# CaSnS3
# CaTa2Bi2O9
# CaTa2O6
# CaTaAlO5
# CaTaBiO5
# CaTaNO2
# CaTb2O4
# CaTe
# CaTeO3
# P2_1/c -> P-1 (324.19K, 22.22 J/kgK)
# CaTeO4
# CaTi(GeO3)2
# CaTi2O5
# CaTi2PbO6
# CaTiF6
# CaTiFe5O8
# CaTiGeO5
# CaTiO3
# CaTiSiO5
# CaUO4
# CaV(SiO3)2
# CaV2(PO5)2
# CaV2O4
# CaV2O6
# CaV5O7
# CaV6O11F
# CaVBiO5
# CaVP2O7
# CaW2O5
# CaWF5
# CaWO4
# I4_1/a -> C2/c (552.46K, 14.20 J/kgK)
# CaY2O4
# CaY4(BiO3)4
# CaYAl3O7
# CaZn2(PO5)2
# Pca2_1 -> Pbcn (309.19K, 135.80 J/kgK)
# CaZnF2
# CaZr4O9
# CaZrAl9BO18
# CaZrNbFeO7
# CaZrO3
# Cd(BO2)2
# Cd(C2N3)2
# Cd(C4N3)2
# P31m -> Pmna (369.90K, 259.03 J/kgK)
# Cd(CN)2
# Cd(CoO2)2
# Cd(FeO2)2
# Cd(GaO2)2
# Cd(HO)2
# Cd(IO3)2
# Cd(InSe2)2
# P-42m -> I-42m (545.89K, 7.02 J/kgK)
# Cd(PO3)2
# Cd2H2SO6
# Cd2P3Cl
# Cd2SiO4
# Cd3(BO3)2
# Cd3(PO4)2
# Cd4SF6
# Cd5(S2Cl)2
# Cd7P10
# CdAg2GeS4
# Pna2_1 -> Pmn2_1 (574.58K, 5.64 J/kgK)
# CdBr2
# CdCl2
# CdF2
# CdGe(BiO3)2
# CdGeN2
# Pna2_1 -> I-42d (476.41K, 128.70 J/kgK)
# CdGeO3
# CdH4(C2O3)2
# CdH8(NO5)2
# CdI2
# CdNCl3
# CdP2
# CdPS3
# C2/m -> R-3 (314.15K, 28.68 J/kgK)
# CdS
# CdSO3
# CdSO4
# Cmcm -> Pmn2_1 (570.93K, 107.15 J/kgK)
# CdSe
# CdSeO3
# Pnma -> P2_1/c (301.65K, 58.58 J/kgK)
# CdSeO4
# CdSiN2
# CdSiO3
# CdSnO3
# CdTe
# P6_3mc -> F-43m (366.51K, 43.15 J/kgK)
# Ce(WO4)2
# Ce2Dy2O7
# Ce2Nd2O7
# Ce2Y2O7
# Ce2ZrO6
# C2 -> I4/mmm (371.72K, 12.55 J/kgK)
# Ce3SnO8
# Ce3ZrO8
# Ce4SnO10
# Ce4ZrO10
# CeH8(SO6)2
# CeHfO4
# P2_1/c -> C2/c (562.08K, 44.14 J/kgK)
# CeO2
# CeSe2
# C2 -> I4_1/acd (452.87K, 11.13 J/kgK)
# C2 -> P-31c (524.33K, 6.41 J/kgK)
# C2/c -> I2_12_12_1 (383.65K, 18.86 J/kgK)
# C2/c -> P4_2/mcm (386.48K, 10.02 J/kgK)
# C2/c -> P4_2/nbc (396.92K, 2.46 J/kgK)
# Cmmm -> C2/m (438.89K, 0.25 J/kgK)
# C2/m -> I-42d (566.75K, 12.19 J/kgK)
# C2/m -> P2/c (411.30K, 3.37 J/kgK)
# C2/m -> Pbam (328.80K, 6.18 J/kgK)
# Pnc2 -> C2/m (479.42K, 5.78 J/kgK)
# Cc -> C222 (410.28K, 12.99 J/kgK)
# P-31m -> C222 (503.10K, 14.12 J/kgK)
# Pm -> C222 (578.39K, 14.82 J/kgK)
# C222_1 -> Fm-3m (594.40K, 13.40 J/kgK)
# C222_1 -> I-4 (559.12K, 12.44 J/kgK)
# C222_1 -> I2_12_12_1 (511.91K, 32.45 J/kgK)
# C222_1 -> P4_2/mcm (574.38K, 23.06 J/kgK)
# C222_1 -> Pa-3 (313.31K, 6.03 J/kgK)
# C222_1 -> Pm-3n (440.38K, 14.40 J/kgK)
# Cc -> Ibam (527.14K, 13.10 J/kgK)
# Cmc2_1 -> Fddd (325.21K, 2.27 J/kgK)
# Cmc2_1 -> Fmmm (461.17K, 2.78 J/kgK)
# Cmc2_1 -> I4_122 (304.94K, 2.55 J/kgK)
# Imma -> Cmc2_1 (542.84K, 1.62 J/kgK)
# Cmc2_1 -> Pbam (586.94K, 6.64 J/kgK)
# Cmc2_1 -> Pcca (444.68K, 7.01 J/kgK)
# Cmcm -> I-42d (368.43K, 5.93 J/kgK)
# Cmmm -> I-42d (563.82K, 12.45 J/kgK)
# Cmmm -> P2/c (413.15K, 3.62 J/kgK)
# Cmmm -> Pbam (332.56K, 6.44 J/kgK)
# Pnc2 -> Cmmm (481.34K, 5.53 J/kgK)
# Fd-3 -> R-3c (362.65K, 11.81 J/kgK)
# Ia-3d -> Fddd (504.47K, 7.02 J/kgK)
# Imma -> Fddd (402.90K, 4.01 J/kgK)
# P2_1/c -> Fddd (566.36K, 10.58 J/kgK)
# P6_3/mcm -> Fddd (527.75K, 2.35 J/kgK)
# Fddd -> Pcca (520.31K, 4.58 J/kgK)
# R-3m -> Fddd (453.69K, 5.09 J/kgK)
# Fm-3m -> I2_12_12_1 (460.11K, 18.79 J/kgK)
# Ima2 -> Fm-3m (528.74K, 4.11 J/kgK)
# Fm-3m -> P4_2/mcm (547.71K, 9.65 J/kgK)
# Pna2_1 -> Fm-3m (559.97K, 11.81 J/kgK)
# Ia-3d -> Fmmm (561.24K, 7.29 J/kgK)
# Imma -> Fmmm (489.68K, 4.42 J/kgK)
# Fmmm -> Pcca (434.14K, 4.23 J/kgK)
# R-3m -> Fmmm (527.00K, 5.42 J/kgK)
# I-4 -> I2_12_12_1 (484.46K, 19.93 J/kgK)
# Ima2 -> I-4 (394.60K, 2.95 J/kgK)
# I-4 -> P4_2/mcm (592.81K, 10.61 J/kgK)
# Pna2_1 -> I-4 (519.13K, 10.80 J/kgK)
# Immm -> I-42d (463.17K, 9.48 J/kgK)
# P2_1/m -> I-42d (486.79K, 8.45 J/kgK)
# Pnc2 -> I-42d (537.02K, 18.02 J/kgK)
# Pmmn -> I-42d (398.83K, 6.21 J/kgK)
# I-42m -> I2_12_12_1 (306.18K, 12.49 J/kgK)
# I2_13 -> I2_12_12_1 (543.15K, 30.25 J/kgK)
# Ima2 -> I2_12_12_1 (471.75K, 22.93 J/kgK)
# P4_2/mcm -> I2_12_12_1 (380.48K, 8.84 J/kgK)
# P4_2/nbc -> I2_12_12_1 (381.70K, 16.39 J/kgK)
# Pa-3 -> I2_12_12_1 (577.49K, 25.49 J/kgK)
# Pm-3n -> I2_12_12_1 (578.47K, 17.75 J/kgK)
# Pna2_1 -> I2_12_12_1 (496.38K, 30.75 J/kgK)
# Pnnn -> I2_12_12_1 (542.99K, 29.83 J/kgK)
# I2_13 -> Pa-3 (384.75K, 4.45 J/kgK)
# I2_13 -> Pm-3n (496.39K, 12.41 J/kgK)
# I2_13 -> Pnnn (554.61K, 0.42 J/kgK)
# P-31c -> I4_1/acd (368.81K, 4.56 J/kgK)
# P-4n2 -> I4_1/acd (341.30K, 12.69 J/kgK)
# P1 -> I4_1/acd (333.76K, 10.49 J/kgK)
# R-3 -> I4_1/acd (568.00K, 15.95 J/kgK)
# I4_1/amd -> I4_122 (598.90K, 9.64 J/kgK)
# I4_1/amd -> Pcca (587.41K, 13.81 J/kgK)
# I4_1/amd -> Pccn (552.23K, 6.24 J/kgK)
# Ia-3d -> I4_122 (483.94K, 7.40 J/kgK)
# Imma -> I4_122 (382.20K, 4.33 J/kgK)
# P2_1/c -> I4_122 (548.42K, 11.00 J/kgK)
# P6_3/mcm -> I4_122 (468.58K, 2.73 J/kgK)
# I4_122 -> Pcca (561.70K, 4.17 J/kgK)
# R-3m -> I4_122 (431.85K, 5.44 J/kgK)
# Ia-3d -> P6_3/mcm (493.15K, 4.67 J/kgK)
# Ia-3d -> Pcca (510.66K, 11.60 J/kgK)
# Ia-3d -> Pccn (345.96K, 3.64 J/kgK)
# Ima2 -> P4_2/mcm (541.97K, 13.76 J/kgK)
# Pna2_1 -> Ima2 (577.38K, 7.70 J/kgK)
# Imma -> Pbam (578.02K, 8.27 J/kgK)
# Imma -> Pcca (461.69K, 8.66 J/kgK)
# P-4n2 -> P-31c (326.75K, 8.11 J/kgK)
# P1 -> P-31c (308.94K, 5.89 J/kgK)
# P-4n2 -> P1 (379.74K, 2.19 J/kgK)
# Pnc2 -> P2/c (453.11K, 9.17 J/kgK)
# P2/m -> Pbam (453.86K, 6.51 J/kgK)
# P4_32_12 -> P2/m (491.19K, 0.47 J/kgK)
# Pnc2 -> P2/m (334.62K, 5.53 J/kgK)
# P2/m -> Pcca (340.10K, 6.39 J/kgK)
# P2_1 -> P23 (544.59K, 7.50 J/kgK)
# P2_1/c -> P6_3/mcm (577.90K, 8.23 J/kgK)
# P2_1/c -> Pcca (552.04K, 15.17 J/kgK)
# P2_1/c -> Pccn (492.79K, 7.53 J/kgK)
# Pnc2 -> P2_1/m (586.10K, 9.49 J/kgK)
# Pm -> P2_12_12 (357.11K, 2.23 J/kgK)
# P4_32_12 -> Pbam (456.30K, 6.98 J/kgK)
# Pnc2 -> Pbam (394.55K, 12.17 J/kgK)
# R-3m -> Pbam (592.87K, 9.23 J/kgK)
# P4_2/nbc -> P4_2/mcm (383.13K, 7.56 J/kgK)
# Pna2_1 -> P4_2/mcm (554.42K, 21.46 J/kgK)
# P4_2/mmc -> R-3c (529.49K, 13.23 J/kgK)
# Pnc2 -> P4_32_12 (322.43K, 5.01 J/kgK)
# P4_32_12 -> Pcca (348.99K, 6.90 J/kgK)
# P6/mmm -> R-3c (514.03K, 12.91 J/kgK)
# P6_3/mcm -> Pcca (522.82K, 6.93 J/kgK)
# R-3m -> P6_3/mcm (397.58K, 2.69 J/kgK)
# Pa-3 -> Pm-3n (575.24K, 7.74 J/kgK)
# Pnnn -> Pa-3 (369.83K, 3.99 J/kgK)
# Pnc2 -> Pcca (337.55K, 11.92 J/kgK)
# R-3m -> Pcca (484.08K, 9.69 J/kgK)
# Pna2_1 -> Pm-3n (399.68K, 12.49 J/kgK)
# Pnnn -> Pm-3n (494.45K, 11.99 J/kgK)
# CeTi2O6
# CeZr3O8
# CeZr7O16
# CeZrO4
# Cl2
# ClF3
# Co(C4N3)2
# Co(HO)2
# Co(IO3)2
# Co(PO2)2
# Co(PO3)3
# Co2As2O7
# Co2C2O7
# Co2OF3
# Cmcm -> Amm2 (515.36K, 18.08 J/kgK)
# Co2P2O7
# Co3(AsO4)2
# Co3(PO4)2
# Co3B7IO13
# Co3C10O9
# Co3OF5
# Co3TeO8
# Co5SbO8
# Co6OF11
# Co7(SbO6)2
# CoAgPO4
# CoAsS
# CoB10H23C13
# CoB4O7
# CoBP(HO3)2
# CoBi6(SO8)2
# CoF3
# CoH15Br2(N3O)2
# CoH15N6(ClO)2
# CoH22N7(ClO2)4
# CoH7C3NO6
# CoHCO3
# CoNiO3
# CoO
# R3m -> P6_3mc (552.88K, 101.92 J/kgK)
# CoO2
# P1 -> C2/m (592.27K, 89.32 J/kgK)
# CoP2WO8
# P2_1/m -> Pm (488.05K, 13.20 J/kgK)
# CoP3H16N4O11
# CoP4O11
# CoPH6NO5
# CoPO4
# CoPSe
# CoSO4
# Pnma -> Cmcm (429.65K, 94.26 J/kgK)
# CoSb(PO4)2
# CoSeO4
# CoTe(PbO3)2
# CoTe2O5
# Cr(GeO3)2
# Cr(PO3)2
# Cr(PO3)3
# Cr2(MoO4)3
# Pbcn -> P2_1/c (577.42K, 67.72 J/kgK)
# Cr2(WO4)3
# Cr2CdH14(NO2)4
# Cr2Cu3(OF)12
# Cr2FeO4
# Cr2NiO4
# Warning: 2 transitions within this interval
# Cc -> Cc (459.76K, 0.24 J/kgK)
# Cr2O3
# Cr2O5
# Cr2P4Pb3O16
# Cr2PO5
# C2/c -> Pnma (576.20K, 141.89 J/kgK)
# Cr3(FeO6)2
# P2_1/c -> Pbcn (571.08K, 55.97 J/kgK)
# Cr3(PO4)2
# Cr3B7ClO13
# Cr3O4
# Cr3O8
# Cr4OF11
# CrAgO2
# CrAgS2
# Cm -> Pc (337.63K, 24.32 J/kgK)
# CrAsO4
# Pnma -> Imma (354.47K, 119.59 J/kgK)
# CrBiO3
# CrBiO4
# CrCdO4
# CrCl3
# CrCoO4
# CrCuO2
# CrF3
# CrF4
# CrF5
# CrFe(PO4)2
# CrH14N4Cl3O
# CrH17N4Cl2O3
# CrH20N2O6F5
# CrHO2
# CrHSe3O8
# CrHgO4
# CrO2
# CrO3
# CrOF
# CrOF4
# C2/c -> P2_1/c (446.22K, 33.72 J/kgK)
# CrP2O7
# CrP4O11
# CrPO4
# CrPO5
# P4/n -> P-1 (563.13K, 89.51 J/kgK)
# Pnma -> P-1 (403.77K, 34.87 J/kgK)
# CrPbO4
# CrSO4
# CrSbO4
# CrWO6
# Cs2BeO2
# Cs2CdBr4
# Cs2CdI4
# P2_1/m -> Pnma (475.11K, 81.68 J/kgK)
# Cs2CeO3
# Cs2Hf(WO4)3
# Cs2HfO3
# Cs2HgBr4
# Pnma -> P2_1/c (435.49K, 84.90 J/kgK)
# Cs2HgCl4
# P2_1/c -> P2_12_12_1 (354.74K, 17.58 J/kgK)
# Pnma -> P2_12_12_1 (508.00K, 15.39 J/kgK)
# Cs2HgI4
# Cs2HgTe
# Cs2I4O11
# P2_1/c -> P6_3 (453.66K, 14.46 J/kgK)
# Cs2K2B10O17
# Cs2Li3I5
# P1 -> P1 (471.78K, 10.36 J/kgK)
# Cs2LiCr(CN)6
# P4/mnc -> P2_1/c (384.57K, 81.76 J/kgK)
# Cs2LiInCl6
# Cs2MgH4
# Cs2MgMo2(O2F3)2
# Cs2Mo(SO)2
# Cs2MoN(Cl2O)2
# Cs2NaAlF6
# Cs2NaFeF6
# Cs2NaGaF6
# Cs2Ni3S4
# P6_3/mmc -> Fmmm (479.96K, 70.33 J/kgK)
# Cs2NiH12(SO7)2
# Cs2O
# Cs2PbO3
# Cs2Pd(IBr2)2
# Cs2PdCl4
# Cs2S
# Cs2SbF5
# Cs2Se
# Cmc2_1 -> Fdd2 (390.91K, 96.63 J/kgK)
# Cmc2_1 -> P-3m1 (534.79K, 140.84 J/kgK)
# Cmc2_1 -> R-3m (307.69K, 61.41 J/kgK)
# Cmcm -> Fdd2 (359.16K, 90.15 J/kgK)
# Cmcm -> P-3m1 (511.59K, 136.68 J/kgK)
# P6_3/mmc -> Fdd2 (416.20K, 107.44 J/kgK)
# P2_1/c -> R-3m (325.09K, 112.33 J/kgK)
# Pnma -> R-3m (327.30K, 113.46 J/kgK)
# P6_3/mmc -> P-3m1 (547.62K, 150.22 J/kgK)
# P6_3/mmc -> R-3m (350.33K, 73.76 J/kgK)
# Cs2Tb6Te7N2
# Cs2Ti(PO4)2
# Cs2Ti(Si2O5)3
# Cs2U2O7
# Cs2WO4
# Cs2ZnI4
# Cs3As2Cl9
# Cs3Bi2Br9
# Cs3Bi2Cl9
# Cs3Bi2I9
# Cs3BiCl6
# Cs3BiF6
# Cs3Cr2I9
# Cs3DyO3
# Cs3ErCl6
# Cs3ErO3
# Cs3Fe2F9
# Cs3FeF6
# Cs3GaO3
# C2/m -> P2_1/c (464.01K, 6.55 J/kgK)
# Cs3H(SeO4)2
# Cm -> C2/c (414.56K, 9.46 J/kgK)
# C2/c -> P2_1/m (541.34K, 46.79 J/kgK)
# Cm -> P2_1/m (511.21K, 51.49 J/kgK)
# Cs3HoCl6
# Cs3HoO3
# Cs3LaBr6
# Cs3LaCl6
# Cs3LaO3
# Cs3LiCl4
# Cs3MgH5
# Cs3NO4
# Cs3PrCl6
# Cs3Sb2Cl9
# P-3m1 -> P321 (333.03K, 7.54 J/kgK)
# Cs3Sb2I9
# Cs3SbF6
# Cs3YF6
# Cs3YO3
# Cs4BiSbCl12
# Cs4CO4
# Cs4Na2MgV2O8
# Cs5Bi(MoO4)4
# Cs5YO4
# Cs8Mg(Sn2O3)4
# P-1 -> Pm (554.55K, 14.37 J/kgK)
# Cs8Na4Y3HoCl24
# CsAgBr2
# CsAgCl2
# CsAlF4
# CsAlSiO4
# CsAsO3
# CsAsSe2
# CsAu(IO3)4
# CsAu(SO4)2
# CsB3H8
# CsB5(H2O3)4
# CsB5O8
# CsBeF3
# CsBr
# Pm-3m -> Fm-3m (589.90K, 23.15 J/kgK)
# CsC3(SeN)3
# CsCN
# CsCaCl3
# P1 -> P1 (383.48K, 6.02 J/kgK)
# CsCaI3
# CsCdBr3
# CsCdCl3
# P6_3/mmc -> Pm-3m (459.77K, 70.83 J/kgK)
# CsCl
# CsClO3
# P2_1/m -> R3m (547.03K, 103.12 J/kgK)
# CsClO4
# Pnma -> F-43m (596.58K, 234.97 J/kgK)
# CsCoH18N6(ClO2)4
# CsCoO2
# CsCoPO4
# P2_1 -> Pna2_1 (313.86K, 23.36 J/kgK)
# CsCuCl3
# CsDyS2
# CsEr(MoO4)2
# CsEr(WO4)2
# CsEr2Cu3Se5
# CsF
# CsFe(MoO4)2
# CsFeO2
# CsGaH4
# CsGaO2
# CsGaP3HO10
# C2 -> P2/c (306.85K, 93.63 J/kgK)
# CsGd(MoO4)2
# CsGe
# CsGeBr3
# R3m -> Cm (504.49K, 23.79 J/kgK)
# CsGeI3
# Cm -> Cm (337.75K, 55.42 J/kgK)
# CsH
# CsH2SNO3
# CsH3O2
# CsH6Rh(N3O4)2
# CsHF2
# CsHO
# CsHSO4
# CsHgCl3
# CsHo(MoO4)2
# CsHo2Cu3Se5
# CsHoS2
# CsI
# CsLi(B3O5)2
# I2_12_12_1 -> P222_1 (475.65K, 77.48 J/kgK)
# CsLi2Cl3
# CsLiCl2
# CsLiO
# CsLiSO4
# CsLu(MoO4)2
# CsLuS2
# CsMg6BO7
# CsMgH3
# CsMo2P3O13
# Warning: 2 transitions within this interval
# P2_1 -> P1 (540.17K, 3.44 J/kgK)
# CsN3
# CsNO3
# CsNb(PO4)2
# CsNbN2
# CsNbO3
# CsNd(MoO4)2
# CsNd(PO3)4
# CsNdS2
# CsNiF3
# CsP(HO2)2
# P2_1 -> P2_1/m (572.43K, 68.06 J/kgK)
# CsP2H5O8
# CsP7
# CsPO3
# CsPSO2
# CsPSe6
# CsPb2Cl5
# CsPbBr3
# Amm2 -> Pm-3m (545.42K, 116.88 J/kgK)
# Pnma -> Amm2 (521.83K, 13.12 J/kgK)
# I4/mcm -> Pm-3m (551.11K, 125.09 J/kgK)
# Pnma -> I4/mcm (364.57K, 4.54 J/kgK)
# Pnma -> Pm-3m (542.99K, 130.01 J/kgK)
# CsPbCl3
# Amm2 -> Amm2 (537.36K, 0.70 J/kgK)
# CsPbF3
# CsPbI3
# CsPr(PO3)4
# CsPrS2
# CsSb
# CsSi
# CsSi2HO5
# CsSm(MoO4)2
# CsSm(PO3)4
# CsSn
# P-43n -> I4_1/acd (445.80K, 23.99 J/kgK)
# CsSnBr3
# CsSnCl3
# CsSnF3
# CsSnI3
# CsSrBr3
# P2_1 -> P1 (576.73K, 94.52 J/kgK)
# CsSrCl3
# CsSrI3
# CsTb(MoO4)2
# CsTbS2
# CsTi3P5O19
# CsTiCu3Se4
# CsVSO6
# CsW3Br7
# CsY(MoO4)2
# CsZnPO4
# Cu2H10C6S3N4
# Cu2SO4
# Cu2SiS3
# Cmc2_1 -> Fdd2 (401.68K, 53.50 J/kgK)
# Cu2WO4
# Cu2WS4
# CuAgS
# CuBi(WO4)2
# CuBi3PbS6
# CuBiO2
# CuCSN
# CuCl
# CuClO2
# CuH12C5S4N
# CuH12N2(Cl2O)2
# CuH2CN2Cl
# CuHgSBr
# CuI
# P3m1 -> P6_3mc (313.27K, 12.41 J/kgK)
# CuN3
# CuP2(HO)4
# CuP4S3Br
# Warning: 2 transitions within this interval
# Cmce -> P-1 (393.35K, 25.59 J/kgK)
# CuPO3
# CuW3Br7
# Pbca -> Pn-3 (548.38K, 3.08 J/kgK)
# Dy(ClO4)3
# Dy(PO3)3
# Dy2(MoO4)3
# Dy2(SeO4)3
# Dy2CO5
# Dy2Ge2O7
# P-1 -> Pnma (353.05K, 11.63 J/kgK)
# Dy2MgS4
# Dy2MgSe4
# Dy2MgV2O7
# Dy2O3
# Dy2P4O13
# Dy2S2O
# Dy2S3
# Dy2SO2
# Dy2Sb2O7
# Dy2SeO2
# Dy2Si2O7
# P-1 -> P1 (481.54K, 29.54 J/kgK)
# Dy2SiO5
# Dy2Te4O11
# Dy2TeO6
# Dy2Ti2O7
# Dy2TiO5
# Dy2WO6
# Dy2Zr2O7
# Fd-3m -> P2_1 (561.69K, 13.33 J/kgK)
# Dy3NbO7
# Dy3TaO7
# Dy6Mg(Sb5O12)2
# Warning: 2 transitions within this interval
# Cm -> R3m (393.47K, 7.25 J/kgK)
# DyAgTe2
# DyAlO3
# DyBO3
# DyClO
# DyCu(WO4)2
# DyCuS2
# P2_12_12_1 -> P2_12_12_1 (302.22K, 5.20 J/kgK)
# DyF3
# DyFe3(BO3)4
# P3_121 -> R32 (388.51K, 54.20 J/kgK)
# DyGaO3
# DyH9C5(NO4)2
# DyHO2
# DyInO3
# DyNbO4
# Warning: 2 transitions within this interval
# C2/c -> P2/c (394.30K, 14.50 J/kgK)
# C2/m -> I4_1/amd (304.11K, 50.65 J/kgK)
# DyP5O14
# DySbO4
# P2_1/c -> P-1 (445.20K, 12.24 J/kgK)
# DyTaO4
# DyVO4
# DyWO4
# Er(CuS)3
# Er(PO3)3
# Er2(WO4)3
# Er2CdS4
# Er2GeO5
# Er2MgS4
# Pnma -> Cmc2_1 (535.34K, 12.91 J/kgK)
# Er2MgSe4
# Er2O3
# Er2P4O13
# Er2PbS4
# Er2S3
# Er2Se3
# Er2Si2O7
# Er2SiO5
# Er2TeO2
# Er2TeO6
# Er2TiO5
# C2/c -> Cc (347.50K, 18.37 J/kgK)
# Er2WO6
# Er2Zr2O7
# Er3TaO7
# Er5Mg(MoO6)2
# ErAgS2
# ErAgTe2
# ErAlO3
# ErBO3
# ErBiO3
# ErBiW2O9
# Pnma -> Pmmn (345.62K, 13.82 J/kgK)
# ErClO
# ErCu(WO4)2
# P-1 -> P1 (337.26K, 22.81 J/kgK)
# ErCuS2
# ErGaO3
# ErH3(SO4)3
# ErInO3
# ErNbO4
# ErP5O14
# ErPaO4
# ErSbO4
# ErTa3O9
# ErTaO4
# ErVO4
# Eu(BH4)2
# EuBr2
# EuCl2
# EuI2
# F2
# Fe(BO2)2
# Fe(CO)5
# Fe(HO)2
# Fe(PO3)3
# Fe(SbO2)2
# Fe10O11F9
# Fe10O9F11
# Fe10OF19
# P1 -> Amm2 (408.07K, 8.59 J/kgK)
# Fe15O16
# Fe2(MoO4)3
# Pbcn -> P2_1 (589.39K, 28.49 J/kgK)
# Fe2(WO4)3
# Fe21HO32
# Fe2BO4
# Fe2C2O7
# Fe2CoO4
# Fe2CuAs2(HO5)2
# Fe2NiO4
# Fe2O3
# Fe2OF3
# Amm2 -> C2 (506.42K, 44.88 J/kgK)
# Amm2 -> Pmn2_1 (393.92K, 41.55 J/kgK)
# Pmn2_1 -> C2 (594.04K, 74.53 J/kgK)
# Pm -> P1 (478.31K, 80.92 J/kgK)
# Fe2P2O7
# P1 -> P1 (322.26K, 12.54 J/kgK)
# Fe2PClO4
# Fe2SiO4
# Fe3(OF)2
# Fe3(OF2)2
# Cmmm -> P2_1/c (569.94K, 261.37 J/kgK)
# Cmmm -> P4_2/mnm (537.67K, 190.27 J/kgK)
# P1 -> P2_1 (512.58K, 12.88 J/kgK)
# P1 -> P4_2/mnm (356.98K, 133.77 J/kgK)
# P2_1 -> P4_2/mnm (329.71K, 111.70 J/kgK)
# P2_1/c -> P4_2/mnm (425.58K, 108.00 J/kgK)
# Fe3(P2O7)2
# Fe3(SiO4)2
# Fe3B7BrO13
# Fe3B7IO13
# Fe3BO5
# Fe3H9S2O15
# Fe3O4
# Fe3OF5
# Warning: 2 transitions within this interval
# C2/m -> Pm (362.80K, 175.46 J/kgK)
# Warning: 2 transitions within this interval
# P2/m -> Cmmm (306.69K, 44.86 J/kgK)
# Cmmm -> Pmn2_1 (527.38K, 139.93 J/kgK)
# Fe3OF7
# Fe4(PO4)3
# Fe4As2O11
# Fe4As5O13
# Fe4Bi2O9
# Fe4H14O13
# Fe4O3F5
# P2_1 -> Pc (351.52K, 16.83 J/kgK)
# Fe4OF6
# Fe4OF7
# Cmcm -> Amm2 (313.16K, 241.27 J/kgK)
# Warning: 2 transitions within this interval
# Pc -> Amm2 (475.39K, 75.71 J/kgK)
# P1 -> Cmc2_1 (300.35K, 252.06 J/kgK)
# Fe5(OF4)2
# P2_1/c -> P2_1 (366.67K, 25.08 J/kgK)
# Pm -> P2_1 (307.92K, 13.04 J/kgK)
# P2_1/c -> Pm (418.18K, 20.43 J/kgK)
# Fe5(SiO4)3
# Fe5O3F7
# Pc -> P1 (508.60K, 22.22 J/kgK)
# Fe5P3O13
# Fe6O5F7
# P1 -> Cm (379.94K, 62.11 J/kgK)
# Pm -> Cm (404.06K, 59.93 J/kgK)
# Fe6OF11
# Fe8O9
# FeAgO2
# FeAsO4
# FeBO3
# FeBP(HO3)2
# FeBi25O39
# FeBiO3
# FeF3
# C2/c -> Fd-3m (350.47K, 536.80 J/kgK)
# P321 -> C2/c (513.77K, 250.52 J/kgK)
# Cmcm -> Fd-3m (406.44K, 411.36 J/kgK)
# P321 -> Fd-3m (368.92K, 474.41 J/kgK)
# C2/c -> Fd-3m (532.44K, 493.72 J/kgK)
# FeH7C3NO6
# FeHO2
# Pmc2_1 -> C2/m (545.65K, 130.23 J/kgK)
# FeMoClO4
# P4/nmm -> Cm (310.01K, 118.33 J/kgK)
# FeO
# FeOF
# P1 -> R3 (337.11K, 194.70 J/kgK)
# Cccm -> R3 (563.32K, 106.75 J/kgK)
# Pnma -> Pmc2_1 (383.13K, 79.64 J/kgK)
# FeP(H2O3)2
# FeP4
# FeP4O11
# FePH5CO4
# FePH5NO4F
# FePH6(NO2)2
# FePH6NO5
# FePO4
# Warning: 2 transitions within this interval
# P1 -> Pna2_1 (396.27K, 110.37 J/kgK)
# C2 -> Pnma (402.29K, 86.75 J/kgK)
# C2 -> R3 (323.71K, 136.62 J/kgK)
# Warning: 2 transitions within this interval
# P6_422 -> Pna2_1 (364.15K, 161.70 J/kgK)
# FeSO4
# FeSO4F
# FeSbO4
# FeSiO3
# FeSiO4
# FeSnO3
# FeTe(PO4)2
# Ga2(SO4)3
# Ga2CoO4
# Ga2HgO4
# Ga2NiO4
# Ga2O3
# Ga2PbO4
# Ga2PbSe4
# Ga2S3
# Ga2Se3
# Ga2WO6
# Ga3Bi5Cl12
# Ga3NO3
# P1 -> C2/m (485.83K, 48.71 J/kgK)
# Ga4B2O9
# Ga4Bi2O9
# Ga6SnTe10
# GaAg(PSe3)2
# GaAgO2
# GaAgS2
# GaAgSeS
# GaAsO4
# GaBiN2
# GaBiO3
# GaBr2
# GaCl3
# GaCuO2
# GaH20C2S2NO14
# GaHO2
# GaHg2SbCl4
# Pna2_1 -> Pbcn (548.20K, 12.86 J/kgK)
# GaHg3AsSCl4
# GaN
# GaN5O14
# GaP
# F-43m -> P6_3mc (546.93K, 45.92 J/kgK)
# GaP2H15C5(NO4)2
# GaPO4
# GaS
# GaSe
# P6_3mc -> P-6m2 (447.10K, 16.93 J/kgK)
# P6_3/mmc -> R3m (306.78K, 16.76 J/kgK)
# GaTe
# Gd(BO2)3
# Gd(PO3)3
# Gd2(MoO4)3
# Gd2(WO4)3
# Gd2B4O9
# Gd2HfO5
# Gd2MgS4
# I-42d -> Pnma (414.78K, 11.29 J/kgK)
# Gd2O3
# Gd2P4O13
# Gd2S3
# Gd2Si2O7
# Gd2TiO5
# Gd2V2O7
# Gd2W2O9
# C222_1 -> Pbcn (561.58K, 81.96 J/kgK)
# Gd2W4O15
# Gd2Zr2O7
# P2_1/c -> Pmna (435.75K, 37.02 J/kgK)
# Gd3AsO7
# Gd3InO6
# Gd3InS6
# Gd3NbO7
# Gd3SbO7
# Gd3TaO7
# Gd3Y13O24
# Gd3YO6
# Gd4(SiS4)3
# Gd6MgWO12
# GdAl3(BO3)4
# GdAlO3
# GdAsO4
# GdB2HO5
# GdBO3
# GdCrO3
# GdFe3(BO3)4
# GdInO3
# GdOF
# GdPO4
# GdTa3O9
# GdTiCdSbO7
# GdZr3F15
# Ge(BrF5)2
# Ge(PbS2)2
# Ge(SeO3)2
# Ge2MoO6
# Ge2N2O
# Ge2WO6
# Ge3N4
# Ge3Pb3O10
# Ge3Pb5O11
# P3 -> P-6 (343.16K, 7.39 J/kgK)
# Ge4PbO9
# GeBi2O5
# GeBr2
# GeBr4
# P2_1/c -> Pa-3 (397.58K, 6.34 J/kgK)
# GeC
# P6_3mc -> F-43m (435.71K, 140.52 J/kgK)
# GeCN2
# GeF2
# GeH4
# GeI2
# P-3m1 -> P3m1 (523.99K, 4.89 J/kgK)
# GeO2
# P3_221 -> P4_12_12 (574.93K, 304.75 J/kgK)
# GePb3O5
# GePbN2
# GePbO3
# GeS
# GeS2
# GeSe2
# Fdd2 -> I-42d (349.27K, 14.81 J/kgK)
# GeTe
# GeWO4
# H(CO)2
# H(WO3)2
# H10C3NClO4
# H12C4N2O9
# H13S2N3O8
# H13Se2N3O8
# H16PdC4S4(N4Cl)2
# H2
# H24C8S(NO2)2
# H2C(NO)2
# H2CBrCl
# P2_12_12 -> C2/c (558.05K, 247.82 J/kgK)
# H2CN2
# H2CO
# H2O
# H2S
# H2SO4
# H2SeO3
# P1 -> P2_12_12_1 (433.84K, 64.63 J/kgK)
# H2SeO4
# H2W2O7
# H3BrO
# H3CI
# H3CSNOF2
# H3ClO5
# H3N
# H3NCl
# H3NO
# H3S
# H4BrN
# H4C(N2O)2
# H4C2O
# H4CN2O
# H4CS(NO)2
# H4CSN2
# H4IN
# H4N2O3
# H4NClO4
# H4NF
# H4PbI3N
# H4Pd(NO4)2
# H4SO5
# H5BrO2
# H5CN3
# H5ClO6
# H5IO6
# H5NO
# H5SeNO4
# H6C(NO)2
# H6C(SN)2
# H6C2SO4
# H6CIN
# H6CN2O3
# H6CNF
# H6N4O9
# H6PbCBr3N
# H6PbCI3N
# H6PbCNCl3
# H7BrO3
# H7C4(N3O2)3
# H7ClO3
# H7NO6
# H7SIO10
# H8C2BrN
# H8C2NCl
# H8C3N2O
# H8N2O
# H8Pd(NCl3)2
# P2_1/c -> Fm-3m (532.29K, 115.46 J/kgK)
# H8S(NO2)2
# H8W3Se(NO6)2
# H9BrO4
# H9CN9
# HAuO2
# Pmn2_1 -> C2/m (486.60K, 38.58 J/kgK)
# HBr
# P1 -> Fmmm (493.52K, 140.24 J/kgK)
# HC
# HC2N3
# HCN
# HCl
# HF
# HIO3
# HIO4
# HN
# HNO
# HNO3
# P2_1/c -> P2_1 (565.45K, 142.52 J/kgK)
# HPbClO
# HS3N
# Hf(MoO4)2
# Hf(PS3)2
# Hf2N2O
# Warning: 2 transitions within this interval
# I4_1/amd -> P2_1/m (342.65K, 13.40 J/kgK)
# P2_1/m -> P2_1/c (579.71K, 53.16 J/kgK)
# P2_1/m -> Pm (547.94K, 26.41 J/kgK)
# Hf2P2O9
# Hf2SN2
# Hf3N2O3
# Hf3N4
# HfBrN
# HfCrAgS4
# P2/m -> Cm (355.57K, 8.05 J/kgK)
# Pmc2_1 -> Pmn2_1 (398.72K, 11.08 J/kgK)
# HfCrCuS4
# HfCrO4
# HfI4
# HfMg30BO31
# HfN2
# HfO2
# P4_2/mnm -> Pbcn (367.44K, 7.41 J/kgK)
# HfP2O7
# HfPbO3
# HfSO
# HfTaNO3
# HfTi4(PbO3)5
# HfTiO4
# HfZrO4
# Hg
# I-43m -> P4_132 (360.77K, 33.46 J/kgK)
# Hg(CO2)2
# P2_1/c -> P2_1 (514.78K, 12.40 J/kgK)
# Hg15(As2Cl3)4
# P2_1/c -> Pna2_1 (480.84K, 8.64 J/kgK)
# Hg2ClO
# Hg2GeO4
# Hg2Mo2O7
# P2/c -> C2/c (308.44K, 5.13 J/kgK)
# Hg2MoO4
# Hg2N2O3
# Hg2SeO3
# Cmc2_1 -> Ibam (587.35K, 14.23 J/kgK)
# Hg2Te2O7
# Hg2W2O7
# C2/c -> P2/c (391.91K, 10.79 J/kgK)
# Hg3(SCl)2
# I2_13 -> Pm-3n (339.07K, 30.65 J/kgK)
# Hg3(SeI)2
# Hg3SO6
# Hg3TeO6
# HgB4O7
# HgBr2
# HgBrCl
# HgC2(SN)2
# HgCN2
# Pbca -> P2_1/c (570.46K, 116.32 J/kgK)
# HgF2
# HgH16(Br3N2)2
# HgI2
# C2/c -> C2 (385.41K, 3.75 J/kgK)
# P4_2/nmc -> C2 (571.83K, 11.61 J/kgK)
# HgN6
# HgO
# Pnma -> P2_1/m (489.54K, 54.06 J/kgK)
# HgS
# HgSeO3
# HgWO4
# Ho(ClO4)3
# Ho14(PbS8)3
# Ho2(MoO4)3
# Ho2(SO4)3
# Ho2(SeO3)3
# Ho2(SeO4)3
# Ho2(WO4)3
# Ho2B4O9
# Ho2CdS4
# Ho2CdSe4
# Ho2Ge2O7
# Ho2MgAg2(WO4)4
# Ho2MgMo2(ClO4)2
# Ho2MgS4
# Ho2MgSe4
# Ho2MgV2O7
# Ho2O3
# Ho2P4O13
# Ho2PbS4
# Ho2S3
# P2_1/m -> R-3c (545.67K, 54.71 J/kgK)
# Ho2SO2
# Ho2Sb2O7
# Ho2Se3
# Ho2Si2O7
# Ho2TeO2
# Ho2TeO6
# Ho2Ti2O7
# Ho2TiO5
# Ho2WO6
# Ho2Zr2O7
# Ho3TaO7
# Ho6MgWO12
# HoAgS2
# HoAgSe2
# HoAgTe2
# HoAl3(BO3)4
# R32 -> C2/c (382.50K, 88.44 J/kgK)
# HoAsO4
# HoBO3
# HoBiO3
# HoBrO
# HoCuO2
# HoCuS2
# Pnma -> P2_12_12_1 (421.04K, 14.01 J/kgK)
# HoCuSe2
# HoErO3
# HoFe3(BO3)4
# P3_121 -> R32 (344.78K, 68.94 J/kgK)
# HoGaO3
# HoH9C5(NO4)2
# HoHO2
# Pmn2_1 -> Pnma (479.35K, 157.50 J/kgK)
# HoIO
# HoInO3
# HoP5O14
# HoPaO4
# HoSbO4
# HoTa3O9
# HoTaO4
# HoVO4
# IF7
# In(HO)3
# In(IO3)3
# In(PO3)3
# In10(Pb2S7)3
# P1 -> P-1 (319.77K, 6.53 J/kgK)
# In2(SO4)3
# In2(WO4)3
# In2Br3
# In2Ge2O7
# In2O3
# In2S3
# Cc -> Imm2 (410.69K, 13.91 J/kgK)
# In2Se3
# In2Si2O7
# In2Te5
# In2WO6
# In3SnI5
# In4(SnO4)3
# P-1 -> P1 (539.00K, 16.81 J/kgK)
# In4Br7
# In5(BiS4)3
# In5Br7
# InBN2
# InBiO3
# InCl
# InGaS3
# InGeCl3
# InHO2
# P2_13 -> Pa-3 (552.82K, 126.68 J/kgK)
# InHSeO4
# InOF
# InP(H2O3)2
# InP2H9(NO4)2
# InPO4
# InPbCl3
# InSe
# InSnBr3
# InSnCl3
# Cm -> Fmm2 (363.39K, 94.83 J/kgK)
# K2(NbBr3)3
# K2Al2B2O7
# C2 -> C2 (332.12K, 41.83 J/kgK)
# K2BaLiCo(NO2)6
# K2BaNi(NO2)6
# K2BeF4
# K2C7N4O
# K2CO3
# K2Ca2(SO4)3
# P2_12_12_1 -> P2_13 (532.69K, 41.10 J/kgK)
# K2Ca3Si3O10
# K2Cd2(SO4)3
# K2Ce(NO3)6
# P2_1/c -> P-3 (352.14K, 119.07 J/kgK)
# K2Ce(PO4)2
# K2CoCl4
# K2CoP4(HO2)8
# K2Cr2AsHO10
# K2Cr2O7
# P-1 -> C2/c (479.72K, 28.50 J/kgK)
# K2CrO4
# Pnma -> P2_1/c (548.58K, 177.36 J/kgK)
# K2Cu(CO3)2
# K2Dy4Cu4S9
# K2FeF5
# C2/m -> Pbam (304.96K, 31.23 J/kgK)
# C2/m -> Pbcn (576.24K, 10.79 J/kgK)
# C2/m -> Pnma (382.69K, 56.57 J/kgK)
# Pbam -> Pnma (516.74K, 23.46 J/kgK)
# Pbcn -> Pnma (345.72K, 44.63 J/kgK)
# K2FeH8(SO6)2
# K2FeO4
# K2Ge2Se5
# K2GeF6
# K2HS2NO6
# K2HfF6
# K2Hg3(GeS4)2
# C2 -> Aea2 (511.21K, 5.60 J/kgK)
# K2HgCl4
# K2Ho4Cu4S9
# K2LiAlF6
# R-3m -> P-3m1 (568.24K, 14.92 J/kgK)
# K2LiAlH6
# K2LiMn2O4
# K2LiNbO4
# K2LiS2(O2F)2
# K2Mg(CO3)2
# R-3m -> C2/m (319.74K, 128.95 J/kgK)
# K2Mg(CoO2)2
# K2Mg(FeO2)2
# K2Mg2(MoO4)3
# K2Mg2O3
# K2MgFe4P6(O4F3)4
# K2MgH8(SO6)2
# K2MgMn2P6(HO10)2
# K2MgMn3V2(HO5)2
# K2MgZn4P4(HO8)2
# K2Mn2Be3F12
# K2MnF6
# K2MnH8(SO6)2
# K2MnSO4F3
# K2Mo(SO)2
# K2Mo2P2O11
# K2Mo4O13
# K2NaAl3F12
# K2NaCl3
# K2NaMo(OF)3
# K2NaNb(OF2)2
# P1 -> I4/mmm (514.74K, 49.36 J/kgK)
# P4_2/mnm -> I4/mmm (548.53K, 57.93 J/kgK)
# P2_1 -> I4/mmm (468.36K, 45.58 J/kgK)
# K2NbAgS4
# K2Ni3S4
# K2O
# C2/m -> P1 (524.49K, 179.52 J/kgK)
# K2O2
# K2P2H2O7
# K2P3
# K2PbO3
# Pnma -> Cmc2_1 (408.82K, 14.87 J/kgK)
# K2Pd3Se4
# K2PdN2(ClO2)2
# K2S
# K2SO4
# K2SbF5
# P2_1/c -> Cmcm (417.01K, 46.31 J/kgK)
# K2SeO4
# K2Si3SnO9
# K2Si4O9
# K2SiF6
# K2Sm2Mg(MoO4)4
# K2Sn2O3
# K2SnBr6
# P4/mnc -> Fm-3m (422.06K, 23.17 J/kgK)
# K2SnCl6
# P2_1/c -> Fm-3m (591.98K, 133.44 J/kgK)
# K2SnF6
# K2SnH2OF6
# K2SrCl4
# K2TaAgS4
# K2TaF7
# K2TaNbO6
# P4/mmm -> Fm-3m (408.90K, 74.84 J/kgK)
# K2Te(WO4)3
# P2_1/c -> Pnma (383.25K, 10.89 J/kgK)
# K2TeBr6
# K2TeH6SeO10
# K2Ti(Si2O5)3
# P-1 -> Cc (313.13K, 26.49 J/kgK)
# P-1 -> P2_1 (392.44K, 29.11 J/kgK)
# K2Ti(SiO3)3
# K2TiCr(PO4)3
# K2U2O7
# K2VAgS4
# K2VAgSe4
# K2VCuS4
# K2VCuSe4
# K2VOF4
# K2WO4
# K2YHf(PO4)3
# K2YTi(PO4)3
# K2Zn(CN)4
# K2Zn(H2N)4
# P2_1/c -> P-1 (464.27K, 145.58 J/kgK)
# K2Zn3S4
# Ibam -> Pnma (460.91K, 41.82 J/kgK)
# K2Zn6O7
# P4_2nm -> P4_2nm (332.32K, 34.24 J/kgK)
# K2ZnBr4
# P2_1/m -> P2_1 (349.81K, 6.82 J/kgK)
# K2ZnCl4
# K2ZrF6
# Cmcm -> C2/c (451.33K, 85.69 J/kgK)
# K2ZrFe(PO4)3
# K2ZrSi2O7
# P2_1/c -> C2/m (524.37K, 25.42 J/kgK)
# K2ZrSi3O10
# K3AlF6
# K3AlH6
# K3AsF6
# K3AsS4
# Pna2_1 -> Pna2_1 (400.58K, 34.06 J/kgK)
# K3AuF6
# K3B12H12Br
# K3ClO
# Amm2 -> Pnma (463.63K, 19.79 J/kgK)
# K3Co(CN)6
# K3CoPCO7
# K3Cr(CN)6
# K3CrF6
# K3DyCl6
# K3DyF6
# K3ErCl6
# K3ErF6
# K3FePCO7
# K3GdCl6
# K3H(SO4)2
# K3H(SeO4)2
# K3HoCl6
# K3HoF6
# K3IO5
# K3In(PO4)2
# K3InCl6
# K3InF6
# K3Li2Nb5O15
# K3Lu(PO4)2
# K3LuF6
# K3MgSbS4
# K3MoCl6
# K3Na(SeO4)2
# K3Na3TeP6(HO4)6
# K3NaCr2O8
# K3NaMgCr2O8
# K3NaP4(H2O7)2
# K3Nb3(BO6)2
# K3Nb3Si2O13
# K3NiO2
# P2_1 -> P4_2/mnm (411.37K, 50.39 J/kgK)
# K3PrCl6
# K3RhF6
# P-1 -> P-1 (410.72K, 8.64 J/kgK)
# K3SO4F
# K3Sb5O14
# K3SbS4
# K3SmF6
# K3Ta2S11
# K3TbF6
# K3VO4
# K3YCl6
# K3YF6
# K4(BSe)9
# K4BaTi6S20O
# P6_322 -> Fdd2 (325.30K, 34.94 J/kgK)
# K4BaU3O12
# K4CO4
# K4Gd2C3O9F4
# K4GeO4
# P-1 -> P2_1/c (431.04K, 38.52 J/kgK)
# K4Mg(MoO4)2
# K4MgMo2(SO3)2
# K4MgV2O7
# K4MgV4O10
# K4MgV6O16
# K4NaCl5
# I4/mmm -> C2/m (420.10K, 32.38 J/kgK)
# I4/mmm -> I4/m (540.79K, 57.29 J/kgK)
# Immm -> I4/m (492.37K, 14.37 J/kgK)
# I4/mmm -> Immm (558.11K, 42.83 J/kgK)
# K4PH5Se3O16
# K4Sr(SiO3)3
# K4Sr2SnAs4
# K4Ta2S11
# K4TiO4
# K5HfIn(MoO4)6
# R3 -> R-3c (340.61K, 12.56 J/kgK)
# K5In(MoO4)4
# K6Ba2CaU6O24
# K6BiH3(Cl2F)4
# K6InP3
# K6Mg(SbS4)2
# K6MgV2(SO3)2
# K6Sb2H18S8O9
# K6Ti2O7
# K8MgCo2(Mo4O15)2
# KAgCO3
# KAgO2
# KAl(SO4)2
# KAl(SiO3)2
# KAl11O17
# KAl2P2H5O11
# KAl3(SiO4)3
# KAl3Si3(HO6)2
# KAlF4
# P4/mbm -> P4/mmm (342.39K, 55.01 J/kgK)
# KAlH4
# KAlO2
# KAlSi3O8
# KAlSiO4
# KAlTe2
# KAs(HO2)2
# KAsF6
# KAsO3
# KAsOF5
# KAu(IO3)4
# KAuCl4
# KAuO2
# KB3O5
# KBF4
# KBH4
# KBaBiWO6
# KBaCeBiO6
# KBaCr2(PO4)3
# KBaGdWO6
# KBaLaSeO6
# KBaLaWO6
# KBaLiZnF6
# KBaNdWO6
# KBaPrWO6
# KBe2B3O7
# C2/c -> Pmn2_1 (442.99K, 106.93 J/kgK)
# P2_1 -> Pmn2_1 (568.30K, 76.76 J/kgK)
# KBe2BO3F2
# KBi(PSe3)2
# KBiF4
# KBiF6
# Ia-3 -> P-4c2 (483.38K, 41.27 J/kgK)
# Ia-3 -> P-4c2 (488.45K, 44.11 J/kgK)
# P-4c2 -> P-4c2 (569.13K, 2.80 J/kgK)
# KBr
# KC
# Fm-3m -> C2/c (351.86K, 32.91 J/kgK)
# KC(NO2)3
# KC2N3
# KCN
# KCNO
# KCSN
# Pbcm -> Ima2 (566.99K, 247.46 J/kgK)
# KCa2Nb3O10
# KCaBr3
# P2_1/m -> Pnma (361.82K, 20.34 J/kgK)
# KCaCeBiO6
# KCaCeNbO6
# KCaCl3
# Cm -> Pm-3m (496.08K, 1.09 J/kgK)
# KCaF3
# KCaLaWO6
# KCaNdWO6
# KCaPrWO6
# KCdF3
# KCdN
# KCeNbSnO6
# KCl
# KClO3
# Pnma -> R3m (558.99K, 135.50 J/kgK)
# KClO4
# KCo(CO)4
# KCoH3(CO2)3
# KCoO2
# KCr(SO4)2
# KCrF3
# C2/m -> P4/mmm (583.14K, 228.55 J/kgK)
# KCrH18N6(ClO2)4
# KCrO2
# KCuO
# KDy(MoO4)2
# C2/c -> P-1 (434.56K, 28.53 J/kgK)
# KDy(PO3)4
# P2_1/c -> C2/c (459.94K, 8.73 J/kgK)
# KEr(MoO4)2
# KEr(PO3)4
# KEr2F7
# KEr3F10
# Cm -> Immm (442.78K, 14.85 J/kgK)
# KF
# KFe(MoO4)2
# KFe(SO4)2
# KFeBP2HO9
# KFeF4
# KFeO2
# KFePO4
# KGaTe2
# KGd(MoO4)2
# KGd(PO3)4
# C2/c -> P2_1 (536.81K, 37.82 J/kgK)
# KGdSnWO6
# KGe
# KGeBr3
# KGeCl3
# KGeN
# Warning: 2 transitions within this interval
# R3m -> P6_3mc (356.57K, 93.53 J/kgK)
# KH(IO3)2
# KH3(SeO3)2
# KH8W(NF3)2
# KH8WN2(OF)3
# KHCO3
# KHO
# P2_1/c -> Cmc2_1 (429.81K, 61.33 J/kgK)
# KHS
# KHgC3(SN)3
# KHo(MoO4)2
# KHo2Cu(MoO4)4
# KHo2F7
# KI
# Cmcm -> Pnma (478.98K, 18.34 J/kgK)
# KIO3
# R3m -> R3 (321.38K, 19.65 J/kgK)
# KIn5S8
# Cm -> C2/m (522.77K, 21.91 J/kgK)
# KInBr3
# KInSe2
# KLa(PO3)4
# KLa(WO4)2
# KLaCeHfO6
# KLaCeSnO6
# KLaDyBiO6
# KLaF4
# KLaMg14O16
# KLaMnWO6
# KLaPrSbO6
# KLaSiS4
# KLaSmSbO6
# KLaTbBiO6
# KLaTiO4
# Pbcm -> P4/nmm (306.91K, 23.77 J/kgK)
# KLaYBiO6
# KLi(PO3)2
# KLi2FeO3
# KLiMg30O31
# KLiMoO4
# KLiS
# KLiSO4
# KLiWO4
# KLiZnP2O7
# KLu(MoO4)2
# KLu3F10
# KMg14AlO16
# KMg14BO16
# KMg14BiO16
# KMg14GaO16
# KMg14SbO16
# KMg14WO16
# KMg3(SiO3)4
# KMg30BO31
# KMg3AlSi3(O5F)2
# KMgAg2SbS4
# KMgFe(PO4)2
# KMgIn(MoO4)3
# KMgNi2H3(SeO5)2
# KMn2O4
# KMn4(PO4)3
# KMnF3
# KMnIO6
# KMnO2
# KMnP3HO10
# KMnSn3O8
# KMo2P3O13
# KMoIO6
# KNO2
# Imm2 -> P2_1/c (528.81K, 196.55 J/kgK)
# KNO3
# P2_1/m -> P2_1/c (428.57K, 260.64 J/kgK)
# R3m -> P2_1/c (539.27K, 346.40 J/kgK)
# R32 -> Pnma (595.28K, 414.17 J/kgK)
# KNa(BH4)2
# R-3 -> R3 (510.38K, 334.78 J/kgK)
# KNa3Al4(SiO4)4
# KNa4Cl5
# C2/m -> I4/mmm (526.76K, 105.36 J/kgK)
# KNaAl6Si6(HO6)4
# P2 -> P1 (513.24K, 44.55 J/kgK)
# KNaMg2F6
# KNaMg30O31
# KNaNb2O6
# Pm -> Cm (367.20K, 19.46 J/kgK)
# KNaNbOF5
# KNaSO4
# KNaSe
# KNaTi4(BiO6)2
# KNb(BO3)2
# Pna2_1 -> Pmn2_1 (321.55K, 195.47 J/kgK)
# KNb4AsO13
# KNb5Pb2O15
# KNbCl6
# P2_1 -> R3m (587.22K, 68.10 J/kgK)
# Pmn2_1 -> P2_1/c (349.23K, 30.00 J/kgK)
# P2_1/c -> R3m (387.65K, 18.28 J/kgK)
# Pmn2_1 -> R3m (363.31K, 48.34 J/kgK)
# KNbF6
# KNbO3
# P4mm -> R3m (510.65K, 19.49 J/kgK)
# KNd(PO3)4
# KNd(SO4)2
# P-1 -> P2_1/c (366.70K, 34.74 J/kgK)
# KNdO2
# KNdSnWO6
# KO3
# I4/mcm -> Imm2 (595.17K, 113.80 J/kgK)
# KP(HO2)2
# Cc -> P-1 (390.06K, 57.51 J/kgK)
# P2_1/c -> P2_1 (307.64K, 64.16 J/kgK)
# Warning: 2 transitions within this interval
# P2_1/c -> Pc (362.58K, 10.04 J/kgK)
# KPF6
# KPO3
# KPSe3
# P3_1 -> P3_121 (497.31K, 7.34 J/kgK)
# KPb2Cl5
# KPbN
# KPr(PO3)4
# KS2N(O2F)2
# KSO2F
# P2_1/m -> P2_1 (487.16K, 64.49 J/kgK)
# KSb2PO8
# Cc -> C2/c (342.34K, 18.10 J/kgK)
# KSb4F13
# KSb5O13
# KSbF6
# KSbO3
# KSbSe2
# KSi
# KSi2HO5
# KSm(MoO4)2
# KSm(WO4)2
# KSmSnWO6
# KSn2F5
# KSnN
# KSrBiWO6
# KSrCeBiO6
# KSrCeNbO6
# KSrCeSbO6
# KSrGdWO6
# KSrLaWO6
# KSrNdWO6
# KSrPrWO6
# KSrSbWO6
# KSrSmWO6
# KSrVO4
# KSrZrBiO6
# KTaF6
# KTb(MoO4)2
# KTbSnWO6
# KTeOF3
# KTi2(PO4)3
# KUN3O11
# KUP3O11
# KV2PO8
# KVPO5
# KY(PO3)4
# KY3F10
# KYF4
# KYMg14O16
# KYP2O7
# KYSnWO6
# KZnP2H5O9
# KZnPO4
# Kr
# Fm-3m -> Im-3m (332.84K, 109.30 J/kgK)
# La(BO2)3
# La(ClO4)3
# La(HO)3
# P2_1/m -> P2_1/m (322.49K, 36.64 J/kgK)
# La2(SiO3)3
# La20S29O
# La2CO5
# La2Ce2O7
# La2CrO6
# La2Fe(SeO)2
# La2Ge2O7
# P1 -> P-1 (461.18K, 1.63 J/kgK)
# La2Hf2O7
# La2HfO5
# La2Mg(FeO3)2
# La2Mg(NiO3)2
# La2MgFe2(TeO6)2
# La2MgMnZnO6
# La2MgMoO6
# La2MgO4
# La2MgS4
# La2MgSe4
# La2MgSnO6
# La2MgTiO6
# La2MgTiZnO6
# La2Mn(SeO)2
# La2MnCrO6
# La2MnNiO6
# La2MoO6
# P2_1/c -> I-42m (467.46K, 64.74 J/kgK)
# La2Nb2N2O5
# C2 -> Cm (303.25K, 15.68 J/kgK)
# La2Ni2O5
# La2O3
# La2P4O13
# La2S2O
# La2S3
# La2Se2O
# La2Si(IO2)2
# La2Si2O7
# La2SiO5
# La2TeO6
# La2Ti2O7
# La2Ti3(BiO6)2
# La2Ti3O9
# P6_3/m -> Pnma (545.54K, 20.36 J/kgK)
# La2TiZnO6
# La2WO6
# La2Zr2O7
# La3NbO7
# La3Nd(GaO3)4
# La3SbO7
# La3Si2ClO8
# La3TaO7
# La3Ti2N3O4
# La4Al2O9
# La4Al6O15
# La4FeSe6O
# P1 -> P1 (329.81K, 5.02 J/kgK)
# La4MgCr2O12
# La4MnO8
# La4MnS6O
# La4Ti3O12
# La5C2I9
# La6MgWO12
# La6NbGa11O28
# La6TaGa11O28
# LaAgO2
# R-3m -> P6_3/mmc (507.52K, 12.77 J/kgK)
# LaAlO3
# Imma -> R-3c (371.43K, 11.69 J/kgK)
# P2_1/c -> P-1 (503.73K, 40.47 J/kgK)
# LaAsO4
# LaAuO2
# LaBO3
# LaBiO3
# R3c -> R-3 (397.36K, 28.22 J/kgK)
# LaClO2
# LaCoO3
# LaCrO3
# LaCrTeO6
# LaErS3
# LaF3
# LaFeO3
# P2_1 -> Pm-3m (593.71K, 96.34 J/kgK)
# LaFeTeO6
# LaGaO3
# LaGaS3
# P2_1/c -> Pna2_1 (587.24K, 46.58 J/kgK)
# LaH3CSO7
# LaH6S3(NO3)3
# LaHoO3
# LaMgCrMoO6
# LaMgFeSnO6
# LaMgI5
# LaMnO3
# LaMoN3
# Ama2 -> P2_1/m (422.78K, 51.33 J/kgK)
# Ama2 -> R3c (505.99K, 83.58 J/kgK)
# LaN
# LaNO4
# LaNb2AgO7
# LaNb3O9
# LaNbO4
# LaOF
# LaP5O14
# LaPO4
# LaPr3Al4O12
# LaS2
# Pna2_1 -> Pnma (431.56K, 31.05 J/kgK)
# LaSO
# LaSiBO5
# LaTa2NO5
# LaTa3O9
# LaTaO4
# LaTaTiO6
# LaTeCl
# Pnma -> P4/nmm (489.49K, 19.70 J/kgK)
# LaTiAlPbO6
# LaTiNO2
# I2_12_12_1 -> P2_1 (481.02K, 49.26 J/kgK)
# LaTiNbO6
# LaVO4
# LaWN3
# C2/c -> P2_1/m (503.29K, 48.56 J/kgK)
# LaZnCrWO6
# Li(BH)6
# Li(CoO2)2
# Li(CoO2)3
# Li(CoO2)4
# Li(Fe2O3)4
# Li(MoO2)2
# Li10Co(SiO5)2
# Li10Co4O9
# Li10Cr(SiO5)2
# Li10Cr3Fe3(NiO8)2
# Li10Ge(PO6)2
# Li10Ge(PS6)2
# Li10Ge(PSe6)2
# Li10Si(PO6)2
# Li10Si(PS6)2
# Li10Si(PSe6)2
# Li10Sn(PO6)2
# Li10Sn(PS6)2
# Li10Sn(PSe6)2
# Li10Zn(PS4)4
# Li10Zn7(PS4)8
# Li2(CoO2)3
# Li24Mn11CrO36
# Li24MnCr11O36
# Li24Ti11CrO36
# P1 -> C2 (549.19K, 13.31 J/kgK)
# Li24TiCr11O36
# P1 -> C2 (440.63K, 61.18 J/kgK)
# Li2AgF3
# C2/c -> Cmcm (422.04K, 168.57 J/kgK)
# C2/c -> Pnma (521.76K, 279.35 J/kgK)
# Li2AgF4
# Li2AgF5
# Li2AlCoO4
# Pna2_1 -> C222_1 (439.73K, 101.00 J/kgK)
# Pnma -> C222_1 (346.28K, 114.36 J/kgK)
# Li2AlCr2SbO8
# Li2AlFeO4
# Pmn2_1 -> C222_1 (539.20K, 111.69 J/kgK)
# Pnma -> C222_1 (400.83K, 117.09 J/kgK)
# Li2AlNiO4
# Li2AlVO4
# Pna2_1 -> Pmn2_1 (416.75K, 24.69 J/kgK)
# Li2BeSiO4
# Pc -> C222_1 (458.16K, 157.10 J/kgK)
# Li2Bi2B2O7
# Li2BiBO4
# Li2BiPCO7
# Li2CO3
# Li2CaTa2O7
# Li2CeO3
# Li2Co(CO3)2
# Li2Co(PO3)4
# Li2Co(SO4)2
# Li2Co(Si2O5)2
# P2_1/c -> P2_12_12_1 (491.45K, 31.01 J/kgK)
# Li2Co(SiO3)2
# Li2Co2(SO4)3
# Li2Co2OF6
# P-1 -> P1 (528.97K, 59.21 J/kgK)
# Li2Co2P2O9
# Li2Co2Si2O7
# Li2Co3(P2O7)2
# Li2Co4OF8
# Li2CoBO4
# Li2CoCSO7
# Li2CoGeO4
# Li2CoH8(CO5)2
# Li2CoO2
# Li2CoO3
# P4_2/mnm -> Pnnm (478.00K, 55.39 J/kgK)
# Li2CoOF3
# Li2CoP2O7
# Warning: 2 transitions within this interval
# P-1 -> Pna2_1 (304.41K, 68.49 J/kgK)
# Li2CoPO4F
# Li2CoSiO4
# P2_1/c -> C2 (355.09K, 180.90 J/kgK)
# Warning: 2 transitions within this interval
# Pnma -> C2 (465.89K, 114.32 J/kgK)
# Li2CoSn(PO4)2
# P1 -> P1 (341.24K, 17.64 J/kgK)
# P1 -> P-1 (307.52K, 22.28 J/kgK)
# P1 -> P-1 (580.96K, 67.69 J/kgK)
# P-1 -> P1 (490.66K, 16.96 J/kgK)
# Li2CoSnO4
# C222 -> C2/c (455.60K, 177.16 J/kgK)
# Li2Cr(CO3)2
# Li2Cr(PO3)4
# Li2Cr(PO3)5
# Li2Cr(Si2O5)2
# Li2Cr(Si2O5)3
# Li2Cr(SiO3)2
# Li2Cr2(SO4)3
# Pbcn -> C2/c (318.28K, 142.61 J/kgK)
# Li2Cr2FeSbO8
# Li2Cr2O7
# Li2Cr3(P2O7)2
# Li2Cr3CoO8
# Li2Cr3NiO8
# Li2Cr3SbO8
# P4_332 -> C2 (535.51K, 37.19 J/kgK)
# Li2Cr3SnO8
# Li2Cr3WO8
# P1 -> P-1 (545.96K, 116.99 J/kgK)
# Li2Cr4O13
# Li2CrCoO4
# Li2CrF6
# Li2CrFe(PO4)2
# Li2CrFeO4
# Li2CrO2
# Immm -> C2/m (586.08K, 103.56 J/kgK)
# Li2CrO3
# P-1 -> P1 (450.50K, 18.97 J/kgK)
# Li2CrO4
# Li2CrP2O7
# Li2CrP3O10
# Li2CrPCO7
# Li2CrPO4F
# Li2CrSi4O11
# Li2CrSiO4
# Pca2_1 -> P2_1/c (549.50K, 17.64 J/kgK)
# Pna2_1 -> P2_1/c (324.49K, 133.27 J/kgK)
# Li2Cu(PO3)4
# Li2Cu(Si2O5)2
# Li2Cu4S3
# Li2CuAsO4
# Li2CuPO4
# Warning: 2 transitions within this interval
# Pc -> P2_1/c (329.10K, 50.79 J/kgK)
# Li2Fe(CO3)2
# Li2Fe(CoO3)2
# Li2Fe(PO3)4
# Li2Fe(PO3)5
# Li2Fe(SO4)2
# Li2Fe(Si2O5)2
# Li2Fe(SiO3)2
# Li2Fe(WO4)2
# Li2Fe2(CO3)3
# Li2Fe2(MoO4)3
# Li2Fe2(SO4)3
# Pbcn -> C2/c (452.12K, 121.12 J/kgK)
# Pbcn -> Pbca (591.14K, 104.36 J/kgK)
# Li2Fe2(SiO3)3
# Li2Fe2Si2O7
# P-1 -> P1 (406.00K, 28.48 J/kgK)
# Li2Fe2Si3O10
# Li2Fe2Si8O19
# Li2Fe2SiO6
# Li2Fe3(P2O7)2
# Li2Fe3F8
# Pnnm -> I4_1/a (589.49K, 72.10 J/kgK)
# R-3m -> P2_1/c (324.89K, 152.13 J/kgK)
# Li2Fe3SbO8
# Li2Fe3TeO8
# Li2Fe3WO8
# Li2Fe4OF8
# Li2Fe5Si5O16
# Li2FeBO4
# Li2FeCoO4
# Li2FeF4
# C2/c -> Pna2_1 (546.74K, 325.15 J/kgK)
# C2/c -> Pnn2 (407.50K, 176.31 J/kgK)
# C2/c -> R-3 (383.67K, 217.85 J/kgK)
# P2_1/c -> Cmcm (509.54K, 93.31 J/kgK)
# I-4 -> Cmmm (579.27K, 409.68 J/kgK)
# Warning: 2 transitions within this interval
# Cmmm -> P1 (366.97K, 100.63 J/kgK)
# P2_1 -> Pnn2 (590.05K, 255.39 J/kgK)
# P2_1 -> R-3 (534.77K, 303.74 J/kgK)
# P4_122 -> Pnn2 (553.58K, 166.87 J/kgK)
# P4_122 -> R-3 (493.95K, 253.78 J/kgK)
# P4_2/mbc -> Pnma (464.06K, 154.35 J/kgK)
# Pbam -> R-3 (583.90K, 175.12 J/kgK)
# Pmc2_1 -> Pnma (414.28K, 136.10 J/kgK)
# Li2FeF5
# C2/c -> P1 (399.61K, 304.35 J/kgK)
# Li2FeO2
# P-1 -> P-1 (448.96K, 236.25 J/kgK)
# Pc -> P-1 (554.60K, 291.04 J/kgK)
# Li2FeO2F
# C2 -> Cc (491.53K, 164.53 J/kgK)
# Li2FeOF3
# Li2FeP2HO8
# Li2FeP2O7
# P2_1/c -> C2/m (387.92K, 162.75 J/kgK)
# P2 -> Cmm2 (314.96K, 28.14 J/kgK)
# Li2FePCO7
# P1 -> P2_1/c (526.66K, 91.10 J/kgK)
# P2_1/m -> P1 (551.24K, 131.52 J/kgK)
# P2_1/m -> P2_1/c (540.86K, 220.44 J/kgK)
# Li2FePHO5
# Li2FePO4F
# Li2FePO5
# ...
# Sn4SF6
# Cmc2_1 -> R3 (403.17K, 13.81 J/kgK)
# Sn5(S2Cl)2
# SnBr2
# SnCl2
# SnClF
# SnF2
# SnF3
# SnF4
# SnGeO3
# SnH6CI3N
# SnI2
# SnI4
# SnNF3
# SnO
# SnO2
# SnP2Cl8O3
# SnP2O7
# SnP4O11
# SnPCl9
# SnPS3
# SnPSe3
# SnPbO3
# SnPbS2
# SnS
# SnS2
# SnSO4
# SnSe
# SnWO4
# Sr(AlCl4)2
# I4_1/acd -> P2/c (368.28K, 52.32 J/kgK)
# Sr(AlS2)2
# Sr(AsO3)2
# Sr(BO2)2
# Sr(BS2)2
# P2_1/c -> R-3 (543.32K, 60.68 J/kgK)
# Sr(BrO3)2
# Sr(C4N3)2
# P31m -> Pmna (460.73K, 133.81 J/kgK)
# Sr(ClO)2
# Sr(ErS2)2
# Sr(GaS2)2
# Sr(H2N)2
# Sr(H2O3)2
# Sr(H8O5)2
# Sr(HO)2
# Sr(IO)2
# Sr(IO3)2
# Sr(InTe2)2
# Sr(PO3)2
# Sr(SO5)2
# Sr(SbO3)2
# Sr(YS2)2
# Sr10P6BrO24F
# Sr10P6ClO24F
# Sr20P12Br(O16F)3
# Sr2AlGaCo2O7
# Sr2As2O7
# Sr2Bi2O5
# Sr2Bi2Se3O2
# P2_1/c -> C2/m (350.00K, 10.84 J/kgK)
# Sr2BiSbO6
# Sr2CaI6
# P2_1/c -> P4_2/mnm (454.73K, 23.44 J/kgK)
# P321 -> Pbcn (437.91K, 10.48 J/kgK)
# Sr2CaMoO6
# Sr2CaTi3O9
# Sr2CaV2(Si2O7)2
# Sr2CaWO6
# Sr2CdWO6
# Sr2CeHfO6
# Sr2CeSnO6
# Sr2CeZrO6
# Sr2Co(ClO)2
# Sr2CoGe2O7
# Sr2CoO3
# Sr2CoSbO6
# Sr2CoWO6
# Sr2CrSbO6
# Sr2DyBiO6
# Sr2DySbO6
# Sr2Fe2O5
# Sr2FeO3F
# Sr2FeSbO6
# Sr2FeWO6
# P-1 -> P-1 (302.15K, 25.06 J/kgK)
# P-1 -> P-1 (370.01K, 24.32 J/kgK)
# Sr2GaSbO6
# Sr2GdBiO6
# Sr2GdNbO6
# Sr2GdSbO6
# Sr2GeO4
# Sr2HfMgCrO6
# Sr2HfO4
# Sr2HfTiO6
# Sr2InSbO6
# Sr2La2MgTi3O12
# Sr2La2MnZnO8
# Sr2LaBiO6
# Sr2LaCl7
# Sr2LaI7
# Sr2LaMn2O7
# Cmcm -> C2/m (414.52K, 5.47 J/kgK)
# Sr2LaNbO6
# Sr2LaSbO6
# Sr2LiCdWO6
# Sr2LiCoWO6
# Sr2LiFeO3F
# Sr2LiV2(Si2O7)2
# Sr2LiZrCrO6
# Immm -> Cm (371.82K, 42.70 J/kgK)
# Sr2LuNbO6
# Sr2LuTaO6
# Sr2Mg(H4O3)2
# Sr2MgCdWO6
# Sr2MgCrO4
# Sr2MgCuMoO6
# Sr2MgCuWO6
# Sr2MgMoO6
# Sr2MgSi2O7
# Sr2MgTiFeO6
# Sr2MgV2(Si2O7)2
# Sr2MgWO6
# Sr2MgZn2Sn2(PO4)4
# Sr2MgZnMoO6
# Sr2MgZnWO6
# Sr2MgZrCrO6
# P1 -> P1 (339.08K, 5.08 J/kgK)
# Sr2MgZrMnO6
# Sr2MnGaO5
# Sr2MnMoO6
# P-1 -> P4_2/n (377.98K, 16.23 J/kgK)
# Sr2MnNbO6
# Sr2MnWO6
# Sr2Nb2O7
# Sr2NbBiO6
# Sr2NbCoO6
# C2 -> P1 (376.50K, 35.23 J/kgK)
# Pmn2_1 -> P1 (346.15K, 32.69 J/kgK)
# Sr2NbFeO6
# Sr2NbGaO6
# Sr2NbInO6
# Sr2NbSbO6
# Sr2NdBiO6
# Sr2NdNbO6
# Sr2NdSbO6
# Sr2NiMoO6
# Sr2NiTeO6
# Sr2PrBiO6
# Sr2PrNbO6
# Sr2PrSbO6
# Sr2SiO4
# Sr2SmBiO6
# Sr2SmNbO6
# Sr2SmSbO6
# Sr2SnO4
# Pccn -> Cmce (304.20K, 1.45 J/kgK)
# Sr2Ta2O7
# Sr2TaAlO6
# Sr2TaCoO6
# Sr2TaCrO6
# Sr2TaFeO6
# Sr2TaInO6
# Sr2TaMnO6
# Sr2TbBiO6
# Sr2TbNbO6
# Sr2TbSbO6
# Sr2TiMnO6
# Sr2V2O7
# Sr2V3O9
# P2_1/c -> P1 (435.82K, 2.49 J/kgK)
# Sr2VMoO6
# Sr2YBiO6
# Sr2YI7
# Sr2YMgCrO6
# Sr2YNbO6
# Sr2YSbO6
# Sr2YTaO6
# Sr2ZnMoO6
# Sr2ZnWO6
# P-1 -> I4/m (350.03K, 10.98 J/kgK)
# P-1 -> P2_1/c (309.41K, 30.63 J/kgK)
# Sr2ZrTiO6
# Sr2ZrVO6
# Sr3(AsO4)2
# Sr3(BN2)2
# Sr3(CoO3)2
# Sr3(InN2)2
# Sr3As4
# Sr3CaI8
# Sr3GeO5
# Sr3Hf2O7
# Sr3InNiO6
# Sr3La4O9
# Sr3LaMn2(WO6)2
# Sr3Li4Nb6O20
# Sr3Mg(FeO3)2
# Sr3MgO4
# Sr3MoN4
# Sr3NbCoO7
# Sr3NbGa3(SiO7)2
# Sr3Nd4O9
# Sr3P4
# Sr3SiO5
# Sr3TaCoO7
# Sr3Te4O11
# P1 -> P1 (408.44K, 6.10 J/kgK)
# Sr3TeO6
# Sr3UO6
# Sr3W2O9
# Pnma -> P2_1/m (392.90K, 28.88 J/kgK)
# Sr3WO6
# Sr3Y2(BO3)4
# Sr4Al6CrO16
# Sr4Al6MoO16
# Sr4Al6WO16
# Sr4Bi2O
# Sr4Br6O
# Sr4BrN2Cl
# R-3m -> P2/m (441.10K, 16.48 J/kgK)
# Sr4CaMn2Ga2O11
# Sr4GeN4
# Sr4LaCl11
# Sr4Mg(Fe2O5)2
# Sr4MgFe4O11
# Sr4Nb2O9
# Sr4Ta2O9
# Sr4ZrTi3O12
# Sr5Cr3ClO12
# Sr5Nb4O15
# Sr5Ta4O15
# Sr5W3O14
# Sr5ZrTi4O15
# Sr6Bi2O11
# Sr6Mg(W2O9)2
# Sr8MgMn6O20
# SrAl12O19
# SrAl2(SiO4)2
# SrAl2B2O7
# SrAl2O4
# SrAl4O7
# SrAlF5
# P2_1/c -> I4 (548.62K, 81.52 J/kgK)
# SrAlSi5N7O2
# SrB4O7
# SrBPO5
# SrBr2
# SrBrCl
# SrC2
# C2/c -> I4/mmm (322.43K, 123.35 J/kgK)
# SrCN2
# R-3m -> Pnma (323.37K, 109.95 J/kgK)
# SrCO3
# R-3c -> C2/m (341.92K, 189.14 J/kgK)
# SrCa2I6
# P2_1/c -> P2_12_12_1 (596.22K, 33.86 J/kgK)
# Pbcn -> P4_2/mnm (520.62K, 15.49 J/kgK)
# SrCa3Zr16(PO4)24
# SrCaBiSbO6
# SrCaDyBiO6
# SrCaGdBiO6
# SrCaGdNbO6
# SrCaI4
# SrCaLaBiO6
# SrCaLaSbO6
# SrCaMg14O16
# SrCaNdSbO6
# SrCaPrSbO6
# SrCaSmBiO6
# SrCaSmNbO6
# SrCaSmSbO6
# SrCaTbBiO6
# SrCaTi2O6
# SrCaTiMnO6
# SrCaYBiO6
# P222 -> P-4n2 (539.44K, 38.66 J/kgK)
# SrCdB2O5
# SrCeN2
# SrCo(GeO3)2
# SrCo2(AsO4)2
# P1 -> P1 (449.77K, 14.12 J/kgK)
# SrCrF4
# SrCrP2O7
# SrCu2GeS4
# SrEr2O4
# SrF2
# SrFe12O19
# SrGa2(SiO4)2
# SrGaBO4
# P2_12_12 -> Pccn (396.10K, 29.94 J/kgK)
# SrGe(PO4)2
# SrGeO3
# SrH2
# SrH2(CO2)2
# SrH4O3
# SrHfO3
# SrI2
# Pbca -> P4_2/mnm (576.96K, 87.59 J/kgK)
# SrLa11Mg3Ga9O34
# SrLa2Cl8
# SrLa2O4
# SrLa3Mn4O10
# SrLa4TiAl4O15
# SrLa7TiGa7O24
# SrLaCl5
# SrLaCoO4
# SrLaDySnO6
# SrLaFeO4
# SrLaI5
# Cc -> C2/c (358.88K, 4.65 J/kgK)
# SrLaTaNiO6
# SrLaTiFeO6
# SrLaTiMnO6
# SrLaVFeO6
# SrLi2Nb2O7
# SrLi2Ta2O7
# SrLi4NiO4
# SrLiAlF6
# P2_1/c -> P-31c (369.87K, 54.82 J/kgK)
# SrLiAlO3
# SrLiLa3MnO8
# SrLiNb2O6F
# SrLiNdCoO4
# SrLiP
# SrLiPrTeO6
# SrLiSb
# SrLiTi4CrO11
# SrLu2O4
# Cmcm -> Fd-3m (551.83K, 25.02 J/kgK)
# SrMg14CO16
# SrMg14CdO16
# SrMg14CoO16
# SrMg14FeO16
# SrMg14MnO16
# SrMg14NiO16
# SrMg14VO16
# SrMg14ZnO16
# SrMg3O4
# SrMgF4
# SrMgFe2(SeO3)4
# SrMgO2
# SrMnO3
# SrMoO4
# SrN6
# SrNd2O4
# SrNdCoO4
# SrO
# SrO2
# SrS
# SrSO4
# SrSeO3
# SrSiO3
# SrSm2O4
# SrSmCoO4
# SrSn(PO4)2
# SrSnN2
# SrSnO3
# SrTa2Bi2O9
# SrTaNO2
# C2 -> P2_1 (337.04K, 11.68 J/kgK)
# Warning: 2 transitions within this interval
# C2 -> Pm (347.61K, 1.95 J/kgK)
# Pm -> P2_1 (334.72K, 9.44 J/kgK)
# Pmc2_1 -> Pc (398.01K, 15.06 J/kgK)
# SrTeO3
# SrTi(PO4)2
# SrTiO3
# SrUO4
# SrV2(AsO5)2
# SrV2(PO5)2
# SrV3O7
# SrV4O10
# SrVSi2O7
# SrWN3
# SrZnF2
# SrZr2SnO6
# SrZrO3
# Ta2Co4O9
# Ta2CrNO5
# Cm -> Pc (364.15K, 17.63 J/kgK)
# Ta2CrO6
# Ta2FeO6
# Ta2H4O7
# Ta2Mn4O9
# Ta2MnO6
# Ta2O5
# Ta2Pb2O7
# Ta2PbO6
# Ta2WO8
# Ta2Zn2CrO8
# Ta2Zn4O9
# Pbcn -> P-3c1 (382.34K, 4.90 J/kgK)
# Ta2ZnO6
# Ta3AgO8
# Ta3Bi7O18
# P1 -> C2/m (307.28K, 15.53 J/kgK)
# Ta3InO9
# Ta6Pb4O19
# Ta7BiO19
# P-6c2 -> P6_322 (330.40K, 54.68 J/kgK)
# TaAgO3
# TaAl(WO4)2
# TaAlO4
# TaAsO4
# TaAsO5
# TaBi3O7
# TaBi4ClO8
# TaBiO4
# TaBr5
# TaCr3(AgS4)2
# TaCrO4
# TaF5
# P1 -> P2_1/c (427.76K, 8.03 J/kgK)
# TaFeO4
# Cmmm -> I4_1md (335.13K, 17.13 J/kgK)
# TaGaO4
# TaIn3O7
# TaMnO4
# TaNO
# TaNb(AgO3)2
# TaNbO5
# P2_1/c -> Pnma (585.13K, 7.71 J/kgK)
# TaO2F
# TaOF3
# TaP4(SCl)5
# P-1 -> P2_1/c (490.36K, 22.00 J/kgK)
# TaPO5
# TaSb3O8
# TaTeCl9
# TaVO4
# TaVO5
# TaZn2WO6
# TaZnBiO5
# Tb(BO2)3
# Tb(HO)3
# Tb2(MoO4)3
# Tb2(WO4)3
# Tb2Mg(NiO3)2
# Tb2MgS4
# Pca2_1 -> Cmc2_1 (463.61K, 24.32 J/kgK)
# Tb2MgSe4
# Tb2O3
# Tb2Pb2O7
# Tb2S3
# Tb2SeO2
# I4/mmm -> Pnnm (459.46K, 7.72 J/kgK)
# Tb2Te4O11
# Tb2Ti2O7
# Fd-3m -> P4_12_12 (322.73K, 39.34 J/kgK)
# Tb2TiO5
# Tb2WO6
# P2_12_12_1 -> Pbca (433.69K, 24.59 J/kgK)
# Tb2Zr2O7
# Tb3Fe5O12
# Tb3NbO7
# Tb3SbO7
# Tb3TaO7
# Tb5Mg(MoO6)2
# TbAl3(BO3)4
# R32 -> C2/c (367.67K, 89.58 J/kgK)
# TbCl3
# Cmcm -> P4_2/mnm (521.41K, 117.11 J/kgK)
# Cmcm -> P6_3/m (504.68K, 67.22 J/kgK)
# P6_3/m -> P4_2/mnm (550.06K, 39.54 J/kgK)
# TbCuSe2
# P3m1 -> P2_1/c (474.13K, 3.87 J/kgK)
# TbCuTe2
# P3m1 -> P-3m1 (339.10K, 25.26 J/kgK)
# TbErO3
# TbFe3(BO3)4
# TbGaO3
# TbHO2
# TbNbO4
# TbOF
# TbPO4
# TbPaO4
# TbSbO4
# TbTa3O9
# TbTaO4
# Te(HO)6
# Te(HO2)2
# Te(S2O7)2
# Te(WO4)2
# Te2Mo
# Te2Pb3(ClO3)2
# Te2W
# Te3WO12
# Te4As2S(OF6)2
# Pnma -> P2_1/c (588.81K, 56.57 J/kgK)
# Te4Mo(OF4)5
# Te4MoW
# Te6Mo2W
# Te6MoW2
# P-6m2 -> P3m1 (478.01K, 5.23 J/kgK)
# Te7(OF5)6
# P-1 -> R-3 (589.43K, 99.30 J/kgK)
# TeAs(SeF3)2
# TeF6
# TeHO3
# TeI
# TeI4
# P2_1/c -> Pmn2_1 (389.39K, 4.71 J/kgK)
# TeO2
# P2_12_12_1 -> Pbca (493.76K, 17.57 J/kgK)
# P4_12_12 -> Pbca (462.21K, 19.88 J/kgK)
# TeO3
# TePb
# TePb2O5
# TePbO3
# TeSeO4
# TeWO6
# Ti(FeO2)2
# Ti(FeO2)3
# Ti(GeO3)2
# Ti(PO3)4
# Ti(PS3)2
# Ti(SO4)2
# Ti(SiO3)2
# Ti(WO4)2
# Ti2Bi2O7
# Ti2CdO6
# Ti2CoO5
# Ti2Fe4O9
# Ti2FeO5
# P2_1/m -> P2_1 (455.86K, 26.47 J/kgK)
# Ti2ZnO5
# Ti3(BiO3)4
# Ti3Fe(BiO3)5
# Ti3Fe5O12
# Ti3Fe9O16
# Ti3H2O7
# Ti3N2O3
# Ti3V5O16
# Ti3Zn2O8
# Ti4Bi2O11
# Ti4Fe(PO4)6
# Ti4Zn3SnO12
# TiAl2O5
# TiAs2O7
# TiBi2O5
# TiBr4
# P2_1/c -> Pa-3 (430.57K, 5.17 J/kgK)
# TiCdO3
# TiCo3O8
# Cm -> R-3m (408.35K, 104.24 J/kgK)
# TiF4
# TiFe11O16
# TiFe2O5
# TiFeO3
# TiGa2O5
# TiMn(PO4)2
# TiMn2O6
# TiMn3O8
# TiMnO3
# TiNF
# TiNb(BiO3)3
# TiNb2O7
# TiNi(PO4)2
# TiO2
# P1 -> I4/m (370.71K, 14.52 J/kgK)
# Cmcm -> P3_121 (504.97K, 24.42 J/kgK)
# Cmcm -> Pmmn (441.46K, 119.78 J/kgK)
# Pmm2 -> Cmm2 (458.93K, 73.75 J/kgK)
# P3_121 -> Pmmn (426.44K, 95.08 J/kgK)
# P6_3mc -> Pbca (335.67K, 100.00 J/kgK)
# TiOF2
# TiP2O7
# TiPHO5
# TiPN3
# TiPO4F
# TiPbO3
# P4mm -> I4/m (532.79K, 126.09 J/kgK)
# TiS2
# TiSCl6O
# P-1 -> P2_1/c (394.95K, 44.65 J/kgK)
# TiSO5
# Pmc2_1 -> Pnma (485.67K, 25.76 J/kgK)
# TiSiO4
# TiSnO3
# TiSnO4
# TiV3O8
# P1 -> P1 (572.25K, 15.15 J/kgK)
# TiVO4
# P1 -> I4_1md (405.96K, 9.97 J/kgK)
# P1 -> P1 (348.72K, 24.36 J/kgK)
# P1 -> Cmmm (583.38K, 89.01 J/kgK)
# Pmn2_1 -> Cmmm (593.35K, 92.63 J/kgK)
# P1 -> I4_1md (364.64K, 33.69 J/kgK)
# Pmn2_1 -> I4_1md (334.43K, 19.77 J/kgK)
# P1 -> Pmn2_1 (418.67K, 10.78 J/kgK)
# TiZn(BiO3)2
# Amm2 -> P4mm (484.64K, 55.20 J/kgK)
# TiZn(GeO3)2
# TiZn2O4
# TiZnO3
# P-1 -> Pnma (562.73K, 88.51 J/kgK)
# TiZnSnO4
# U(HO2)2
# U(MoO6)2
# U(OF)2
# U3(HO5)2
# UAg2(WO5)2
# UBi4(AsO8)2
# UCO5
# UCdO4
# UO3
# UOF4
# US2O9
# Pca2_1 -> P-1 (487.00K, 18.10 J/kgK)
# USO6
# UTeO5
# V(CO3)2
# P-1 -> P-1 (352.27K, 155.42 J/kgK)
# I-42d -> P-1 (395.75K, 260.46 J/kgK)
# V(GeO3)2
# V(PO3)3
# V(PO3)4
# C2/m -> C2/c (353.85K, 58.09 J/kgK)
# V(SO4)2
# V(SiO3)2
# V(WO4)2
# V2(OF)3
# V2(SO4)3
# V2Bi4O11
# C2 -> P1 (426.82K, 43.02 J/kgK)
# V2Bi8O17
# V2CdO6
# V2CoO6
# V2CrO6
# V2FeO4
# C2/c -> P1 (527.23K, 230.59 J/kgK)
# V2FeO6
# P-1 -> C2/c (334.25K, 42.90 J/kgK)
# V2MoO8
# V2NiO6
# V2O3
# V2O3F
# V2O5
# Fdd2 -> Pbam (527.45K, 43.90 J/kgK)
# V2OF5
# P3_2 -> P3_1 (444.94K, 55.81 J/kgK)
# V2OF7
# V2P2O7
# V2P2O9
# V2Pb3O8
# V2PbO6
# V2Si2O7
# Warning: 2 transitions within this interval
# P-1 -> C2/c (442.12K, 37.15 J/kgK)
# V2SiO4
# V2Te2O9
# V2Zn2O7
# V2ZnO4
# V2ZnO5
# V2ZnO6
# V3(H3O5)2
# V3(HO2)4
# V3(O2F)2
# C2/m -> P2_1 (362.73K, 129.87 J/kgK)
# P-1 -> P2_1 (404.53K, 142.44 J/kgK)
# P4_2nm -> P2_1 (325.01K, 87.63 J/kgK)
# V3(OF3)2
# V3(PO4)2
# V3(PO4)4
# V3As2O9
# V3CoO8
# V3CrO8
# V3O2F5
# V3O5
# V3O5F
# V3O7
# V3O8
# V3OF11
# V3OF7
# V3Pb2O9
# V3Zn2O8
# V4(OF3)3
# V4O5F7
# V4OF11
# V4ZnO10
# V5O12
# V5O9
# V5W3O20
# V6H2Pb4Se3O26
# V6O7F5
# V7O13
# V9O22
# VAg3O4
# VAgO3
# VAs2H4O9
# VAsO5
# VBO4
# VBi(PbO3)2
# P2_1/c -> Pc (334.44K, 9.11 J/kgK)
# VBiO4
# I4_1/a -> I4_1/amd (327.01K, 33.92 J/kgK)
# VBiPbO5
# VCd2N3
# VCl2O
# C2/c -> Imm2 (435.17K, 122.44 J/kgK)
# VCrO3
# VCrO4
# Cmcm -> C2/m (490.40K, 118.07 J/kgK)
# VCuO3
# VF3
# P2_1/c -> C2/c (436.10K, 67.42 J/kgK)
# VF4
# Pc -> C2/c (486.52K, 233.75 J/kgK)
# C2/m -> Pbam (336.60K, 244.84 J/kgK)
# C2/m -> Pna2_1 (429.76K, 186.55 J/kgK)
# C2/m -> R-3 (341.81K, 208.04 J/kgK)
# Pc -> Pbam (431.54K, 125.21 J/kgK)
# R-3 -> Pbam (306.21K, 33.95 J/kgK)
# Pc -> R-3 (508.50K, 52.96 J/kgK)
# VF5
# Cmce -> P2_1 (317.21K, 48.93 J/kgK)
# Cmce -> P4/n (565.48K, 215.53 J/kgK)
# VFeO4
# VH10SO10
# VHO3
# VInO4
# VMoO5
# VO
# VO2
# Pnma -> C2/m (416.93K, 53.73 J/kgK)
# P1 -> P2_1/m (472.73K, 163.32 J/kgK)
# P1 -> Pmmn (321.34K, 155.65 J/kgK)
# Pmn2_1 -> Pc (559.07K, 57.09 J/kgK)
# VO2F
# P-1 -> Cm (369.65K, 109.03 J/kgK)
# P1 -> P2_1/c (411.12K, 40.30 J/kgK)
# Warning: 2 transitions within this interval
# P2_12_12_1 -> P1 (384.97K, 63.12 J/kgK)
# P2_12_12_1 -> P2_1/c (395.18K, 96.10 J/kgK)
# VOF
# P-1 -> P2_1/m (319.94K, 174.79 J/kgK)
# P2/m -> P2_1/c (560.66K, 108.29 J/kgK)
# P2/m -> P2_1/m (554.52K, 244.45 J/kgK)
# P2/m -> R-3 (357.57K, 220.36 J/kgK)
# P2_1 -> R-3 (390.05K, 238.03 J/kgK)
# P2_1/c -> P2_1/m (549.99K, 144.45 J/kgK)
# P2_1/c -> R-3 (319.43K, 208.20 J/kgK)
# P2_12_12_1 -> R-3 (463.00K, 234.99 J/kgK)
# Pm -> P2_1/m (483.52K, 233.98 J/kgK)
# Pnma -> R-3 (500.40K, 282.20 J/kgK)
# VOF2
# P2_1 -> P1 (403.87K, 86.37 J/kgK)
# VOF3
# Pna2_1 -> C2 (423.89K, 168.74 J/kgK)
# P4_1 -> P-1 (453.82K, 72.15 J/kgK)
# P2_12_12_1 -> P-42_1m (354.31K, 174.07 J/kgK)
# P1 -> P2_1 (312.88K, 126.84 J/kgK)
# Warning: 2 transitions within this interval
# Pca2_1 -> P2_1 (341.34K, 66.26 J/kgK)
# P2_12_12_1 -> Pc (310.58K, 241.67 J/kgK)
# VP2O7
# VPO4
# VPO4F
# VPO5
# P4/nmm -> C2/m (479.09K, 9.99 J/kgK)
# VPPbO6
# VPb2N3
# VSO5
# VWO4
# VZn(SiO3)2
# VZn2WO6
# VZnBiO5
# VZnP2O7
# VZnPO5
# W(BrO)2
# W(ClO)2
# Pmm2 -> Pmc2_1 (447.47K, 11.99 J/kgK)
# W(OF)2
# W2O5
# W3(Se2S)2
# P-6m2 -> P3m1 (568.05K, 4.45 J/kgK)
# W3(SeS2)2
# W3O8
# W5(O2F11)2
# P-1 -> I4_1/a (327.19K, 12.94 J/kgK)
# W7(OF5)6
# WBr4O
# WCl6
# P-3m1 -> R-3 (322.79K, 8.87 J/kgK)
# WF5
# WN2
# P3_121 -> Pna2_1 (309.34K, 14.96 J/kgK)
# WO2
# WO3
# Im-3 -> Pbcm (461.45K, 26.12 J/kgK)
# P4/ncc -> P2_1/c (556.23K, 23.80 J/kgK)
# P4/ncc -> P2_1/m (399.36K, 33.41 J/kgK)
# P4/nmm -> P2_1/m (471.80K, 20.12 J/kgK)
# P4/ncc -> P4/nmm (306.31K, 12.56 J/kgK)
# Pm-3m -> Pbcm (324.83K, 37.79 J/kgK)
# Pnma -> Pbcm (317.08K, 18.23 J/kgK)
# Pm-3m -> Pmma (495.25K, 24.50 J/kgK)
# Pm-3m -> Pnma (332.22K, 19.55 J/kgK)
# WOF4
# C2/c -> I-4 (523.38K, 90.81 J/kgK)
# Pca2_1 -> C2/m (326.55K, 29.29 J/kgK)
# P-1 -> I-4 (348.39K, 98.81 J/kgK)
# Pca2_1 -> I-4 (581.76K, 140.38 J/kgK)
# WS2
# P6_3/mmc -> P-3m1 (373.26K, 47.09 J/kgK)
# P6_3/mmc -> P3m1 (532.80K, 49.56 J/kgK)
# R3m -> P3m1 (416.05K, 21.69 J/kgK)
# P6_3/mmc -> R3m (556.65K, 56.39 J/kgK)
# WSCl4
# WSe2
# P6_3/mmc -> P-3m1 (387.41K, 46.14 J/kgK)
# P6_3/mmc -> P-6m2 (312.52K, 34.15 J/kgK)
# WSeS
# Xe
# Cmce -> P6_3/mmc (379.64K, 44.32 J/kgK)
# R-3m -> Im-3m (319.92K, 23.32 J/kgK)
# XeF6
# Pna2_1 -> C2/c (556.20K, 42.79 J/kgK)
# Y(BO2)3
# Y(FeO2)2
# Y(HO)3
# Y(PO3)3
# Y2(MoO4)3
# Y2(SO4)3
# Y2(SeO4)3
# Y2AlN3
# Y2BeAlBO7
# Y2C(NO)2
# Y2Cr3O12
# Y2GaN3
# Y2Ge2O7
# Y2GeO5
# Pnma -> P2_1/c (365.95K, 36.67 J/kgK)
# Y2Hf2O7
# Y2HfO5
# Y2Hg2O5
# Y2HgO4
# Y2MgBi2O7
# Y2MgMo2(ClO4)2
# Y2MgS4
# Y2MgSe4
# Y2MgV2O7
# Y2O3
# P1 -> P-4m2 (570.28K, 76.08 J/kgK)
# Y2S3
# P2_1/m -> Pnma (453.66K, 21.16 J/kgK)
# Y2Se3
# Y2SeO2
# Y2Si2O7
# C2/m -> P2_1/c (493.96K, 28.90 J/kgK)
# Y2SiO5
# Y2TeO6
# Y2Ti2O7
# Y2W2O9
# Y2WO6
# Y2ZnS4
# Y2Zr2O7
# Fd-3m -> C2/m (515.59K, 86.92 J/kgK)
# P2_1 -> C2/m (592.01K, 65.43 J/kgK)
# Fd-3m -> P2_1 (323.56K, 18.78 J/kgK)
# Y3AlO6
# Y3NbO7
# Y3TaO7
# Cmcm -> C222_1 (382.68K, 37.25 J/kgK)
# Y4Ga2O9
# Y4Mg(BiO3)4
# Y4S3N2
# Y4Zr3O12
# P-1 -> P1 (538.36K, 14.21 J/kgK)
# Y5Mg(MoO6)2
# Y5O4F7
# Y6O5F8
# Y7(O2F3)3
# YAg(WO4)2
# YAgS2
# YAgSe2
# YAgTe2
# YAlN2
# I-42d -> Pbca (509.12K, 39.26 J/kgK)
# YAlO3
# YB3(H6N)4
# YBO3
# YBi(WO4)2
# YBiO3
# YBr3
# YBrO
# YClO
# YCrO3
# YCu(WO4)2
# YCuO2
# YCuPbS3
# YCuS2
# YF3
# YFe(WO4)2
# YFe3(BO3)4
# YFeO3
# YGaN2
# YHO2
# P2_1/m -> Pnma (532.34K, 200.92 J/kgK)
# YIO
# YLuO3
# P6_3/mmc -> Pnma (572.41K, 23.10 J/kgK)
# YMg14NiO16
# YMgAg(WO4)2
# YMgCu(WO4)2
# YMgMo3O8
# YMn(WO4)2
# YMo(WO4)2
# YMo3O8
# YN
# YNO4
# YNb2NO5
# YNbO4
# YOF
# YP5O14
# YPO4
# YPaO4
# I4_1/amd -> P4/mmm (382.15K, 33.83 J/kgK)
# YSF
# YSb(PbO3)2
# YSbO3
# YSeF
# YSeO3F
# YSiNO2
# YSnF7
# YTa(WO4)2
# YTa3O9
# YTaO4
# YTi(WO4)2
# YV(WO4)2
# YVO3
# YVO4
# YW3O8
# YWN3
# P2_1/m -> Ama2 (517.23K, 15.22 J/kgK)
# YZr3F15
# Zn(BH4)2
# Zn(BiO2)2
# Zn(C4N3)2
# Zn(CN)2
# Zn(FeO2)2
# Zn(GaS2)2
# Zn(HO)2
# P2_1 -> P2_12_12_1 (577.52K, 8.11 J/kgK)
# Zn(InS2)2
# Zn(InSe2)2
# Zn(MoO2)2
# Zn(NCl2)2
# Zn(NO3)2
# Zn(PO3)2
# Zn(PbN)2
# Zn(SbO2)2
# Zn(SbO3)2
# Zn(SnO2)2
# Zn(WO2)2
# Zn2As2O7
# Zn2BiWO6
# Zn2CoWO6
# Zn2CrWO6
# P1 -> P1 (354.13K, 3.94 J/kgK)
# Zn2FeWO6
# Zn2Ga2S5
# R-3m -> P6_3/mmc (314.96K, 80.46 J/kgK)
# Zn2MoWO6
# Zn2P2O7
# Zn2PHO5
# Zn2SbWO6
# Zn2SeCl2O3
# Pccn -> P2_1/c (365.52K, 32.09 J/kgK)
# Zn2SeS
# Zn2SiH2O5
# Zn2SiO4
# Zn2Sn3O8
# Zn2SnWO6
# Zn3(AsO3)2
# Zn3(BO3)2
# P-1 -> C2/c (416.26K, 91.34 J/kgK)
# Zn3(PO4)2
# Zn3B7IO13
# Zn3BPO7
# Zn3CdSe4
# Zn3In2O6
# Zn3TeP2Pb3O14
# Zn4CdSe5
# Zn5(SiN3)2
# Zn8B4H3O15F
# ZnAg2C4(SN)4
# ZnAgF3
# ZnAgPO4
# ZnAu2(CN)4
# ZnB4O7
# ZnBiF5
# P1 -> C2/c (542.85K, 6.95 J/kgK)
# ZnBiMoO5
# ZnBiSbO5
# ZnBiWO5
# ZnBr2
# R-3m -> C2/m (475.30K, 151.58 J/kgK)
# ZnCdS2
# ZnCdSe2
# R3m -> P-4m2 (575.28K, 44.36 J/kgK)
# ZnCdTe2
# ZnCl2
# I-42d -> Pna2_1 (359.62K, 89.09 J/kgK)
# P4_2/nmc -> P2_1/c (334.32K, 4.15 J/kgK)
# P2_1/c -> Pna2_1 (507.78K, 36.03 J/kgK)
# P4_2/nmc -> Pna2_1 (485.87K, 40.51 J/kgK)
# ZnCo(GeO3)2
# P2_1/c -> P-1 (353.33K, 49.07 J/kgK)
# ZnCo(SiO3)2
# ZnCoF5
# ZnCoO2
# R-3m -> C2/m (314.00K, 127.87 J/kgK)
# ZnCoP2O7
# ZnCr2O4
# Pbcm -> Pmmn (581.99K, 57.10 J/kgK)
# ZnCrBiO5
# ZnCrF5
# ZnCrO4
# ZnCrP2O7
# ZnCu2SiS4
# ZnCuF4
# ZnF2
# ZnFe(GeO3)2
# ZnFe(SiO3)2
# ZnFe4CoO8
# ZnFeF5
# ZnFeP2O7
# P2_1/c -> P-1 (478.86K, 66.31 J/kgK)
# ZnFePO5
# ZnGaP2H4NO8
# ZnGe2WO6
# ZnGeN2
# ZnGeO3
# ZnH2(CO2)2
# ZnH6
# ZnH7C3NO6
# ZnI2
# ZnMoF5
# P2_1/c -> C2/c (501.46K, 98.95 J/kgK)
# ZnMoO4
# P-1 -> P2/c (379.54K, 64.08 J/kgK)
# ZnN6
# ZnNi(GeO3)2
# P2_1/c -> C2/c (380.34K, 31.63 J/kgK)
# ZnNiO2
# ZnNiP2O7
# ZnNiP2WO9
# ZnO
# ZnO2
# ZnP2
# P4_32_12 -> P4_12_12 (588.57K, 39.91 J/kgK)
# ZnP2(H4O5)2
# ZnP4O11
# ZnPH5C2N4O3
# ZnS
# ZnSO4
# ZnSbF5
# ZnSe
# ZnSeO3
# ZnSeO4
# ZnSi2NiO6
# ZnSi2SnO6
# ZnSiO3
# ZnSn(GeO3)2
# ZnSn2(PO4)2
# ZnSnO2
# ZnSnO3
# ZnSnP2O7
# ZnTe
# F-43m -> P6_3mc (342.13K, 5.38 J/kgK)
# ZnTe(H2N)4
# ZnTe2O5
# ZnWO4
# Zr(MoO4)2
# Pmn2_1 -> C2/m (410.15K, 67.96 J/kgK)
# Pmn2_1 -> P-3m1 (464.61K, 84.45 J/kgK)
# Zr(PO3)4
# Zr(Se2Cl3)2
# Zr(WO4)2
# Zr11VO24
# Zr2Bi2O7
# Zr2N2O
# P-1 -> C2/m (529.24K, 22.73 J/kgK)
# Zr2P2O9
# Cmce -> C2/m (413.06K, 81.06 J/kgK)
# Zr2P2SO12
# Zr2SN2
# Zr2Ti(PbO3)3
# Zr2Ti3(PbO3)5
# Zr3BiF15
# Zr3N2O3
# Zr3N4
# R-3m -> I-43d (480.10K, 47.92 J/kgK)
# Zr3Ti(PbO3)4
# Pm -> P1 (538.41K, 31.16 J/kgK)
# Zr3Ti2(PbO3)5
# Cm -> R3m (413.98K, 9.65 J/kgK)
# Zr4N2O5
# Zr4Ti(PbO3)5
# Zr5Ti7O24
# Zr7(NO2)4
# Zr7VO16
# ZrBrN
# ZrCrAgS4
# Pmn2_1 -> Pmc2_1 (387.18K, 3.30 J/kgK)
# ZrCrCuS4
# ZrF4
# P4_2/m -> C2/c (328.79K, 57.22 J/kgK)
# ZrH6O3F4
# ZrI4
# ZrIN
# ZrMnO3
# ZrMoWO8
# ZrNCl
# ZrO2
# I4_1/amd -> Fm-3m (425.91K, 51.73 J/kgK)
# Fm-3m -> Pbcn (395.54K, 44.01 J/kgK)
# I4_1/amd -> Pbcn (411.67K, 95.80 J/kgK)
# ZrP2(HO3)2
# ZrP2O7
# ZrPbO3
# Amm2 -> Pm (450.08K, 9.90 J/kgK)
# Pba2 -> Pnma (310.01K, 3.00 J/kgK)
# ZrSO
# ZrSeO
# P2_13 -> P4/nmm (311.73K, 70.14 J/kgK)
# ZrSiO4
# ZrTi(PbO3)2
# P1 -> P4mm (561.24K, 42.66 J/kgK)
# R3m -> P4mm (433.47K, 27.73 J/kgK)
# ZrTi2(PbO3)3
# Pmm2 -> Cm (541.10K, 36.02 J/kgK)
# ZrTiO4

# %% [markdown]
# # Visualize the results

# %%
# Convert to panda data-frames for easy handling
stable_transition_phases   = pd.DataFrame(stable_transition_phases)
unstable_transition_phases = pd.DataFrame(unstable_transition_phases)

# %% [markdown]
# ## First N stable materials highest entropy changes

# %%
# Save to excel
df_es_stp = stable_transition_phases.sort_values(by='entropy-change', ascending=False)
df_es_stp.to_excel(f'{output_folder}/high-entropy stable transitions.xlsx')
df_es_stp
# Out:
#        compound polymorph-1 polymorph-2  transition-temperature  \
# 285        Li3N      P6/mmm    P6_3/mmc              550.867441
# 305      Li5BO4        Pmmn        Pbca              522.883531
# 467      NaCoO2        R-3m    P6_3/mmc              569.800067
# 54        BeCl2    I4_1/acd       I-43m              406.333305
# 383  Mg14VFeO16        Pmmm      P4/mmm              483.750873
# ..          ...         ...         ...                     ...
# 80       CaPbI4        C2/m        P2/m              304.840836
# 223    La2Ge2O7          P1         P-1              461.176494
# 537     Sr2SnO4        Pccn        Cmce              304.198275
# 129     CsPbCl3        Amm2        Amm2              537.359433
# 98      Cr2NiO4          Cc          Cc              459.761889
#
#      entropy-change  centrosymmetry  conductivity-change
# 285     1229.783120               2                  NaN
# 305      884.560796               2                  NaN
# 467      595.219039               2                  NaN
# 54       521.109083               1            -0.097980
# 383      496.918142               2                  NaN
# ..              ...             ...                  ...
# 80         1.736816               2                  NaN
# 223        1.627095               1            -0.010381
# 537        1.448546               2                  NaN
# 129        0.695875               0                  NaN
# 98         0.240488               0                  NaN
#
# [615 rows x 7 columns]

# %%
# Save to excel
df_es_stp = stable_transition_phases.sort_values(by='conductivity-change', ascending=False)
df_es_stp.to_excel(f'{output_folder}/high-conductivity stable transitions.xlsx')
df_es_stp
# Out:
#           compound polymorph-1 polymorph-2  transition-temperature  \
# 612          ZrSeO       P2_13      P4/nmm              311.725685
# 573            VF4          Pc        C2/c              486.519999
# 566         V2FeO4        C2/c          P1              527.231798
# 300        Li4TiS4        Pnma       I-42m              362.812226
# 362    LiNd(MoO4)2         I-4        P2/c              566.002101
# ..             ...         ...         ...                     ...
# 609        Zr2P2O9        Cmce        C2/m              413.059791
# 610   Zr3Ti(PbO3)4          Pm          P1              538.410364
# 611  Zr3Ti2(PbO3)5          Cm         R3m              413.980045
# 613    ZrTi(PbO3)2          P1        P4mm              561.244323
# 614   ZrTi2(PbO3)3        Pmm2          Cm              541.099155
#
#      entropy-change  centrosymmetry  conductivity-change
# 612       70.141038               1             0.733072
# 573      233.753006               1             0.473931
# 566      230.592425               1             0.429878
# 300       95.930945               1             0.427425
# 362       29.513969               1             0.366592
# ..              ...             ...                  ...
# 609       81.061703               2                  NaN
# 610       31.163507               0                  NaN
# 611        9.652537               0                  NaN
# 613       42.663214               0                  NaN
# 614       36.024532               0                  NaN
#
# [615 rows x 7 columns]

# %% [markdown]
# ## Amount of phase transitions at each temperature interval

# %%
n, bins, patches = plt.hist(unstable_transition_phases['transition-temperature'], alpha=0.4, label='Metastable')
n, bins, patches = plt.hist(stable_transition_phases['transition-temperature'],   alpha=0.4, label='Stable')

plt.legend(loc='best')
plt.xlabel('T (K)')
plt.ylabel(r'$N_{PT}$')
plt.savefig(f'{output_folder}/histogram_critical_temperatures.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Amount of phase transitions involving some entropy change

# %%
n, bins, patches = plt.hist(unstable_transition_phases['entropy-change'], bins=100, alpha=0.4, label='Metastable')
n, bins, patches = plt.hist(stable_transition_phases['entropy-change'],   bins=100, alpha=0.4, label='Stable')

plt.legend(loc='best')
plt.xlim(0, 500)
plt.xlabel(r'$\Delta S$ (J / kg K)')
plt.ylabel(r'$N_{PT}$')
plt.savefig(f'{output_folder}/histogram_entropy_changes.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Amount of phase transitions in terms of centrosymmetry

# %%
# Swith to type of transition
plt_unstable_non_centrosymmetry = np.array(unstable_transition_phases['centrosymmetry'], dtype=object)
plt_stable_non_centrosymmetry   = np.array(stable_transition_phases['centrosymmetry'],   dtype=object)

centrosymmetries = np.array(['polar-polar', 'polar-nonpolar', 'nonpolar-nonpolar'])

for i in range(len(centrosymmetries)):
    plt_unstable_non_centrosymmetry[np.where(unstable_transition_phases['centrosymmetry'] == i)[0]] = centrosymmetries[i]
    plt_stable_non_centrosymmetry[np.where(stable_transition_phases['centrosymmetry']     == i)[0]] = centrosymmetries[i]

# Create the histogram

n, bins, patches = plt.hist(plt_unstable_non_centrosymmetry, alpha=0.4, label='Metastable', align='left')
n, bins, patches = plt.hist(plt_stable_non_centrosymmetry,   alpha=0.4, label='Stable', align='left')

plt.ylabel(r'$N_{PT}$')
plt.legend(loc='best')
plt.savefig(f'{output_folder}/histogram_centrosymmetry.eps', dpi=50, bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Amount of phase transitions at each temperature and LTC change

# %%
x_edges = temperatures
y_edges = np.linspace(0, 1, 10+1)

# Generate the 2D histogram data
distribution = np.histogram2d(stable_transition_phases['transition-temperature'], np.abs(stable_transition_phases['conductivity-change']),
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=0, vmax=35)
plt.xlabel('T (K)')
plt.ylabel(r'$|\Delta \lambda_t| / \lambda_0$')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Stable transformations')
plt.savefig(f'{output_folder}/temperature_vs_stable_conductivity_changes.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Amount of phase transitions at each temperature and entropy change

# %%
x_edges = temperatures
y_edges = np.linspace(0, 500, 10+1)

# Generate the 2D histogram data
distribution = np.histogram2d(stable_transition_phases['transition-temperature'], stable_transition_phases['entropy-change'],
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=0, vmax=70)
plt.xlabel('T (K)')
plt.ylabel(r'$\Delta S$ (J / kg K)')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Stable transformations')
plt.savefig(f'{output_folder}/temperature_vs_stable_entropy_changes.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %%
x_edges = temperatures
y_edges = np.linspace(0, 500, 10+1)

# Generate the 2D histogram data
distribution = np.histogram2d(unstable_transition_phases['transition-temperature'], unstable_transition_phases['entropy-change'],
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=0, vmax=120)
plt.xlabel('T (K)')
plt.ylabel(r'$\Delta S$ (J / kg K)')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Metastable transformations')
plt.savefig(f'{output_folder}/temperature_vs_unstable_stable_entropy_changes.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Amount of phase transitions at each temperature and centrosymmetries

# %%
# Create a mapping of strings to unique integers
centrosymmetries_dict = {'polar-polar':       0,
                         'polar-nonpolar':    1,
                         'nonpolar-nonpolar': 2}
centrosymmetry_edges = [0, 0.66, 1.33, 2]
centrosymmetry_ticks_x = [0.33, 1, 1.66]
centrosymmetry_ticks_labels = ['polar-polar', 'polar-nonpolar', 'nonpolar-nonpolar']

# %%
x_edges = temperatures
y_edges = np.array(centrosymmetry_edges)

# Generate the 2D histogram data
distribution = np.histogram2d(stable_transition_phases['transition-temperature'], stable_transition_phases['centrosymmetry'],
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=20, vmax=45)
plt.yticks(centrosymmetry_ticks_x,
           centrosymmetry_ticks_labels)
plt.xlabel('T (K)')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Stable transformations')
plt.savefig(f'{output_folder}/temperature_vs_stable_centrosymmetry.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %%
x_edges = temperatures
y_edges = np.array(centrosymmetry_edges)

# Generate the 2D histogram data
distribution = np.histogram2d(unstable_transition_phases['transition-temperature'], unstable_transition_phases['centrosymmetry'],
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=50, vmax=140)
plt.yticks(centrosymmetry_ticks_x,
           centrosymmetry_ticks_labels)
plt.xlabel('T (K)')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Metastable transformations')
plt.savefig(f'{output_folder}/temperature_vs_unstable_centrosymmetry.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Amount of phase transitions with centrosymmetries and entropy change

# %%
x_edges = np.array(centrosymmetry_edges)
y_edges = np.linspace(0, 500, 10+1)

# Generate the 2D histogram data
distribution = np.histogram2d(stable_transition_phases['centrosymmetry'], stable_transition_phases['entropy-change'],
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=0, vmax=120)
plt.xticks(centrosymmetry_ticks_x,
           centrosymmetry_ticks_labels)
plt.ylabel(r'$\Delta S$ (J / kg K)')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Stable transformations')
plt.savefig(f'{output_folder}/entropy_changes_vs_stable_centrosymmetry.pdf', dpi=50, bbox_inches='tight')
plt.show()

# %%
x_edges = np.array(centrosymmetry_edges)
y_edges = np.linspace(0, 500, 10+1)

# Generate the 2D histogram data
distribution = np.histogram2d(unstable_transition_phases['centrosymmetry'], unstable_transition_phases['entropy-change'],
                              bins=(list(x_edges), list(y_edges))
                             )[0].T

# Create meshgrid for plotting
X, Y = np.meshgrid(x_edges, y_edges)

# Plot the 2D histogram with pcolormesh
fig, ax = plt.subplots()
plt.pcolormesh(X, Y, distribution, shading='auto', cmap='viridis', vmin=0, vmax=225)
plt.xticks(centrosymmetry_ticks_x,
           centrosymmetry_ticks_labels)
plt.ylabel(r'$\Delta S$ (J / kg K)')

# Calculate the centers of each cell
x_centers = (x_edges[:-1] + x_edges[1:]) / 2
y_centers = (y_edges[:-1] + y_edges[1:]) / 2
X_centers, Y_centers = np.meshgrid(x_centers, y_centers)

# Flatten the centers and Z values for vectorized annotation
x_flat = X_centers.flatten()
y_flat = Y_centers.flatten()
z_flat = distribution.flatten()

# Annotate all cells at once using vectorized operations
for xc, yc, z in zip(x_flat, y_flat, z_flat):
    ax.text(xc, yc, f'{int(z)}', ha='center', va='center', color='white', size=14)

# Add colorbar
colorbar = plt.colorbar()
colorbar.set_label(r'$N_{PT}$')

# Save the plot to a file
plt.title('Metastable transformations')
plt.savefig(f'{output_folder}/entropy_changes_vs_unstable_centrosymmetry.pdf', dpi=50, bbox_inches='tight')
plt.show()
